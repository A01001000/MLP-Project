# %% [markdown]
# # **WGANS WITH GRADIENT PENALTY FOR SYNTHESIZING ALZHEIMER'S MRI**

# %% [markdown]
# ### **IMPORTING THE NECESSARY DEPENDENCIES**

# %%
import os
import cv2
import random
import shutil
import warnings
import numpy as np
import seaborn as sns
from tqdm import tqdm
from numpy import cov
from PIL import Image
from numpy import trace
import tensorflow as tf
from numpy import asarray
from tensorflow import keras
from scipy.linalg import sqrtm
from numpy import iscomplexobj
import matplotlib.pyplot as plt
from numpy.random import randint
warnings.filterwarnings("ignore")
from tensorflow.keras import layers
from skimage.transform import resize
from IPython.display import FileLink
from keras.datasets.mnist import load_data
from keras.applications.inception_v3 import InceptionV3
from skimage.metrics import structural_similarity as ssim
from keras.applications.inception_v3 import preprocess_input
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# ### **DECLARING PATHS AND VARIABLES**

# %%
tf.random.set_seed(5638)
random.seed(5638)

# %%
working_directory = '/content/working_dir/'
os.makedirs(working_directory, exist_ok=True)
dataset_path = '/content/Kaggle Alzheimers Dataset/train/'
class_name = 'MildImpairment'

noise_dim = 256
IMG_SHAPE = (128, 128, 1)
BATCH_SIZE = 64

# %% [markdown]
# ### **PREPARING THE DATASET**

# %%
def prepare_dataset(class_name):
    # Path to the class where the real images are; in the orignal dataset
    class_path = dataset_path + class_name + '/'
    images = [cv2.imread(class_path + image_name, cv2.COLOR_BGR2GRAY) for image_name in os.listdir(class_path)]
    resized_images = np.array([cv2.resize(i, (IMG_SHAPE[0],IMG_SHAPE[1])) for i in images]).astype(np.float32)
    # Reshape each sample to (128, 128, 1) and normalize the pixel values in the [-1, 1] range
    reshaped_images = resized_images.reshape(resized_images.shape[0], *IMG_SHAPE)
    dataset = (reshaped_images - 127.5) / 127.5
    return dataset

train_images = prepare_dataset(class_name)

# %%
def conv_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding="same",
    use_bias=True,
    use_bn=False,
    use_dropout=False,
    drop_value=0.5
    ):

    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

def upsample_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    up_size=(2, 2),
    padding="same",
    use_bn=False,
    use_bias=True,
    use_dropout=False,
    drop_value=0.3
    ):

    x = layers.UpSampling2D(up_size)(x)
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    if activation:
        x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

# %% [markdown]
# ### **CREATE THE DISCRIMINATOR** (the critic in the original WGAN)

# %%
def get_discriminator_model():
    # input = 128 x 128, output = 64 x 64 
    img_input = layers.Input(shape=IMG_SHAPE)
    x = conv_block(
        img_input,
        32,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=False,
        drop_value=0.3
        )
    
    # input = 64 x 64, output = 32 x 32
    x = conv_block(
        x,
        64,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 32 x 32, output = 16 x 16
    x = conv_block(
        x,
        128,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 16 x 16, output = 8 x 8
    x = conv_block(
        x,
        256,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 8 x 8, output = 4 x 4
    x = conv_block(
        x,
        512,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 4 x 4, output = 1 
    x = layers.Flatten()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(1)(x)

    d_model = keras.models.Model(img_input, x, name="discriminator")
    return d_model

d_model = get_discriminator_model()
tf.keras.utils.plot_model(d_model, to_file='discriminator.jpg', show_shapes=True, rankdir='TB')

# %%
FileLink(r'discriminator.jpg')
# Out:
# /content/discriminator.jpg

# %% [markdown]
# ### **CREATE THE GENERATOR**

# %%
def get_generator_model():
    # input = (noise_dim, ), output = 4 x 4
    noise = layers.Input(shape=(noise_dim,))
    x = layers.Dense(4 * 4 * 2048, use_bias=False)(noise)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Reshape((4, 4, 2048))(x)
    
    # input = 4 x 4, output = 8 x 8
    x = upsample_block(
        x,
        1024,
        layers.LeakyReLU(0.2),
        kernel_size =(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 8 x 8, output = 16 x 16
    x = upsample_block(
        x,
        512,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 16 x 16, output = 32 x 32
    x = upsample_block(
        x,
        256,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 32 x 32, output = 64 x 64
    x = upsample_block(
        x,
        128,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 64 x 64, output = 128 x 128
    x = upsample_block(x, 1, layers.Activation("tanh"), strides=(1, 1), use_bias=False, use_bn=True)
    
    g_model = keras.models.Model(noise, x, name="generator")
    return g_model


g_model = get_generator_model()
tf.keras.utils.plot_model(g_model, to_file='generator.jpg', show_shapes=True, rankdir='TB')

# %%
FileLink('generator.jpg')
# Out:
# /content/generator.jpg

# %% [markdown]
# ### **CREATE THE WGAN-GP MODEL**
#
# Now that we have defined our generator and discriminator, it's time to implement the WGAN-GP model. We will also override the train_step for training.

# %%
class WGAN(keras.Model):
    def __init__(
        self,
        discriminator,
        generator,
        latent_dim,
        discriminator_extra_steps=5,
        gp_weight=10.0,
    ):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.d_steps = discriminator_extra_steps
        self.gp_weight = gp_weight

    def compile(self, d_optimizer, g_optimizer, d_loss_fn, g_loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss_fn = d_loss_fn
        self.g_loss_fn = g_loss_fn 

    def gradient_penalty(self, batch_size, real_images, fake_images):
        """Calculates the gradient penalty.

        This loss is calculated on an interpolated image
        and added to the discriminator loss.
        """
        # Get the interpolated image
        alpha = tf.random.normal([batch_size, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            # 1. Get the discriminator output for this interpolated image.
            pred = self.discriminator(interpolated, training=True)

        # 2. Calculate the gradients w.r.t to this interpolated image.
        grads = gp_tape.gradient(pred, [interpolated])[0]
        # 3. Calculate the norm of the gradients.
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        if isinstance(real_images, tuple):
            real_images = real_images[0]

        # Get the batch size
        batch_size = tf.shape(real_images)[0]

        # For each batch, we are going to perform the
        # following steps as laid out in the original paper:
        # 1. Train the generator and get the generator loss
        # 2. Train the discriminator and get the discriminator loss
        # 3. Calculate the gradient penalty
        # 4. Multiply this gradient penalty with a constant weight factor
        # 5. Add the gradient penalty to the discriminator loss
        # 6. Return the generator and discriminator losses as a loss dictionary

        # Train the discriminator first. 
        for i in range(self.d_steps):
            # Get the latent vector
            random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
            with tf.GradientTape() as tape:
                # Generate fake images from the latent vector
                fake_images = self.generator(random_latent_vectors, training=True)
                # Get the logits for the fake images
                fake_logits = self.discriminator(fake_images, training=True)
                # Get the logits for the real images
                real_logits = self.discriminator(real_images, training=True)

                # Calculate the discriminator loss using the fake and real image logits
                d_cost = self.d_loss_fn(real_img=real_logits, fake_img=fake_logits)
                # Calculate the gradient penalty
                gp = self.gradient_penalty(batch_size, real_images, fake_images)
                # Add the gradient penalty to the original discriminator loss
                d_loss = d_cost + gp * self.gp_weight

            # Get the gradients w.r.t the discriminator loss
            d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
            # Update the weights of the discriminator using the discriminator optimizer
            self.d_optimizer.apply_gradients(
                zip(d_gradient, self.discriminator.trainable_variables)
            )

        # Train the generator
        # Get the latent vector
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        with tf.GradientTape() as tape:
            # Generate fake images using the generator
            generated_images = self.generator(random_latent_vectors, training=True)
            # Get the discriminator logits for fake images
            gen_img_logits = self.discriminator(generated_images, training=True)
            # Calculate the generator loss
            g_loss = self.g_loss_fn(gen_img_logits)

        # Get the gradients w.r.t the generator loss
        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        # Update the weights of the generator using the generator optimizer
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )

        return {"d_loss": d_loss, "g_loss": g_loss}

# %% [markdown]
# ### **CREATE A CUSTOM CALLBACK**

# %%
class WGAN_CALLBACK(keras.callbacks.Callback):
    def __init__(self, n_epochs = 20, batch_size = BATCH_SIZE, latent_vector_dim = 128):
        self.batch_size = batch_size
        self.noise_dim = latent_vector_dim
        self.fid_scores = []
        self.n_epochs = n_epochs
        
    @property
    def get_fid_scores(self):
        return self.fid_scores
    
    def plot_multiple_images(self,images, n_cols):
        n_cols = n_cols or len(images)
        n_rows = len(images) // n_cols
        if images.shape[-1] == 1:
            images = np.squeeze(images, axis=-1)
        plt.figure(figsize=(n_cols, n_rows))   
        plt.tight_layout()
        plt.suptitle('BEST GENERATOR', fontweight = 'bold')
        for index, image in enumerate(images):
            plt.subplot(n_rows, n_cols, index + 1)
            plt.imshow(image, cmap="gray")
            plt.axis("off")
    
    def calculate_fid(self, generated_images, real_images):
        # scale an array of images to a new size
        def scale_images(images, new_shape):
            images_list = []
            for image in images:
                # resize with nearest neighbor interpolation
                resized_image = cv2.cvtColor(cv2.resize(image, new_shape, cv2.INTER_NEAREST), cv2.COLOR_GRAY2BGR)
                # store the resized images
                images_list.append(resized_image)
            return asarray(images_list)
        # prepare the inception v3 model
        model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))
        # resize images
        generated_images = scale_images(generated_images, (299,299))
        real_images = scale_images(real_images, (299,299))
        # pre-process images
        generated_images = preprocess_input(generated_images)
        real_images = preprocess_input(real_images)
        # calculate feature embeddings
        embeddings1 = model.predict(generated_images)
        embeddings2 = model.predict(real_images)
        # calculate mean and covariance statistics
        mu1, sigma1 = embeddings1.mean(axis=0), cov(embeddings1, rowvar=False)
        mu2, sigma2 = embeddings2.mean(axis=0), cov(embeddings2, rowvar=False)
        # calculate sum squared difference between means
        ssdiff = np.sum((mu1 - mu2)**2.0)
        # calculate sqrt of product between cov
        covmean = sqrtm(sigma1.dot(sigma2))
        # check and correct imaginary numbers from sqrt
        if iscomplexobj(covmean):
            covmean = covmean.real
        # calculate fid score
        fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
        return np.round(fid,2)

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.batch_size, self.noise_dim))
        generator = self.model.generator
        generated_batch = generator(random_latent_vectors)
        generated_batch = generated_batch.numpy()
        random_number = np.random.randint(train_images.shape[0] - self.batch_size)
        real_batch = train_images[random_number: random_number + self.batch_size]
        current_fid = self.calculate_fid(generated_batch, real_batch)
        self.fid_scores.append(current_fid)  
        print('\033[1mFID SCORE: {}\033[0m'.format(current_fid))
        
        if current_fid < 5:
          generator.save(working_directory + "MI_gen_{}_({}).h5".format(epoch+1,current_fid),save_format='h5')

# %%
def clear_workspace():
    for filename in os.listdir(working_directory):
        file_path = os.path.join(working_directory, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
def download_synthetic_images(generator, number_of_images, class_name = 'None'):
    clear_workspace()
    # Making sure that no two images have the same name
    counter = 1
    # To check if folder is full
    folder_full = False
    # Folder path to store synthetic images. Folder name is the same as the class name which is inside the working directory
    folder_path = working_directory + 'synthetic_' + class_name + '/'
    images_folder = os.path.join(folder_path)
    # Create this folder if it doesn't exists, otherwise do nothing
    os.makedirs(images_folder, exist_ok=True)
    # Unless I get the desired number of good quality synthetic images in this folder, keep on generating images
    pbar = tqdm(total=number_of_images, position=0, leave=True)
    while len(os.listdir(images_folder)) < number_of_images:
        # Generate a batch of synthetic images
        random_latent_vectors = tf.random.normal(shape=(BATCH_SIZE, noise_dim))
        synthetic_images_batch = generator(random_latent_vectors)
        # Convert tensors to numpy arrays 
        synthetic_images_batch = synthetic_images_batch.numpy()
        # Convert the scale of images from (-1,1) to (0,255) and data type from float to integers 
        for image in synthetic_images_batch:
            image = (image * 127.5) + 127.5
            image = image.astype(np.uint8)
            # If it is a single channel image then save it as it is
            if image.shape[2] == 1:
                cv2.imwrite(images_folder + class_name + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If it is a 3 channel image then first convert it to grayscale and then save it
            elif image.shape[2] == 3:
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                cv2.imwrite(images_folder + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If the folder now has the number of desired images, then come out of the loop
            if len(os.listdir(images_folder)) >= number_of_images:
                folder_full = True
                break
        if folder_full == True:
                break
            
    # Generate a link from where I can download the synthetic images
    os.system('zip -r synthetic_images.zip {} >/dev/null 2>&1'.format(folder_path))
    return FileLink(r'synthetic_images.zip')

# %% [markdown]
# ### **TRAIN THE END TO END MODEL**

# %%
def train_wgans(dataset, n_epochs, batch_size = BATCH_SIZE, optimizer = 'adam', gen_lr = 0.0001, dis_lr = 0.0001):
    clear_workspace()
    assert optimizer in ['adam','rmsprop', 'nadam'], "Invalid optimizer. Valid options are 'adam' or 'rmsprop' or 'nadam'."
    if optimizer == 'adam':
        generator_optimizer = keras.optimizers.Adam(learning_rate = gen_lr, beta_1=0, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Adam(learning_rate = dis_lr, beta_1=0, beta_2=0.9)
    elif optimizer == 'rmsprop':
        generator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = gen_lr)
        discriminator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = dis_lr)
    elif optimizer == 'nadam':
        generator_optimizer = keras.optimizers.Nadam(learning_rate = gen_lr, beta_1=0.5, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Nadam(learning_rate = dis_lr, beta_1=0.5, beta_2=0.9)

    # Define the loss functions for the discriminator,
    # which should be (fake_loss - real_loss).
    # We will add the gradient penalty later to this loss function.
    def discriminator_loss(real_img, fake_img):
        real_loss = tf.reduce_mean(real_img)
        fake_loss = tf.reduce_mean(fake_img)
        return fake_loss - real_loss

    # Define the loss functions for the generator.
    def generator_loss(fake_img):
        return -tf.reduce_mean(fake_img)

    # Instantiate the customer `WGAN_CALLBACK` Keras callback.
    custom_callback = WGAN_CALLBACK(n_epochs, batch_size = BATCH_SIZE, latent_vector_dim = noise_dim)

    # Get the wgan model
    wgan = WGAN(discriminator = d_model, generator = g_model, latent_dim = noise_dim, discriminator_extra_steps=5)

    # Compile the wgan model
    wgan.compile(
        d_optimizer = discriminator_optimizer,
        g_optimizer = generator_optimizer,
        g_loss_fn = generator_loss,
        d_loss_fn = discriminator_loss
    )

    # Start training
    wgan_history = wgan.fit(dataset, batch_size = BATCH_SIZE, epochs = n_epochs, callbacks=[custom_callback])
    fid_scores = custom_callback.get_fid_scores
    return wgan_history, fid_scores

# %%
# %%time
wgan_history, fid_scores = train_wgans(dataset = train_images, 
                                        n_epochs = 2000, 
                                        batch_size = BATCH_SIZE, 
                                        optimizer = 'adam', 
                                        gen_lr = 0.0001, 
                                        dis_lr = 0.0001)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 12.22
# 12/12 [==============================] - 13s 1s/step - d_loss: -4.6973 - g_loss: 9.1767
# Epoch 1002/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.45
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.5682 - g_loss: 11.7431
# Epoch 1003/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.67
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.3884 - g_loss: 8.2887
# Epoch 1004/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# FID SCORE: 6.67
# 12/12 [==============================] - 13s 1s/step - d_loss: -4.5217 - g_loss: 2.5856
# Epoch 1005/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.97
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.7711 - g_loss: 4.3978
# Epoch 1006/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 11.27
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.7387 - g_loss: -0.4727
# Epoch 1007/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.54
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.2986 - g_loss: 17.7080
# Epoch 1008/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.62
# 12/12 [==============================] - 14s 1s/step - d_loss: -8.1460 - g_loss: 18.2954
# Epoch 1009/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.76
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.7668 - g_loss: 22.8568
# Epoch 1010/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.36
# 12/12 [==============================] - 14s 1s/step - d_loss: -7.2931 - g_loss: 18.1408
# Epoch 1011/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.53
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.6647 - g_loss: 35.0929
# Epoch 1012/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.44
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.6107 - g_loss: 27.1748
# Epoch 1013/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 7.0
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.3685 - g_loss: 30.0008
# Epoch 1014/2000
# 2/2 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 11.99
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.7904 - g_loss: 19.1108
# Epoch 1015/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 9.84
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.9609 - g_loss: 22.2784
# Epoch 1016/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.97
# 12/12 [==============================] - 15s 1s/step - d_loss: -2.2960 - g_loss: 13.4914
# Epoch 1017/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# FID SCORE: 8.85
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.9529 - g_loss: 10.3756
# Epoch 1018/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.44
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.8425 - g_loss: 5.6744
# Epoch 1019/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 5.95
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.5658 - g_loss: 6.8833
# Epoch 1020/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 6.88
# 12/12 [==============================] - 15s 1s/step - d_loss: -2.0606 - g_loss: 6.2558
# Epoch 1021/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# FID SCORE: 7.39
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.4726 - g_loss: 0.3942
# Epoch 1022/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 7.38
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.7821 - g_loss: 1.5630
# Epoch 1023/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.15
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.8418 - g_loss: -0.6482
# Epoch 1024/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.4
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.0401 - g_loss: 5.8716
# Epoch 1025/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 14.65
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.3688 - g_loss: 3.2148
# Epoch 1026/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.11
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.4530 - g_loss: 8.3391
# Epoch 1027/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 8.54
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.7934 - g_loss: 5.7539
# Epoch 1028/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.45
# 12/12 [==============================] - 16s 1s/step - d_loss: -3.9020 - g_loss: 13.3666
# Epoch 1029/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.36
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.4395 - g_loss: 6.1795
# Epoch 1030/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.0
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.9251 - g_loss: 5.0090
# Epoch 1031/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.13
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.0256 - g_loss: 9.5121
# Epoch 1032/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# FID SCORE: 14.44
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.0183 - g_loss: 14.9010
# Epoch 1033/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 10.2
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1249 - g_loss: 7.5858
# Epoch 1034/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 5.89
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.0343 - g_loss: 10.5661
# Epoch 1035/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.84
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.8297 - g_loss: 7.0219
# Epoch 1036/2000
# 2/2 [==============================] - 1s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 9.4
# 12/12 [==============================] - 13s 1s/step - d_loss: -4.3023 - g_loss: 4.1807
# Epoch 1037/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 12.5
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.6939 - g_loss: 5.2497
# Epoch 1038/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.7
# 12/12 [==============================] - 15s 1s/step - d_loss: -7.8660 - g_loss: 12.2657
# Epoch 1039/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.7
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.3858 - g_loss: 6.3013
# Epoch 1040/2000
# 2/2 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 7.43
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1208 - g_loss: 5.4563
# Epoch 1041/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.24
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.9140 - g_loss: -2.4296
# Epoch 1042/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 6.68
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.4314 - g_loss: -4.4035
# Epoch 1043/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 6.38
# 12/12 [==============================] - 13s 1s/step - d_loss: -3.0614 - g_loss: -3.1818
# Epoch 1044/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.37
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.1130 - g_loss: -0.0273
# Epoch 1045/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 5.7
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.8496 - g_loss: 1.4303
# Epoch 1046/2000
# 2/2 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 12.21
# 12/12 [==============================] - 13s 1s/step - d_loss: -3.9856 - g_loss: 5.6275
# Epoch 1047/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.56
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.1083 - g_loss: 6.2795
# Epoch 1048/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 9.22
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.9521 - g_loss: 9.5002
# Epoch 1049/2000
# 2/2 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.67
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.2920 - g_loss: 10.7397
# Epoch 1050/2000
# 2/2 [==============================] - 3s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.02
# 12/12 [==============================] - 15s 1s/step - d_loss: -2.9770 - g_loss: 8.5753
# Epoch 1051/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.77
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.4259 - g_loss: 10.2258
# Epoch 1052/2000
# 2/2 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 10.68
# 12/12 [==============================] - 13s 1s/step - d_loss: -2.0573 - g_loss: 6.1861
# Epoch 1053/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.58
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.3209 - g_loss: 10.4340
# Epoch 1054/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 11.09
# 12/12 [==============================] - 15s 1s/step - d_loss: -2.4042 - g_loss: 14.4954
# Epoch 1055/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 10.42
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.8623 - g_loss: 4.7855
# Epoch 1056/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.66
# 12/12 [==============================] - 13s 1s/step - d_loss: -6.3257 - g_loss: 11.4274
# Epoch 1057/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.3
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.7707 - g_loss: 19.7209
# Epoch 1058/2000
# 2/2 [==============================] - 2s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 10.58
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.8144 - g_loss: 7.7557
# Epoch 1059/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.52
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.9048 - g_loss: 1.5383
# Epoch 1060/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 5.55
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.0297 - g_loss: 10.9734
# Epoch 1061/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.89
# 12/12 [==============================] - 14s 1s/step - d_loss: -6.4191 - g_loss: 6.0304
# Epoch 1062/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 5.14
# 12/12 [==============================] - 14s 1s/step - d_loss: -6.0743 - g_loss: 9.5819
# Epoch 1063/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.76
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.9859 - g_loss: 10.8197
# Epoch 1064/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.24
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.2726 - g_loss: 9.3821
# Epoch 1065/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.63
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.2576 - g_loss: 23.0531
# Epoch 1066/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 14.97
# 12/12 [==============================] - 13s 1s/step - d_loss: -5.2573 - g_loss: 12.4714
# Epoch 1067/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.34
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.8727 - g_loss: 19.3346
# Epoch 1068/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.56
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.6779 - g_loss: 10.2749
# Epoch 1069/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 11.5
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.5529 - g_loss: 5.8840
# Epoch 1070/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.22
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.7495 - g_loss: 13.5568
# Epoch 1071/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.24
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.6843 - g_loss: 12.3335
# Epoch 1072/2000
# 2/2 [==============================] - 1s 31ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.38
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.2048 - g_loss: 10.7005
# Epoch 1073/2000
# 2/2 [==============================] - 2s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 6.86
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.5553 - g_loss: 8.0923
# Epoch 1074/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.16
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.4421 - g_loss: -0.4303
# Epoch 1075/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.16
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.4838 - g_loss: 10.5572
# Epoch 1076/2000
# 2/2 [==============================] - 3s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 9.43
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.4699 - g_loss: 8.6353
# Epoch 1077/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 11.68
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.4536 - g_loss: 16.4093
# Epoch 1078/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 33ms/step
# FID SCORE: 7.75
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.6228 - g_loss: 9.1666
# Epoch 1079/2000
# 2/2 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 12.44
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1289 - g_loss: 6.6203
# Epoch 1080/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 5.88
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.7778 - g_loss: 11.1297
# Epoch 1081/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 9.06
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.0727 - g_loss: 6.6195
# Epoch 1082/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.25
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.1754 - g_loss: 0.7393
# Epoch 1083/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.41
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.3237 - g_loss: 4.0662
# Epoch 1084/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 14.24
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.7901 - g_loss: 1.6024
# Epoch 1085/2000
# 2/2 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 5.25
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.6243 - g_loss: -0.6565
# Epoch 1086/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 12.8
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.5148 - g_loss: 2.4776
# Epoch 1087/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# FID SCORE: 7.61
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.1514 - g_loss: 6.3164
# Epoch 1088/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.99
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.7870 - g_loss: 0.2261
# Epoch 1089/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 5.73
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.5404 - g_loss: 2.0167
# Epoch 1090/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 5.56
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1044 - g_loss: -8.5413
# Epoch 1091/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.45
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.4403 - g_loss: -5.5869
# Epoch 1092/2000
# 2/2 [==============================] - 3s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.81
# 12/12 [==============================] - 15s 1s/step - d_loss: -2.6184 - g_loss: -7.6708
# Epoch 1093/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.79
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.8818 - g_loss: 0.9174
# Epoch 1094/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 9.97
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1979 - g_loss: -6.6018
# Epoch 1095/2000
# 2/2 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# FID SCORE: 6.98
# 12/12 [==============================] - 13s 1s/step - d_loss: -4.4144 - g_loss: -2.0556
# Epoch 1096/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.16
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.5739 - g_loss: 7.4575
# Epoch 1097/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.71
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.5129 - g_loss: -2.4524
# Epoch 1098/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 10.85
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.1027 - g_loss: 8.2437
# Epoch 1099/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.72
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.3949 - g_loss: 4.8409
# Epoch 1100/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.73
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.2366 - g_loss: 0.9356
# Epoch 1101/2000
# 2/2 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.7
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.9826 - g_loss: 3.8628
# Epoch 1102/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 5.51
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.4485 - g_loss: 4.4981
# Epoch 1103/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 5.32
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.0193 - g_loss: 1.3213
# Epoch 1104/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.08
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.6229 - g_loss: 3.1467
# Epoch 1105/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 6.33
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1354 - g_loss: 2.3819
# Epoch 1106/2000
# 2/2 [==============================] - 2s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.78
# 12/12 [==============================] - 16s 1s/step - d_loss: -5.4861 - g_loss: 4.8729
# Epoch 1107/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 5.65
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.7575 - g_loss: 5.8255
# Epoch 1108/2000
# 2/2 [==============================] - 1s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 7.1
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.3022 - g_loss: 14.0941
# Epoch 1109/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.49
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.2293 - g_loss: 6.2771
# Epoch 1110/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 12.05
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.0172 - g_loss: 11.5976
# Epoch 1111/2000
# 2/2 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.53
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.3814 - g_loss: 13.4799
# Epoch 1112/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 10.48
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.5584 - g_loss: 9.6490
# Epoch 1113/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.06
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.7434 - g_loss: 8.8953
# Epoch 1114/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 10.33
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.0279 - g_loss: 7.1440
# Epoch 1115/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.2
# 12/12 [==============================] - 15s 1s/step - d_loss: -2.5485 - g_loss: 11.3586
# Epoch 1116/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.88
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.6073 - g_loss: -1.3272
# Epoch 1117/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.78
# 12/12 [==============================] - 13s 1s/step - d_loss: -4.9986 - g_loss: 6.1780
# Epoch 1118/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 9.38
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.0831 - g_loss: -4.2070
# Epoch 1119/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.53
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.0718 - g_loss: 4.1861
# Epoch 1120/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.36
# 12/12 [==============================] - 13s 1s/step - d_loss: -3.7328 - g_loss: 7.9791
# Epoch 1121/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 33ms/step
# FID SCORE: 6.65
# 12/12 [==============================] - 13s 1s/step - d_loss: -3.0641 - g_loss: 7.5790
# Epoch 1122/2000
# 2/2 [==============================] - 2s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.16
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.4182 - g_loss: 7.5697
# Epoch 1123/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 8.52
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.2060 - g_loss: 9.4689
# Epoch 1124/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 7.06
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.5727 - g_loss: 4.1826
# Epoch 1125/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 5.73
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.1051 - g_loss: 8.3490
# Epoch 1126/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 5.44
# 12/12 [==============================] - 13s 1s/step - d_loss: -4.5903 - g_loss: 11.4592
# Epoch 1127/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 4.91
# 12/12 [==============================] - 13s 1s/step - d_loss: -5.4849 - g_loss: 10.3273
# Epoch 1128/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.49
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.7102 - g_loss: 8.5981
# Epoch 1129/2000
# 2/2 [==============================] - 2s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 5.95
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.2179 - g_loss: 14.5927
# Epoch 1130/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
# FID SCORE: 8.09
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.1558 - g_loss: 2.4594
# Epoch 1131/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.53
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.2118 - g_loss: 5.5463
# Epoch 1132/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.81
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.5837 - g_loss: 2.9423
# Epoch 1133/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.73
# 12/12 [==============================] - 13s 1s/step - d_loss: -3.6590 - g_loss: 4.8751
# Epoch 1134/2000
# 2/2 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 6.89
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.9934 - g_loss: 13.7835
# Epoch 1135/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.47
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.2746 - g_loss: 10.8957
# Epoch 1136/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.54
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.7288 - g_loss: 10.9707
# Epoch 1137/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.79
# 12/12 [==============================] - 13s 1s/step - d_loss: -4.4702 - g_loss: 5.5588
# Epoch 1138/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 10.34
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.6835 - g_loss: 13.1061
# Epoch 1139/2000
# 2/2 [==============================] - 2s 24ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.02
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.3364 - g_loss: 5.0724
# Epoch 1140/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.89
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.4937 - g_loss: 7.1930
# Epoch 1141/2000
# 2/2 [==============================] - 2s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 6.43
# 12/12 [==============================] - 16s 1s/step - d_loss: -4.0090 - g_loss: 5.9661
# Epoch 1142/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 5.57
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.0788 - g_loss: 9.8187
# Epoch 1143/2000
# 2/2 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 13.29
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.8897 - g_loss: 2.8049
# Epoch 1144/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.25
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.1407 - g_loss: 7.9984
# Epoch 1145/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 7.78
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.9208 - g_loss: 3.2748
# Epoch 1146/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.37
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.5360 - g_loss: 12.7440
# Epoch 1147/2000
# 2/2 [==============================] - 3s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.54
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.5353 - g_loss: 8.5792
# Epoch 1148/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 9.23
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.5231 - g_loss: 3.7772
# Epoch 1149/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 8.01
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.9061 - g_loss: 8.7070
# Epoch 1150/2000
# 2/2 [==============================] - 1s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 4.75
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.5443 - g_loss: 6.5270
# Epoch 1151/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.67
# 12/12 [==============================] - 15s 1s/step - d_loss: -2.7933 - g_loss: -2.7207
# Epoch 1152/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 11.91
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.2984 - g_loss: 3.1684
# Epoch 1153/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 11.7
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.2723 - g_loss: -6.7793
# Epoch 1154/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 5.38
# 12/12 [==============================] - 15s 1s/step - d_loss: -2.4528 - g_loss: 5.1807
# Epoch 1155/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.4
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.8547 - g_loss: 0.1685
# Epoch 1156/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 5.81
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.7026 - g_loss: 10.8287
# Epoch 1157/2000
# 2/2 [==============================] - 3s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 10.09
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.8138 - g_loss: 8.0307
# Epoch 1158/2000
# 2/2 [==============================] - 2s 31ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.16
# 12/12 [==============================] - 14s 1s/step - d_loss: -8.1084 - g_loss: 16.2078
# Epoch 1159/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 7.55
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.6924 - g_loss: 10.0212
# Epoch 1160/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 5.3
# 12/12 [==============================] - 14s 1s/step - d_loss: -6.4987 - g_loss: 18.7388
# Epoch 1161/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 32ms/step
# FID SCORE: 5.1
# 12/12 [==============================] - 15s 1s/step - d_loss: -6.2459 - g_loss: 13.9841
# Epoch 1162/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.87
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1943 - g_loss: 9.6749
# Epoch 1163/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.59
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.1989 - g_loss: 6.2820
# Epoch 1164/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.07
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.5320 - g_loss: 1.1891
# Epoch 1165/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 11.22
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.7688 - g_loss: 6.5966
# Epoch 1166/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.31
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.2583 - g_loss: 18.4531
# Epoch 1167/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 5.18
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.2262 - g_loss: 13.9144
# Epoch 1168/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 12.67
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.2043 - g_loss: 16.2679
# Epoch 1169/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.79
# 12/12 [==============================] - 15s 1s/step - d_loss: -6.7294 - g_loss: 19.0438
# Epoch 1170/2000
# 2/2 [==============================] - 3s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 5.99
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.8231 - g_loss: 11.1932
# Epoch 1171/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 5.61
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.6243 - g_loss: 13.6847
# Epoch 1172/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 6.61
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.3391 - g_loss: 10.1118
# Epoch 1173/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 7.53
# 12/12 [==============================] - 14s 1s/step - d_loss: -8.3708 - g_loss: 24.0428
# Epoch 1174/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 7.18
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.5609 - g_loss: 21.1080
# Epoch 1175/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 6.51
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.6181 - g_loss: 15.7824
# Epoch 1176/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 14.39
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.1943 - g_loss: 14.7652
# Epoch 1177/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.27
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.1020 - g_loss: 24.2642
# Epoch 1178/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.28
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.8280 - g_loss: 14.3313
# Epoch 1179/2000
# 2/2 [==============================] - 2s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.66
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.1401 - g_loss: 17.3030
# Epoch 1180/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.63
# 12/12 [==============================] - 15s 1s/step - d_loss: -1.2614 - g_loss: 13.4716
# Epoch 1181/2000
# 2/2 [==============================] - 2s 31ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.3
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.2031 - g_loss: 25.8416
# Epoch 1182/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 6.63
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.7502 - g_loss: 11.0849
# Epoch 1183/2000
# 2/2 [==============================] - 3s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.53
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.9210 - g_loss: 20.4200
# Epoch 1184/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.8
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.1107 - g_loss: 14.9794
# Epoch 1185/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.51
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1987 - g_loss: 12.4417
# Epoch 1186/2000
# 2/2 [==============================] - 1s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 8.98
# 12/12 [==============================] - 14s 1s/step - d_loss: -2.3421 - g_loss: 10.8744
# Epoch 1187/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 7.16
# 12/12 [==============================] - 16s 1s/step - d_loss: -4.7673 - g_loss: 10.1887
# Epoch 1188/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.32
# 12/12 [==============================] - 14s 1s/step - d_loss: -5.0884 - g_loss: 11.4441
# Epoch 1189/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 9.48
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.1627 - g_loss: 12.1475
# Epoch 1190/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 6.96
# 12/12 [==============================] - 16s 1s/step - d_loss: -3.4105 - g_loss: 1.4463
# Epoch 1191/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 9.05
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1123 - g_loss: 3.5189
# Epoch 1192/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 7.03
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.4613 - g_loss: -4.9306
# Epoch 1193/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 6.47
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.9092 - g_loss: -1.3837
# Epoch 1194/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 6.52
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.5103 - g_loss: 7.1476
# Epoch 1195/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.13
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.0828 - g_loss: 8.0291
# Epoch 1196/2000
# 2/2 [==============================] - 3s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 5.62
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.1219 - g_loss: -0.0843
# Epoch 1197/2000
# 2/2 [==============================] - 2s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# FID SCORE: 9.74
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.5449 - g_loss: 4.2819
# Epoch 1198/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 9.49
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.2709 - g_loss: 6.4314
# Epoch 1199/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 5.21
# 12/12 [==============================] - 13s 1s/step - d_loss: -3.9657 - g_loss: 8.7416
# Epoch 1200/2000
# 2/2 [==============================] - 2s 31ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.43
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.5208 - g_loss: 14.2008
# Epoch 1201/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 4.25
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.5083 - g_loss: 7.8173
# Epoch 1202/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# FID SCORE: 7.42
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.4749 - g_loss: 1.0920
# Epoch 1203/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.23
# 12/12 [==============================] - 15s 1s/step - d_loss: -5.3538 - g_loss: 9.5358
# Epoch 1204/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.76
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.0026 - g_loss: 10.3155
# Epoch 1205/2000
# 2/2 [==============================] - 1s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 5.96
# 12/12 [==============================] - 14s 1s/step - d_loss: -3.0363 - g_loss: 5.7925
# Epoch 1206/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 6.96
# 12/12 [==============================] - 16s 1s/step - d_loss: -3.8998 - g_loss: 2.7495
# Epoch 1207/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.91
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.2172 - g_loss: 11.8085
# Epoch 1208/2000
# 2/2 [==============================] - 1s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 5.66
# 12/12 [==============================] - 14s 1s/step - d_loss: -1.9757 - g_loss: 9.2295
# Epoch 1209/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 5.77
# 12/12 [==============================] - 15s 1s/step - d_loss: -3.4357 - g_loss: 5.3007
# Epoch 1210/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 9.6
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.7667 - g_loss: 5.3793
# Epoch 1211/2000
# 2/2 [==============================] - 1s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 5.64
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.1959 - g_loss: 11.5441
# Epoch 1212/2000
# 2/2 [==============================] - 3s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 6.25
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.3702 - g_loss: 6.0240
# Epoch 1213/2000
# 2/2 [==============================] - 2s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 11.64
# 12/12 [==============================] - 14s 1s/step - d_loss: -4.6249 - g_loss: 12.5825
# Epoch 1214/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 32ms/step
# FID SCORE: 6.39
# ...
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 7.84
# 12/12 [==============================] - 17s 1s/step - d_loss: 152.6770 - g_loss: 619.0074
# Epoch 1932/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 8.95
# 12/12 [==============================] - 15s 1s/step - d_loss: 78.1840 - g_loss: 509.8098
# Epoch 1933/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 35ms/step
# FID SCORE: 10.87
# 12/12 [==============================] - 14s 1s/step - d_loss: -133.2583 - g_loss: 257.7245
# Epoch 1934/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 14.25
# 12/12 [==============================] - 14s 1s/step - d_loss: 141.6101 - g_loss: 100.3028
# Epoch 1935/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 11.55
# 12/12 [==============================] - 16s 1s/step - d_loss: -163.1733 - g_loss: -37.0599
# Epoch 1936/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 11.52
# 12/12 [==============================] - 15s 1s/step - d_loss: -50.2003 - g_loss: -101.0956
# Epoch 1937/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 13.36
# 12/12 [==============================] - 15s 1s/step - d_loss: 14.9457 - g_loss: 211.7244
# Epoch 1938/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 7.53
# 12/12 [==============================] - 17s 1s/step - d_loss: -47.0046 - g_loss: 765.9830
# Epoch 1939/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 10.53
# 12/12 [==============================] - 15s 1s/step - d_loss: 144.6905 - g_loss: 521.2136
# Epoch 1940/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 14.44
# 12/12 [==============================] - 14s 1s/step - d_loss: 22.6385 - g_loss: 447.9386
# Epoch 1941/2000
# 2/2 [==============================] - 2s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 16.86
# 12/12 [==============================] - 16s 1s/step - d_loss: -185.2048 - g_loss: 473.6168
# Epoch 1942/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 10.95
# 12/12 [==============================] - 16s 1s/step - d_loss: -128.4208 - g_loss: 214.4651
# Epoch 1943/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 14.69
# 12/12 [==============================] - 14s 1s/step - d_loss: 76.8516 - g_loss: 245.9590
# Epoch 1944/2000
# 2/2 [==============================] - 3s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 11.39
# 12/12 [==============================] - 18s 2s/step - d_loss: 21.7893 - g_loss: 821.4132
# Epoch 1945/2000
# 2/2 [==============================] - 2s 34ms/step
# 2/2 [==============================] - 0s 39ms/step
# FID SCORE: 8.12
# 12/12 [==============================] - 16s 1s/step - d_loss: 152.8337 - g_loss: 940.3390
# Epoch 1946/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 13.25
# 12/12 [==============================] - 15s 1s/step - d_loss: 191.2872 - g_loss: 1334.0230
# Epoch 1947/2000
# 2/2 [==============================] - 3s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.27
# 12/12 [==============================] - 16s 1s/step - d_loss: 235.8329 - g_loss: 1982.3837
# Epoch 1948/2000
# 2/2 [==============================] - 2s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 10.17
# 12/12 [==============================] - 16s 1s/step - d_loss: -23.3285 - g_loss: 1844.2394
# Epoch 1949/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 6.84
# 12/12 [==============================] - 14s 1s/step - d_loss: 240.6070 - g_loss: 2030.5822
# Epoch 1950/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 11.48
# 12/12 [==============================] - 15s 1s/step - d_loss: -94.9832 - g_loss: 1859.1626
# Epoch 1951/2000
# 2/2 [==============================] - 2s 32ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.84
# 12/12 [==============================] - 17s 1s/step - d_loss: 82.8794 - g_loss: 1683.6021
# Epoch 1952/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 9.2
# 12/12 [==============================] - 15s 1s/step - d_loss: 128.1736 - g_loss: 1323.8115
# Epoch 1953/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 10.95
# 12/12 [==============================] - 15s 1s/step - d_loss: 2.2563 - g_loss: 817.7399
# Epoch 1954/2000
# 2/2 [==============================] - 3s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 13.16
# 12/12 [==============================] - 16s 1s/step - d_loss: 164.1986 - g_loss: 377.4824
# Epoch 1955/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 9.65
# 12/12 [==============================] - 15s 1s/step - d_loss: -4.3146 - g_loss: 454.1385
# Epoch 1956/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 14.95
# 12/12 [==============================] - 15s 1s/step - d_loss: -45.0572 - g_loss: 296.6042
# Epoch 1957/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.15
# 12/12 [==============================] - 16s 1s/step - d_loss: -125.5750 - g_loss: 487.2278
# Epoch 1958/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 11.4
# 12/12 [==============================] - 15s 1s/step - d_loss: -111.2908 - g_loss: 417.8796
# Epoch 1959/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.39
# 12/12 [==============================] - 15s 1s/step - d_loss: 159.9842 - g_loss: 285.3641
# Epoch 1960/2000
# 2/2 [==============================] - 3s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 10.05
# 12/12 [==============================] - 16s 1s/step - d_loss: -85.1435 - g_loss: 28.7154
# Epoch 1961/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 10.34
# 12/12 [==============================] - 15s 1s/step - d_loss: -76.0760 - g_loss: -50.0549
# Epoch 1962/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.78
# 12/12 [==============================] - 15s 1s/step - d_loss: 13.2198 - g_loss: 23.8319
# Epoch 1963/2000
# 2/2 [==============================] - 2s 33ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 11.45
# 12/12 [==============================] - 14s 1s/step - d_loss: -52.1658 - g_loss: -81.5161
# Epoch 1964/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# FID SCORE: 12.71
# 12/12 [==============================] - 16s 1s/step - d_loss: -103.2450 - g_loss: -249.9289
# Epoch 1965/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.06
# 12/12 [==============================] - 15s 1s/step - d_loss: 16.3073 - g_loss: -142.6873
# Epoch 1966/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 7.97
# 12/12 [==============================] - 15s 1s/step - d_loss: -72.7374 - g_loss: -145.3521
# Epoch 1967/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 33ms/step
# FID SCORE: 17.67
# 12/12 [==============================] - 16s 1s/step - d_loss: -86.9963 - g_loss: -77.9056
# Epoch 1968/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 32ms/step
# FID SCORE: 10.95
# 12/12 [==============================] - 15s 1s/step - d_loss: -127.6670 - g_loss: -17.7375
# Epoch 1969/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 9.81
# 12/12 [==============================] - 15s 1s/step - d_loss: -109.6045 - g_loss: -39.5125
# Epoch 1970/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.11
# 12/12 [==============================] - 16s 1s/step - d_loss: -26.5266 - g_loss: -507.5051
# Epoch 1971/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 12.57
# 12/12 [==============================] - 16s 1s/step - d_loss: 159.2537 - g_loss: -629.7549
# Epoch 1972/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 7.96
# 12/12 [==============================] - 15s 1s/step - d_loss: -28.5373 - g_loss: -378.8685
# Epoch 1973/2000
# 2/2 [==============================] - 3s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 11.99
# 12/12 [==============================] - 15s 1s/step - d_loss: 50.1964 - g_loss: 11.6904
# Epoch 1974/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 12.04
# 12/12 [==============================] - 16s 1s/step - d_loss: -142.0905 - g_loss: -124.3376
# Epoch 1975/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# FID SCORE: 7.34
# 12/12 [==============================] - 15s 1s/step - d_loss: -8.3835 - g_loss: 25.8152
# Epoch 1976/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 9.82
# 12/12 [==============================] - 14s 1s/step - d_loss: -202.5584 - g_loss: 57.7268
# Epoch 1977/2000
# 2/2 [==============================] - 2s 35ms/step
# 2/2 [==============================] - 0s 30ms/step
# FID SCORE: 7.79
# 12/12 [==============================] - 16s 1s/step - d_loss: -26.9264 - g_loss: 327.7869
# Epoch 1978/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 7.57
# 12/12 [==============================] - 15s 1s/step - d_loss: 53.5503 - g_loss: 284.1202
# Epoch 1979/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 11.33
# 12/12 [==============================] - 14s 1s/step - d_loss: 105.9910 - g_loss: 31.6178
# Epoch 1980/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.13
# 12/12 [==============================] - 16s 1s/step - d_loss: 29.8794 - g_loss: 101.8810
# Epoch 1981/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 15.09
# 12/12 [==============================] - 15s 1s/step - d_loss: -254.0831 - g_loss: 110.5345
# Epoch 1982/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 7.62
# 12/12 [==============================] - 14s 1s/step - d_loss: -57.8766 - g_loss: -233.0281
# Epoch 1983/2000
# 2/2 [==============================] - 3s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.77
# 12/12 [==============================] - 16s 1s/step - d_loss: -87.5181 - g_loss: -807.0675
# Epoch 1984/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 10.69
# 12/12 [==============================] - 16s 1s/step - d_loss: 175.4127 - g_loss: 124.7346
# Epoch 1985/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.94
# 12/12 [==============================] - 15s 1s/step - d_loss: 24.5823 - g_loss: 84.0641
# Epoch 1986/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 10.84
# 12/12 [==============================] - 14s 1s/step - d_loss: 8.4065 - g_loss: 19.3741
# Epoch 1987/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.12
# 12/12 [==============================] - 16s 1s/step - d_loss: -13.8771 - g_loss: 257.3682
# Epoch 1988/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# FID SCORE: 10.74
# 12/12 [==============================] - 15s 1s/step - d_loss: -27.5321 - g_loss: 151.0686
# Epoch 1989/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 12.88
# 12/12 [==============================] - 14s 1s/step - d_loss: -119.0453 - g_loss: 177.4939
# Epoch 1990/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 32ms/step
# FID SCORE: 8.21
# 12/12 [==============================] - 16s 1s/step - d_loss: 57.5857 - g_loss: 49.9015
# Epoch 1991/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 8.98
# 12/12 [==============================] - 15s 1s/step - d_loss: -66.9461 - g_loss: 306.3775
# Epoch 1992/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 32ms/step
# FID SCORE: 10.1
# 12/12 [==============================] - 15s 1s/step - d_loss: -330.3963 - g_loss: 338.1935
# Epoch 1993/2000
# 2/2 [==============================] - 3s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 12.65
# 12/12 [==============================] - 16s 1s/step - d_loss: 142.0649 - g_loss: 693.7609
# Epoch 1994/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# FID SCORE: 8.62
# 12/12 [==============================] - 15s 1s/step - d_loss: -218.2988 - g_loss: 511.7928
# Epoch 1995/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 10.73
# 12/12 [==============================] - 15s 1s/step - d_loss: 53.8408 - g_loss: 1070.2552
# Epoch 1996/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 17.06
# 12/12 [==============================] - 14s 1s/step - d_loss: 20.0042 - g_loss: 923.8536
# Epoch 1997/2000
# 2/2 [==============================] - 2s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 11.34
# 12/12 [==============================] - 16s 1s/step - d_loss: 81.8665 - g_loss: 350.1456
# Epoch 1998/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# FID SCORE: 10.96
# 12/12 [==============================] - 15s 1s/step - d_loss: 45.5840 - g_loss: 46.4032
# Epoch 1999/2000
# 2/2 [==============================] - 2s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 7.21
# 12/12 [==============================] - 15s 1s/step - d_loss: 90.0978 - g_loss: 271.0118
# Epoch 2000/2000
# 2/2 [==============================] - 2s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# FID SCORE: 11.43
# 12/12 [==============================] - 16s 1s/step - d_loss: -321.0168 - g_loss: 12.8586
# CPU times: user 16h 47min 45s, sys: 20h 18min 29s, total: 1d 13h 6min 14s
# Wall time: 7h 53min 15s

# %%
min(fid_scores)
# Out:
# 4.05

# %%
rounded_fid_scores = [np.round(i) for i in fid_scores]
min_fid = min(rounded_fid_scores)
latest_epoch_for_min_fid = 1 + max([epoch for epoch,fid_score in enumerate(rounded_fid_scores) if fid_score == min_fid])
print(latest_epoch_for_min_fid)
# Out:
# 1664

# %%
# take best generator and plot 64 images with it
best_generator = tf.keras.models.load_model("MI_gen_1664_(4.05).h5")
random_latent_vectors = tf.random.normal(shape=(BATCH_SIZE, noise_dim))
generated_batch = best_generator(random_latent_vectors)
synthetic_images = generated_batch.numpy()
WGAN_CALLBACK().plot_multiple_images(synthetic_images, 8)                    
plt.show()

# %%
# Plotting fid scores corresponding to each epoch
plt.figure(figsize = (30,5))
plt.plot(fid_scores[1600:1900], linewidth = 3, linestyle = '-', marker = 'o', markersize = 10, markerfacecolor='red', label = "FID_SCORE", color = 'k')
plt.axhline(y = min(fid_scores), color = 'green', linestyle = '--', label = 'minimum fid score')
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("FID_SCORE", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(fid_scores[1600:1900])),np.arange(1600,len(fid_scores[1600:1900])+1600),rotation=90)
plt.legend()
plt.title("FID SCORES FOR EACH EPOCH", fontsize = 20, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### **PLOTTING GENERATOR VS DISCRIMINATOR LOSSES**

# %%
plt.figure(figsize = (30,5))
plt.plot(wgan_history.history['g_loss'][1600:1900], linewidth = 3, marker = 'o', markersize = 10, markerfacecolor='k',label = "Generator's Loss")
plt.plot(wgan_history.history['d_loss'][1600:1900], linewidth = 3, marker = '*', markersize = 10, markerfacecolor='k',label = "Discriminator's Loss")
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("LOSS", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(wgan_history.history['g_loss'][1600:1900])),np.arange(1600,len(wgan_history.history['g_loss'])+1600),rotation=90)
plt.legend()
plt.title("GENERATOR VS DISCRIMINATOR LOSS", fontsize = 20, fontweight = 'bold')
plt.show()
