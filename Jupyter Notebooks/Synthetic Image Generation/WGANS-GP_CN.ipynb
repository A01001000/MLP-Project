# %% [markdown]
# # **WGANS WITH GRADIENT PENALTY FOR SYNTHESIZING ALZHEIMER'S MRI**

# %% [markdown]
# ### **IMPORTING THE NECESSARY DEPENDENCIES**

# %%
import os
import cv2
import random
import shutil
import warnings
import numpy as np
import seaborn as sns
from tqdm import tqdm
from numpy import cov
from PIL import Image
from numpy import trace
import tensorflow as tf
from numpy import asarray
from tensorflow import keras
from scipy.linalg import sqrtm
from numpy import iscomplexobj
import matplotlib.pyplot as plt
from numpy.random import randint
warnings.filterwarnings("ignore")
from tensorflow.keras import layers
from skimage.transform import resize
from IPython.display import FileLink
from keras.datasets.mnist import load_data
from keras.applications.inception_v3 import InceptionV3
from skimage.metrics import structural_similarity as ssim
from keras.applications.inception_v3 import preprocess_input
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# ### **DECLARING PATHS AND VARIABLES**

# %%
tf.random.set_seed(5638)
random.seed(5638)

# %%
working_directory = '/synthetic/'
os.makedirs(working_directory, exist_ok=True)
dataset_path = '/raw_adni/final_preprocessed2/train/'
class_name = 'CN'

noise_dim = 256
IMG_SHAPE = (128, 128, 1)
BATCH_SIZE = 64

# %% [markdown]
# ### **PREPARING THE DATASET**

# %%
def prepare_dataset(class_name):
    # Path to the class where the real images are; in the orignal dataset
    class_path = dataset_path + class_name + '/'
    images = [cv2.imread(class_path + image_name, cv2.COLOR_BGR2GRAY) for image_name in os.listdir(class_path)]
    resized_images = np.array([cv2.resize(i, (IMG_SHAPE[0],IMG_SHAPE[1])) for i in images]).astype(np.float32)
    # Reshape each sample to (128, 128, 1) and normalize the pixel values in the [-1, 1] range
    reshaped_images = resized_images.reshape(resized_images.shape[0], *IMG_SHAPE)
    dataset = (reshaped_images - 127.5) / 127.5
    return dataset

train_images = prepare_dataset(class_name)

# %%
def conv_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding="same",
    use_bias=True,
    use_bn=False,
    use_dropout=False,
    drop_value=0.5
    ):

    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

def upsample_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    up_size=(2, 2),
    padding="same",
    use_bn=False,
    use_bias=True,
    use_dropout=False,
    drop_value=0.3
    ):

    x = layers.UpSampling2D(up_size)(x)
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    if activation:
        x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

# %% [markdown]
# ### **CREATE THE DISCRIMINATOR** (the critic in the original WGAN)

# %%
def get_discriminator_model():
    # input = 128 x 128, output = 64 x 64 
    img_input = layers.Input(shape=IMG_SHAPE)
    x = conv_block(
        img_input,
        32,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=False,
        drop_value=0.3
        )
    
    # input = 64 x 64, output = 32 x 32
    x = conv_block(
        x,
        64,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 32 x 32, output = 16 x 16
    x = conv_block(
        x,
        128,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 16 x 16, output = 8 x 8
    x = conv_block(
        x,
        256,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 8 x 8, output = 4 x 4
    x = conv_block(
        x,
        512,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 4 x 4, output = 1 
    x = layers.Flatten()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(1)(x)

    d_model = keras.models.Model(img_input, x, name="discriminator")
    return d_model

d_model = get_discriminator_model()
tf.keras.utils.plot_model(d_model, to_file='discriminator.jpg', show_shapes=True, rankdir='TB')

# %%
FileLink(r'discriminator.jpg')
# Out:
# /content/discriminator.jpg

# %% [markdown]
# ### **CREATE THE GENERATOR**

# %%
def get_generator_model():
    # input = (noise_dim, ), output = 4 x 4
    noise = layers.Input(shape=(noise_dim,))
    x = layers.Dense(4 * 4 * 2048, use_bias=False)(noise)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Reshape((4, 4, 2048))(x)
    
    # input = 4 x 4, output = 8 x 8
    x = upsample_block(
        x,
        1024,
        layers.LeakyReLU(0.2),
        kernel_size =(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 8 x 8, output = 16 x 16
    x = upsample_block(
        x,
        512,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 16 x 16, output = 32 x 32
    x = upsample_block(
        x,
        256,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 32 x 32, output = 64 x 64
    x = upsample_block(
        x,
        128,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 64 x 64, output = 128 x 128
    x = upsample_block(x, 1, layers.Activation("tanh"), strides=(1, 1), use_bias=False, use_bn=True)
    
    g_model = keras.models.Model(noise, x, name="generator")
    return g_model


g_model = get_generator_model()
tf.keras.utils.plot_model(g_model, to_file='generator.jpg', show_shapes=True, rankdir='TB')

# %%
FileLink('generator.jpg')
# Out:
# /content/generator.jpg

# %% [markdown]
# ### **CREATE THE WGAN-GP MODEL**
#
# Now that we have defined our generator and discriminator, it's time to implement the WGAN-GP model. We will also override the train_step for training.

# %%
class WGAN(keras.Model):
    def __init__(
        self,
        discriminator,
        generator,
        latent_dim,
        discriminator_extra_steps=5,
        gp_weight=10.0,
    ):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.d_steps = discriminator_extra_steps
        self.gp_weight = gp_weight

    def compile(self, d_optimizer, g_optimizer, d_loss_fn, g_loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss_fn = d_loss_fn
        self.g_loss_fn = g_loss_fn 

    def gradient_penalty(self, batch_size, real_images, fake_images):
        """Calculates the gradient penalty.

        This loss is calculated on an interpolated image
        and added to the discriminator loss.
        """
        # Get the interpolated image
        alpha = tf.random.normal([batch_size, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            # 1. Get the discriminator output for this interpolated image.
            pred = self.discriminator(interpolated, training=True)

        # 2. Calculate the gradients w.r.t to this interpolated image.
        grads = gp_tape.gradient(pred, [interpolated])[0]
        # 3. Calculate the norm of the gradients.
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        if isinstance(real_images, tuple):
            real_images = real_images[0]

        # Get the batch size
        batch_size = tf.shape(real_images)[0]

        # For each batch, we are going to perform the
        # following steps as laid out in the original paper:
        # 1. Train the generator and get the generator loss
        # 2. Train the discriminator and get the discriminator loss
        # 3. Calculate the gradient penalty
        # 4. Multiply this gradient penalty with a constant weight factor
        # 5. Add the gradient penalty to the discriminator loss
        # 6. Return the generator and discriminator losses as a loss dictionary

        # Train the discriminator first. 
        for i in range(self.d_steps):
            # Get the latent vector
            random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
            with tf.GradientTape() as tape:
                # Generate fake images from the latent vector
                fake_images = self.generator(random_latent_vectors, training=True)
                # Get the logits for the fake images
                fake_logits = self.discriminator(fake_images, training=True)
                # Get the logits for the real images
                real_logits = self.discriminator(real_images, training=True)

                # Calculate the discriminator loss using the fake and real image logits
                d_cost = self.d_loss_fn(real_img=real_logits, fake_img=fake_logits)
                # Calculate the gradient penalty
                gp = self.gradient_penalty(batch_size, real_images, fake_images)
                # Add the gradient penalty to the original discriminator loss
                d_loss = d_cost + gp * self.gp_weight

            # Get the gradients w.r.t the discriminator loss
            d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
            # Update the weights of the discriminator using the discriminator optimizer
            self.d_optimizer.apply_gradients(
                zip(d_gradient, self.discriminator.trainable_variables)
            )

        # Train the generator
        # Get the latent vector
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        with tf.GradientTape() as tape:
            # Generate fake images using the generator
            generated_images = self.generator(random_latent_vectors, training=True)
            # Get the discriminator logits for fake images
            gen_img_logits = self.discriminator(generated_images, training=True)
            # Calculate the generator loss
            g_loss = self.g_loss_fn(gen_img_logits)

        # Get the gradients w.r.t the generator loss
        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        # Update the weights of the generator using the generator optimizer
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )

        return {"d_loss": d_loss, "g_loss": g_loss}

# %% [markdown]
# ### **CREATE A CUSTOM CALLBACK**

# %%
class WGAN_CALLBACK(keras.callbacks.Callback):
    def __init__(self, n_epochs = 20, batch_size = BATCH_SIZE, latent_vector_dim = 128):
        self.batch_size = batch_size
        self.noise_dim = latent_vector_dim
        self.fid_scores = []
        self.n_epochs = n_epochs
        
    @property
    def get_fid_scores(self):
        return self.fid_scores
    
    def plot_multiple_images(self,images, n_cols):
        n_cols = n_cols or len(images)
        n_rows = len(images) // n_cols
        if images.shape[-1] == 1:
            images = np.squeeze(images, axis=-1)
        plt.figure(figsize=(n_cols, n_rows))   
        plt.tight_layout()
        plt.suptitle('BEST GENERATOR', fontweight = 'bold')
        for index, image in enumerate(images):
            plt.subplot(n_rows, n_cols, index + 1)
            plt.imshow(image, cmap="gray")
            plt.axis("off")
    
    def calculate_fid(self, generated_images, real_images):
        # scale an array of images to a new size
        def scale_images(images, new_shape):
            images_list = []
            for image in images:
                # resize with nearest neighbor interpolation
                resized_image = cv2.cvtColor(cv2.resize(image, new_shape, cv2.INTER_NEAREST), cv2.COLOR_GRAY2BGR)
                # store the resized images
                images_list.append(resized_image)
            return asarray(images_list)
        # prepare the inception v3 model
        model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))
        # resize images
        generated_images = scale_images(generated_images, (299,299))
        real_images = scale_images(real_images, (299,299))
        # pre-process images
        generated_images = preprocess_input(generated_images)
        real_images = preprocess_input(real_images)
        # calculate feature embeddings
        embeddings1 = model.predict(generated_images)
        embeddings2 = model.predict(real_images)
        # calculate mean and covariance statistics
        mu1, sigma1 = embeddings1.mean(axis=0), cov(embeddings1, rowvar=False)
        mu2, sigma2 = embeddings2.mean(axis=0), cov(embeddings2, rowvar=False)
        # calculate sum squared difference between means
        ssdiff = np.sum((mu1 - mu2)**2.0)
        # calculate sqrt of product between cov
        covmean = sqrtm(sigma1.dot(sigma2))
        # check and correct imaginary numbers from sqrt
        if iscomplexobj(covmean):
            covmean = covmean.real
        # calculate fid score
        fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
        return np.round(fid,2)

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.batch_size, self.noise_dim))
        generator = self.model.generator
        generated_batch = generator(random_latent_vectors)
        generated_batch = generated_batch.numpy()
        random_number = np.random.randint(train_images.shape[0] - self.batch_size)
        real_batch = train_images[random_number: random_number + self.batch_size]
        current_fid = self.calculate_fid(generated_batch, real_batch)
        self.fid_scores.append(current_fid)  
        print('\033[1mFID SCORE: {}\033[0m'.format(current_fid))
        
        if current_fid < 5:
          generator.save(working_directory + "VMI_gen_{}_({}).h5".format(epoch+1,current_fid),save_format='h5')

# %%
def clear_workspace():
    for filename in os.listdir(working_directory):
        file_path = os.path.join(working_directory, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
def download_synthetic_images(generator, number_of_images, class_name = 'None'):
    clear_workspace()
    # Making sure that no two images have the same name
    counter = 1
    # To check if folder is full
    folder_full = False
    # Folder path to store synthetic images. Folder name is the same as the class name which is inside the working directory
    folder_path = working_directory + 'synthetic_' + class_name + '/'
    images_folder = os.path.join(folder_path)
    # Create this folder if it doesn't exists, otherwise do nothing
    os.makedirs(images_folder, exist_ok=True)
    # Unless I get the desired number of good quality synthetic images in this folder, keep on generating images
    pbar = tqdm(total=number_of_images, position=0, leave=True)
    while len(os.listdir(images_folder)) < number_of_images:
        # Generate a batch of synthetic images
        random_latent_vectors = tf.random.normal(shape=(BATCH_SIZE, noise_dim))
        synthetic_images_batch = generator(random_latent_vectors)
        # Convert tensors to numpy arrays 
        synthetic_images_batch = synthetic_images_batch.numpy()
        # Convert the scale of images from (-1,1) to (0,255) and data type from float to integers 
        for image in synthetic_images_batch:
            image = (image * 127.5) + 127.5
            image = image.astype(np.uint8)
            # If it is a single channel image then save it as it is
            if image.shape[2] == 1:
                cv2.imwrite(images_folder + class_name + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If it is a 3 channel image then first convert it to grayscale and then save it
            elif image.shape[2] == 3:
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                cv2.imwrite(images_folder + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If the folder now has the number of desired images, then come out of the loop
            if len(os.listdir(images_folder)) >= number_of_images:
                folder_full = True
                break
        if folder_full == True:
                break
            
    # Generate a link from where I can download the synthetic images
    os.system('zip -r synthetic_images.zip {} >/dev/null 2>&1'.format(folder_path))
    return FileLink(r'synthetic_images.zip')

# %% [markdown]
# ### **TRAIN THE END TO END MODEL**

# %%
def train_wgans(dataset, n_epochs, batch_size = BATCH_SIZE, optimizer = 'adam', gen_lr = 0.0001, dis_lr = 0.0001):
    clear_workspace()
    assert optimizer in ['adam','rmsprop', 'nadam'], "Invalid optimizer. Valid options are 'adam' or 'rmsprop' or 'nadam'."
    if optimizer == 'adam':
        generator_optimizer = keras.optimizers.Adam(learning_rate = gen_lr, beta_1=0, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Adam(learning_rate = dis_lr, beta_1=0, beta_2=0.9)
    elif optimizer == 'rmsprop':
        generator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = gen_lr)
        discriminator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = dis_lr)
    elif optimizer == 'nadam':
        generator_optimizer = keras.optimizers.Nadam(learning_rate = gen_lr, beta_1=0.5, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Nadam(learning_rate = dis_lr, beta_1=0.5, beta_2=0.9)

    # Define the loss functions for the discriminator,
    # which should be (fake_loss - real_loss).
    # We will add the gradient penalty later to this loss function.
    def discriminator_loss(real_img, fake_img):
        real_loss = tf.reduce_mean(real_img)
        fake_loss = tf.reduce_mean(fake_img)
        return fake_loss - real_loss

    # Define the loss functions for the generator.
    def generator_loss(fake_img):
        return -tf.reduce_mean(fake_img)

    # Instantiate the customer `WGAN_CALLBACK` Keras callback.
    custom_callback = WGAN_CALLBACK(n_epochs, batch_size = BATCH_SIZE, latent_vector_dim = noise_dim)

    # Get the wgan model
    wgan = WGAN(discriminator = d_model, generator = g_model, latent_dim = noise_dim, discriminator_extra_steps=5)

    # Compile the wgan model
    wgan.compile(
        d_optimizer = discriminator_optimizer,
        g_optimizer = generator_optimizer,
        g_loss_fn = generator_loss,
        d_loss_fn = discriminator_loss
    )

    # Start training
    wgan_history = wgan.fit(dataset, batch_size = BATCH_SIZE, epochs = n_epochs, callbacks=[custom_callback])
    fid_scores = custom_callback.get_fid_scores
    return wgan_history, fid_scores

# %%
# %%time
wgan_history, fid_scores = train_wgans(dataset = train_images, 
                                        n_epochs = 2000, 
                                        batch_size = BATCH_SIZE, 
                                        optimizer = 'adam', 
                                        gen_lr = 0.0001, 
                                        dis_lr = 0.0001)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 66.02
# 28/28 [==============================] - 10s 373ms/step - d_loss: 861.7760 - g_loss: 947.3217
# Epoch 1002/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 62.72
# 28/28 [==============================] - 11s 390ms/step - d_loss: -189.7438 - g_loss: 626.4262
# Epoch 1003/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 76.83
# 28/28 [==============================] - 10s 383ms/step - d_loss: 56.5244 - g_loss: 1947.1200
# Epoch 1004/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 72.03
# 28/28 [==============================] - 10s 379ms/step - d_loss: 156.6838 - g_loss: 1102.9144
# Epoch 1005/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 44.12
# 28/28 [==============================] - 10s 384ms/step - d_loss: 476.2664 - g_loss: 1065.0208
# Epoch 1006/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 32.03
# 28/28 [==============================] - 10s 374ms/step - d_loss: -207.5433 - g_loss: 723.9324
# Epoch 1007/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 48.95
# 28/28 [==============================] - 10s 381ms/step - d_loss: -552.7171 - g_loss: 586.9496
# Epoch 1008/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 77.19
# 28/28 [==============================] - 11s 390ms/step - d_loss: 108.1365 - g_loss: 208.7695
# Epoch 1009/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 40.79
# 28/28 [==============================] - 10s 378ms/step - d_loss: -419.9213 - g_loss: -257.9156
# Epoch 1010/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 51.39
# 28/28 [==============================] - 10s 383ms/step - d_loss: -381.5023 - g_loss: -335.8694
# Epoch 1011/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 47.12
# 28/28 [==============================] - 10s 382ms/step - d_loss: -931.0767 - g_loss: -616.2458
# Epoch 1012/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 69.44
# 28/28 [==============================] - 10s 384ms/step - d_loss: -157.6787 - g_loss: -1233.2369
# Epoch 1013/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 76.15
# 28/28 [==============================] - 10s 380ms/step - d_loss: -1385.0997 - g_loss: -3003.9979
# Epoch 1014/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 41.18
# 28/28 [==============================] - 11s 396ms/step - d_loss: 2075.2547 - g_loss: -173.5719
# Epoch 1015/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 47.6
# 28/28 [==============================] - 10s 381ms/step - d_loss: 221.2235 - g_loss: -2520.5518
# Epoch 1016/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 54.83
# 28/28 [==============================] - 11s 392ms/step - d_loss: -6.0602 - g_loss: -454.4997
# Epoch 1017/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 41.34
# 28/28 [==============================] - 10s 368ms/step - d_loss: -1262.5510 - g_loss: -1188.3735
# Epoch 1018/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 91.13
# 28/28 [==============================] - 11s 390ms/step - d_loss: -2218.4233 - g_loss: 1968.3820
# Epoch 1019/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 67.12
# 28/28 [==============================] - 10s 375ms/step - d_loss: -37.1096 - g_loss: 383.4039
# Epoch 1020/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 48.04
# 28/28 [==============================] - 11s 385ms/step - d_loss: 497.6225 - g_loss: 1132.6851
# Epoch 1021/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 70.03
# 28/28 [==============================] - 10s 374ms/step - d_loss: -1707.9309 - g_loss: -1828.9222
# Epoch 1022/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 59.93
# 28/28 [==============================] - 11s 386ms/step - d_loss: -1152.8790 - g_loss: 757.5358
# Epoch 1023/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 70.36
# 28/28 [==============================] - 11s 390ms/step - d_loss: -494.0614 - g_loss: 2217.4962
# Epoch 1024/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 33ms/step
# FID SCORE: 58.1
# 28/28 [==============================] - 10s 377ms/step - d_loss: -2222.7139 - g_loss: 1264.0621
# Epoch 1025/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 53.58
# 28/28 [==============================] - 10s 370ms/step - d_loss: -1494.8487 - g_loss: 238.9376
# Epoch 1026/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 47.84
# 28/28 [==============================] - 11s 396ms/step - d_loss: 1916.3135 - g_loss: 2.2774
# Epoch 1027/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 76.71
# 28/28 [==============================] - 10s 382ms/step - d_loss: 295.0850 - g_loss: -809.8242
# Epoch 1028/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 46.59
# 28/28 [==============================] - 11s 389ms/step - d_loss: 573.0927 - g_loss: 648.8758
# Epoch 1029/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 56.25
# 28/28 [==============================] - 10s 381ms/step - d_loss: 765.2797 - g_loss: 762.1357
# Epoch 1030/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 35.86
# 28/28 [==============================] - 10s 371ms/step - d_loss: 1186.3515 - g_loss: 1639.0740
# Epoch 1031/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 94.77
# 28/28 [==============================] - 10s 372ms/step - d_loss: -316.6893 - g_loss: 2014.3167
# Epoch 1032/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 50.53
# 28/28 [==============================] - 10s 383ms/step - d_loss: 1175.7630 - g_loss: 2080.7153
# Epoch 1033/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 39.84
# 28/28 [==============================] - 10s 383ms/step - d_loss: -480.8656 - g_loss: -86.9087
# Epoch 1034/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 73.44
# 28/28 [==============================] - 10s 384ms/step - d_loss: 783.5648 - g_loss: -948.1167
# Epoch 1035/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 43.47
# 28/28 [==============================] - 10s 370ms/step - d_loss: 318.9245 - g_loss: -1785.3841
# Epoch 1036/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 71.67
# 28/28 [==============================] - 10s 372ms/step - d_loss: -667.2645 - g_loss: -1803.9461
# Epoch 1037/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 39.62
# 28/28 [==============================] - 10s 380ms/step - d_loss: 1357.0928 - g_loss: -1060.2812
# Epoch 1038/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 55.48
# 28/28 [==============================] - 11s 392ms/step - d_loss: -1137.0742 - g_loss: -3544.2090
# Epoch 1039/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 57.72
# 28/28 [==============================] - 10s 368ms/step - d_loss: 598.3430 - g_loss: -6572.9760
# Epoch 1040/2000
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 68.06
# 28/28 [==============================] - 11s 392ms/step - d_loss: 1113.9901 - g_loss: -4557.6059
# Epoch 1041/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 67.8
# 28/28 [==============================] - 10s 377ms/step - d_loss: -436.4407 - g_loss: -2357.6136
# Epoch 1042/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 74.72
# 28/28 [==============================] - 10s 381ms/step - d_loss: -345.5382 - g_loss: -611.1588
# Epoch 1043/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 66.26
# 28/28 [==============================] - 10s 370ms/step - d_loss: 162.3211 - g_loss: -849.2814
# Epoch 1044/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 38.97
# 28/28 [==============================] - 11s 387ms/step - d_loss: -250.6521 - g_loss: -645.3876
# Epoch 1045/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 42.66
# 28/28 [==============================] - 10s 373ms/step - d_loss: -266.2280 - g_loss: -457.9792
# Epoch 1046/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 51.07
# 28/28 [==============================] - 11s 388ms/step - d_loss: -314.6220 - g_loss: -1288.4313
# Epoch 1047/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 85.75
# 28/28 [==============================] - 10s 375ms/step - d_loss: -169.5791 - g_loss: -1067.1676
# Epoch 1048/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 57.91
# 28/28 [==============================] - 10s 373ms/step - d_loss: 74.8717 - g_loss: -806.4593
# Epoch 1049/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 42.52
# 28/28 [==============================] - 10s 373ms/step - d_loss: -733.2216 - g_loss: -445.3584
# Epoch 1050/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 37.93
# 28/28 [==============================] - 11s 390ms/step - d_loss: 928.1516 - g_loss: -3300.5222
# Epoch 1051/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 56.27
# 28/28 [==============================] - 10s 383ms/step - d_loss: 675.1070 - g_loss: -3541.5681
# Epoch 1052/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 62.48
# 28/28 [==============================] - 10s 384ms/step - d_loss: -339.7299 - g_loss: -4792.0931
# Epoch 1053/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 65.38
# 28/28 [==============================] - 10s 378ms/step - d_loss: -2267.1661 - g_loss: -6665.5287
# Epoch 1054/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 69.1
# 28/28 [==============================] - 10s 383ms/step - d_loss: 2162.6177 - g_loss: -6072.6499
# Epoch 1055/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 66.73
# 28/28 [==============================] - 10s 381ms/step - d_loss: 1348.0334 - g_loss: -3697.6673
# Epoch 1056/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 73.85
# 28/28 [==============================] - 11s 395ms/step - d_loss: -292.7482 - g_loss: -3294.1863
# Epoch 1057/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 36.68
# 28/28 [==============================] - 10s 376ms/step - d_loss: 131.6234 - g_loss: -4919.6703
# Epoch 1058/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 43.65
# 28/28 [==============================] - 10s 384ms/step - d_loss: 442.1689 - g_loss: -3219.1287
# Epoch 1059/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 49.21
# 28/28 [==============================] - 10s 383ms/step - d_loss: 881.1018 - g_loss: -3200.0464
# Epoch 1060/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 63.34
# 28/28 [==============================] - 10s 373ms/step - d_loss: 187.7023 - g_loss: -1865.3854
# Epoch 1061/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 52.11
# 28/28 [==============================] - 10s 378ms/step - d_loss: 83.6022 - g_loss: -896.7524
# Epoch 1062/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 82.2
# 28/28 [==============================] - 11s 388ms/step - d_loss: 155.1738 - g_loss: -544.7671
# Epoch 1063/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 64.9
# 28/28 [==============================] - 10s 372ms/step - d_loss: -224.6216 - g_loss: -983.8590
# Epoch 1064/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 58.06
# 28/28 [==============================] - 11s 386ms/step - d_loss: -51.2865 - g_loss: -1792.8443
# Epoch 1065/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 54.58
# 28/28 [==============================] - 10s 380ms/step - d_loss: -137.0972 - g_loss: -1732.8643
# Epoch 1066/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 34.0
# 28/28 [==============================] - 10s 376ms/step - d_loss: 801.7643 - g_loss: -2064.1104
# Epoch 1067/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 50.5
# 28/28 [==============================] - 10s 378ms/step - d_loss: 331.1591 - g_loss: -2171.3248
# Epoch 1068/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 27.15
# 28/28 [==============================] - 11s 388ms/step - d_loss: -446.6943 - g_loss: -2459.1444
# Epoch 1069/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 38.18
# 28/28 [==============================] - 10s 366ms/step - d_loss: 337.9977 - g_loss: -1646.1425
# Epoch 1070/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 27.58
# 28/28 [==============================] - 10s 384ms/step - d_loss: 422.6137 - g_loss: -1040.8014
# Epoch 1071/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 35.25
# 28/28 [==============================] - 10s 378ms/step - d_loss: -333.2950 - g_loss: -1058.9633
# Epoch 1072/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 46.94
# 28/28 [==============================] - 10s 383ms/step - d_loss: -289.8910 - g_loss: -1535.5118
# Epoch 1073/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 32.0
# 28/28 [==============================] - 10s 375ms/step - d_loss: -65.6969 - g_loss: -1301.2763
# Epoch 1074/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 53.0
# 28/28 [==============================] - 11s 392ms/step - d_loss: 214.0734 - g_loss: -1468.5617
# Epoch 1075/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 54.16
# 28/28 [==============================] - 10s 379ms/step - d_loss: 524.5105 - g_loss: -1053.2801
# Epoch 1076/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 36.68
# 28/28 [==============================] - 11s 386ms/step - d_loss: 112.5359 - g_loss: -1221.1523
# Epoch 1077/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 29.29
# 28/28 [==============================] - 10s 373ms/step - d_loss: 86.7493 - g_loss: 87.4529
# Epoch 1078/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 55.33
# 28/28 [==============================] - 10s 379ms/step - d_loss: -434.9637 - g_loss: -937.9620
# Epoch 1079/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 50.46
# 28/28 [==============================] - 10s 375ms/step - d_loss: -1156.5518 - g_loss: -812.7562
# Epoch 1080/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 64.76
# 28/28 [==============================] - 11s 391ms/step - d_loss: 942.1178 - g_loss: -206.5854
# Epoch 1081/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 36.16
# 28/28 [==============================] - 10s 371ms/step - d_loss: 905.5684 - g_loss: 2476.7875
# Epoch 1082/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 47.81
# 28/28 [==============================] - 10s 378ms/step - d_loss: -407.2209 - g_loss: 5071.0626
# Epoch 1083/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 63.63
# 28/28 [==============================] - 10s 370ms/step - d_loss: 2043.0904 - g_loss: 6212.0687
# Epoch 1084/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 51.85
# 28/28 [==============================] - 10s 374ms/step - d_loss: -3476.0586 - g_loss: 4210.3992
# Epoch 1085/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 45.2
# 28/28 [==============================] - 10s 376ms/step - d_loss: -992.2271 - g_loss: 1067.0700
# Epoch 1086/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 60.08
# 28/28 [==============================] - 11s 393ms/step - d_loss: -344.7983 - g_loss: -1720.4170
# Epoch 1087/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 39.49
# 28/28 [==============================] - 10s 376ms/step - d_loss: 8351.5019 - g_loss: -2175.4542
# Epoch 1088/2000
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 53.13
# 28/28 [==============================] - 11s 392ms/step - d_loss: 4510.4893 - g_loss: 2896.8019
# Epoch 1089/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 70.94
# 28/28 [==============================] - 10s 383ms/step - d_loss: -7832.9387 - g_loss: 1224.8427
# Epoch 1090/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 87.3
# 28/28 [==============================] - 10s 379ms/step - d_loss: -4223.5198 - g_loss: 1757.4882
# Epoch 1091/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 78.86
# 28/28 [==============================] - 10s 373ms/step - d_loss: 1931.5981 - g_loss: -2937.4969
# Epoch 1092/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 55.98
# 28/28 [==============================] - 11s 397ms/step - d_loss: -1797.2528 - g_loss: -4205.0284
# Epoch 1093/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 72.89
# 28/28 [==============================] - 10s 382ms/step - d_loss: 752.1954 - g_loss: -11492.8550
# Epoch 1094/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 41.15
# 28/28 [==============================] - 11s 394ms/step - d_loss: 4873.6687 - g_loss: -4481.2228
# Epoch 1095/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 50.95
# 28/28 [==============================] - 10s 374ms/step - d_loss: 4257.2427 - g_loss: -4925.6750
# Epoch 1096/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 87.08
# 28/28 [==============================] - 10s 375ms/step - d_loss: -2164.7342 - g_loss: -76.6726
# Epoch 1097/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 60.34
# 28/28 [==============================] - 10s 373ms/step - d_loss: 1676.2750 - g_loss: 443.4155
# Epoch 1098/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 69.15
# 28/28 [==============================] - 11s 388ms/step - d_loss: -1845.1819 - g_loss: 3613.5036
# Epoch 1099/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 77.59
# 28/28 [==============================] - 10s 383ms/step - d_loss: -2808.2207 - g_loss: 5812.2827
# Epoch 1100/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 34ms/step
# FID SCORE: 77.4
# 28/28 [==============================] - 11s 390ms/step - d_loss: -4322.7862 - g_loss: 2242.1039
# Epoch 1101/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 143.05
# 28/28 [==============================] - 10s 382ms/step - d_loss: -3685.3241 - g_loss: 1996.2677
# Epoch 1102/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 94.55
# 28/28 [==============================] - 10s 378ms/step - d_loss: -4047.9102 - g_loss: 1316.5038
# Epoch 1103/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 132.06
# 28/28 [==============================] - 10s 373ms/step - d_loss: 1658.6297 - g_loss: 5137.9718
# Epoch 1104/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 92.35
# 28/28 [==============================] - 11s 387ms/step - d_loss: -1752.5629 - g_loss: 255.5895
# Epoch 1105/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 96.36
# 28/28 [==============================] - 10s 371ms/step - d_loss: -792.1568 - g_loss: -2400.1767
# Epoch 1106/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 86.19
# 28/28 [==============================] - 10s 383ms/step - d_loss: 182.4246 - g_loss: -4689.4790
# Epoch 1107/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 77.18
# 28/28 [==============================] - 10s 374ms/step - d_loss: -3808.6876 - g_loss: -6383.0542
# Epoch 1108/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 85.69
# 28/28 [==============================] - 10s 367ms/step - d_loss: -2443.7037 - g_loss: 8259.5848
# Epoch 1109/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 74.1
# 28/28 [==============================] - 10s 374ms/step - d_loss: 6363.6874 - g_loss: -2524.2024
# Epoch 1110/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 93.02
# 28/28 [==============================] - 11s 388ms/step - d_loss: -4009.9395 - g_loss: 2377.4240
# Epoch 1111/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 101.35
# 28/28 [==============================] - 10s 376ms/step - d_loss: 6325.5650 - g_loss: -4194.3268
# Epoch 1112/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 90.3
# 28/28 [==============================] - 11s 388ms/step - d_loss: 7160.6344 - g_loss: -1023.3377
# Epoch 1113/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 133.24
# 28/28 [==============================] - 10s 379ms/step - d_loss: -4566.8402 - g_loss: -742.5118
# Epoch 1114/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 61.46
# 28/28 [==============================] - 10s 367ms/step - d_loss: -321.8850 - g_loss: -1944.5173
# Epoch 1115/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 77.99
# 28/28 [==============================] - 10s 372ms/step - d_loss: 5026.8399 - g_loss: -5819.7569
# Epoch 1116/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 91.28
# 28/28 [==============================] - 11s 395ms/step - d_loss: -1747.4957 - g_loss: 145.9181
# Epoch 1117/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 77.78
# 28/28 [==============================] - 10s 374ms/step - d_loss: 4468.8397 - g_loss: -3321.2589
# Epoch 1118/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 50.11
# 28/28 [==============================] - 10s 382ms/step - d_loss: -1378.8355 - g_loss: -201.3198
# Epoch 1119/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 79.53
# 28/28 [==============================] - 10s 376ms/step - d_loss: 2825.7307 - g_loss: 1251.8571
# Epoch 1120/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 50.27
# 28/28 [==============================] - 10s 370ms/step - d_loss: -3902.6876 - g_loss: -409.7002
# Epoch 1121/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 34ms/step
# FID SCORE: 65.66
# 28/28 [==============================] - 10s 375ms/step - d_loss: -3522.0195 - g_loss: 7176.5913
# Epoch 1122/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 79.21
# 28/28 [==============================] - 11s 390ms/step - d_loss: 4087.0468 - g_loss: 12012.6550
# Epoch 1123/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 80.87
# 28/28 [==============================] - 10s 380ms/step - d_loss: -861.0187 - g_loss: 6250.2188
# Epoch 1124/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 89.58
# 28/28 [==============================] - 10s 383ms/step - d_loss: -2181.5463 - g_loss: 1808.4847
# Epoch 1125/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 55.65
# 28/28 [==============================] - 10s 381ms/step - d_loss: -2863.8137 - g_loss: -1484.1782
# Epoch 1126/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 47.3
# 28/28 [==============================] - 10s 373ms/step - d_loss: 5818.9815 - g_loss: 1376.0279
# Epoch 1127/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 49.73
# 28/28 [==============================] - 10s 373ms/step - d_loss: 6232.5486 - g_loss: -1221.0491
# Epoch 1128/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 52.47
# 28/28 [==============================] - 11s 386ms/step - d_loss: 971.3693 - g_loss: 1204.8542
# Epoch 1129/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 48.11
# 28/28 [==============================] - 10s 378ms/step - d_loss: 3743.1478 - g_loss: 5723.9982
# Epoch 1130/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 40.5
# 28/28 [==============================] - 10s 383ms/step - d_loss: 2722.8257 - g_loss: 157.5698
# Epoch 1131/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 60.03
# 28/28 [==============================] - 10s 379ms/step - d_loss: -4257.7526 - g_loss: 3805.1863
# Epoch 1132/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 59.08
# 28/28 [==============================] - 10s 376ms/step - d_loss: -741.6346 - g_loss: 8326.3892
# Epoch 1133/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 64.26
# 28/28 [==============================] - 10s 376ms/step - d_loss: -4103.4842 - g_loss: 8527.3776
# Epoch 1134/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 33ms/step
# FID SCORE: 42.96
# 28/28 [==============================] - 11s 392ms/step - d_loss: -4711.3369 - g_loss: -2112.5886
# Epoch 1135/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 56.19
# 28/28 [==============================] - 10s 371ms/step - d_loss: 2307.1922 - g_loss: -11250.2916
# Epoch 1136/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 41.4
# 28/28 [==============================] - 11s 386ms/step - d_loss: 2978.3025 - g_loss: -4295.1340
# Epoch 1137/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 53.48
# 28/28 [==============================] - 10s 383ms/step - d_loss: -6620.0913 - g_loss: -8378.8179
# Epoch 1138/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 63.82
# 28/28 [==============================] - 10s 371ms/step - d_loss: 2648.4301 - g_loss: 1632.1978
# Epoch 1139/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 48.1
# 28/28 [==============================] - 10s 373ms/step - d_loss: 2680.3825 - g_loss: -920.3107
# Epoch 1140/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 44.42
# 28/28 [==============================] - 11s 391ms/step - d_loss: 42.2023 - g_loss: -4205.7642
# Epoch 1141/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 46.41
# 28/28 [==============================] - 10s 377ms/step - d_loss: 4219.4096 - g_loss: -3536.7825
# Epoch 1142/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 66.01
# 28/28 [==============================] - 11s 390ms/step - d_loss: 3014.6900 - g_loss: -1579.3795
# Epoch 1143/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 70.86
# 28/28 [==============================] - 10s 381ms/step - d_loss: -401.4492 - g_loss: -3995.2171
# Epoch 1144/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 60.66
# 28/28 [==============================] - 10s 372ms/step - d_loss: -1889.3130 - g_loss: -2940.2098
# Epoch 1145/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 38.67
# 28/28 [==============================] - 10s 377ms/step - d_loss: 1570.2102 - g_loss: 1633.6744
# Epoch 1146/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 40.34
# 28/28 [==============================] - 11s 385ms/step - d_loss: -3422.5768 - g_loss: -1898.4705
# Epoch 1147/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 34.89
# 28/28 [==============================] - 10s 372ms/step - d_loss: 3069.9773 - g_loss: -3102.1911
# Epoch 1148/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 55.47
# 28/28 [==============================] - 11s 385ms/step - d_loss: 1906.2165 - g_loss: -854.0434
# Epoch 1149/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 38.64
# 28/28 [==============================] - 10s 373ms/step - d_loss: -394.2001 - g_loss: -4761.2814
# Epoch 1150/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 37.81
# 28/28 [==============================] - 10s 380ms/step - d_loss: -3124.0167 - g_loss: -2582.7179
# Epoch 1151/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 32.82
# 28/28 [==============================] - 10s 374ms/step - d_loss: -1723.1391 - g_loss: -1047.7701
# Epoch 1152/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 31.65
# 28/28 [==============================] - 10s 380ms/step - d_loss: -1174.7918 - g_loss: -5987.8603
# Epoch 1153/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 87.24
# 28/28 [==============================] - 10s 375ms/step - d_loss: 959.7655 - g_loss: -5684.7601
# Epoch 1154/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 43.09
# 28/28 [==============================] - 10s 380ms/step - d_loss: 231.6536 - g_loss: -193.9310
# Epoch 1155/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 35.41
# 28/28 [==============================] - 10s 381ms/step - d_loss: -2786.4945 - g_loss: 702.3413
# Epoch 1156/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 45.17
# 28/28 [==============================] - 10s 377ms/step - d_loss: 750.3511 - g_loss: -2637.9094
# Epoch 1157/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 82.08
# 28/28 [==============================] - 10s 368ms/step - d_loss: -693.7644 - g_loss: 1556.0893
# Epoch 1158/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 82.46
# 28/28 [==============================] - 10s 384ms/step - d_loss: 573.5219 - g_loss: -63.0951
# Epoch 1159/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 31.05
# 28/28 [==============================] - 10s 364ms/step - d_loss: -954.0530 - g_loss: -2910.7962
# Epoch 1160/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 39.61
# 28/28 [==============================] - 10s 377ms/step - d_loss: 1559.7474 - g_loss: -3624.2501
# Epoch 1161/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 47.94
# 28/28 [==============================] - 10s 378ms/step - d_loss: 2451.9413 - g_loss: -2299.1265
# Epoch 1162/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 38.93
# 28/28 [==============================] - 10s 375ms/step - d_loss: 903.1925 - g_loss: -402.6961
# Epoch 1163/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 36.22
# 28/28 [==============================] - 10s 375ms/step - d_loss: 660.6932 - g_loss: -10.8050
# Epoch 1164/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 35.56
# 28/28 [==============================] - 11s 391ms/step - d_loss: -1643.1579 - g_loss: -2475.4372
# Epoch 1165/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 28.84
# 28/28 [==============================] - 11s 387ms/step - d_loss: -379.6535 - g_loss: -963.3558
# Epoch 1166/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 33.14
# 28/28 [==============================] - 10s 381ms/step - d_loss: 1531.5577 - g_loss: -1378.6987
# Epoch 1167/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 56.63
# 28/28 [==============================] - 10s 378ms/step - d_loss: 868.2703 - g_loss: 134.0878
# Epoch 1168/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 74.49
# 28/28 [==============================] - 10s 381ms/step - d_loss: -1681.1666 - g_loss: -5365.7218
# Epoch 1169/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 31.15
# 28/28 [==============================] - 10s 377ms/step - d_loss: -1157.3964 - g_loss: -3362.3172
# Epoch 1170/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 44.49
# 28/28 [==============================] - 11s 392ms/step - d_loss: -826.3781 - g_loss: -5671.0667
# Epoch 1171/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 30.74
# 28/28 [==============================] - 10s 370ms/step - d_loss: 1132.2506 - g_loss: -3359.5590
# Epoch 1172/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 34.46
# 28/28 [==============================] - 10s 379ms/step - d_loss: -1707.6586 - g_loss: -3997.4786
# Epoch 1173/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 36.47
# 28/28 [==============================] - 10s 374ms/step - d_loss: 1294.4653 - g_loss: -7147.2406
# Epoch 1174/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 35.36
# 28/28 [==============================] - 10s 379ms/step - d_loss: -2797.3300 - g_loss: -2995.8279
# Epoch 1175/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 48.54
# 28/28 [==============================] - 10s 382ms/step - d_loss: -2046.5013 - g_loss: -6630.7959
# Epoch 1176/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 46.89
# 28/28 [==============================] - 11s 396ms/step - d_loss: -47.8722 - g_loss: -3729.8433
# Epoch 1177/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 31.44
# 28/28 [==============================] - 10s 384ms/step - d_loss: 2886.9824 - g_loss: -1804.6879
# Epoch 1178/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 30.92
# 28/28 [==============================] - 10s 381ms/step - d_loss: 3212.4338 - g_loss: -1922.1776
# Epoch 1179/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 29.79
# 28/28 [==============================] - 10s 377ms/step - d_loss: 1150.1448 - g_loss: 3012.4417
# Epoch 1180/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 48.77
# 28/28 [==============================] - 10s 377ms/step - d_loss: -3427.3732 - g_loss: 6179.7822
# Epoch 1181/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 51.07
# 28/28 [==============================] - 10s 379ms/step - d_loss: -10287.9930 - g_loss: 3778.0698
# Epoch 1182/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 59.81
# 28/28 [==============================] - 10s 383ms/step - d_loss: -7019.7855 - g_loss: 10843.3989
# Epoch 1183/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 41.97
# 28/28 [==============================] - 10s 367ms/step - d_loss: 5755.1297 - g_loss: 12797.8513
# Epoch 1184/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 33ms/step
# FID SCORE: 38.07
# 28/28 [==============================] - 11s 386ms/step - d_loss: -1933.8722 - g_loss: 8912.7885
# Epoch 1185/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 50.87
# 28/28 [==============================] - 10s 380ms/step - d_loss: 2314.9172 - g_loss: 5334.5453
# Epoch 1186/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 69.73
# 28/28 [==============================] - 10s 370ms/step - d_loss: -9065.1289 - g_loss: 11028.8482
# Epoch 1187/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 52.1
# 28/28 [==============================] - 10s 384ms/step - d_loss: 10169.4502 - g_loss: 15282.7228
# Epoch 1188/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 76.52
# 28/28 [==============================] - 11s 394ms/step - d_loss: 3889.9198 - g_loss: 20164.3532
# Epoch 1189/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 36.25
# 28/28 [==============================] - 10s 367ms/step - d_loss: 994.8203 - g_loss: 11502.6078
# Epoch 1190/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 39.39
# 28/28 [==============================] - 11s 389ms/step - d_loss: -3418.4114 - g_loss: 18707.7888
# Epoch 1191/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 35.52
# 28/28 [==============================] - 10s 380ms/step - d_loss: -10624.4235 - g_loss: 9889.1605
# Epoch 1192/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 49.02
# 28/28 [==============================] - 10s 376ms/step - d_loss: 3680.5800 - g_loss: 12813.0304
# Epoch 1193/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 31.35
# 28/28 [==============================] - 10s 379ms/step - d_loss: 7228.8792 - g_loss: 9632.3170
# Epoch 1194/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 61.05
# 28/28 [==============================] - 11s 397ms/step - d_loss: 1606.8869 - g_loss: -486.8558
# Epoch 1195/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 36.92
# 28/28 [==============================] - 10s 381ms/step - d_loss: -2952.8949 - g_loss: 6829.0081
# Epoch 1196/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 57.27
# 28/28 [==============================] - 10s 382ms/step - d_loss: -1312.9697 - g_loss: 3986.3087
# Epoch 1197/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 36.71
# 28/28 [==============================] - 10s 375ms/step - d_loss: 1732.2813 - g_loss: 6289.8809
# Epoch 1198/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 64.85
# 28/28 [==============================] - 10s 375ms/step - d_loss: -1946.8635 - g_loss: 8278.3183
# Epoch 1199/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 68.69
# 28/28 [==============================] - 10s 379ms/step - d_loss: -770.2887 - g_loss: 1357.9468
# Epoch 1200/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 65.97
# 28/28 [==============================] - 11s 389ms/step - d_loss: 5383.7086 - g_loss: -636.2688
# Epoch 1201/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 79.41
# 28/28 [==============================] - 10s 376ms/step - d_loss: 3565.0413 - g_loss: -5144.6115
# Epoch 1202/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 74.43
# 28/28 [==============================] - 11s 388ms/step - d_loss: 3844.3956 - g_loss: -8363.2503
# Epoch 1203/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 70.02
# 28/28 [==============================] - 10s 374ms/step - d_loss: 8226.0020 - g_loss: -4980.7366
# Epoch 1204/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 41.48
# 28/28 [==============================] - 10s 377ms/step - d_loss: 1457.0352 - g_loss: -4981.3290
# Epoch 1205/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 57.91
# 28/28 [==============================] - 10s 374ms/step - d_loss: -1754.5726 - g_loss: -1541.8007
# Epoch 1206/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 65.56
# 28/28 [==============================] - 11s 392ms/step - d_loss: -3178.1896 - g_loss: -4707.9119
# Epoch 1207/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 70.9
# 28/28 [==============================] - 10s 380ms/step - d_loss: -7929.5352 - g_loss: -2831.7678
# Epoch 1208/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# ...
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 39.4
# 28/28 [==============================] - 11s 386ms/step - d_loss: 1294.6788 - g_loss: 2811.7760
# Epoch 1933/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 63.1
# 28/28 [==============================] - 10s 376ms/step - d_loss: 9.3731 - g_loss: 4547.4847
# Epoch 1934/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 42.44
# 28/28 [==============================] - 11s 387ms/step - d_loss: 170.2166 - g_loss: 3197.8465
# Epoch 1935/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 73.78
# 28/28 [==============================] - 10s 376ms/step - d_loss: -951.1335 - g_loss: 6994.3866
# Epoch 1936/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 39.78
# 28/28 [==============================] - 10s 380ms/step - d_loss: 2477.0762 - g_loss: 7759.2010
# Epoch 1937/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 55.11
# 28/28 [==============================] - 10s 375ms/step - d_loss: 733.1438 - g_loss: 9246.1176
# Epoch 1938/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 37.79
# 28/28 [==============================] - 11s 394ms/step - d_loss: -1455.1958 - g_loss: 8127.5640
# Epoch 1939/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 91.54
# 28/28 [==============================] - 10s 381ms/step - d_loss: 4263.5892 - g_loss: 11540.6003
# Epoch 1940/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 90.06
# 28/28 [==============================] - 11s 385ms/step - d_loss: 1924.9935 - g_loss: 8608.7016
# Epoch 1941/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 57.73
# 28/28 [==============================] - 10s 374ms/step - d_loss: 983.3316 - g_loss: 9047.0023
# Epoch 1942/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 104.86
# 28/28 [==============================] - 10s 371ms/step - d_loss: -6602.8054 - g_loss: 9047.1295
# Epoch 1943/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 84.02
# 28/28 [==============================] - 10s 370ms/step - d_loss: -1258.7393 - g_loss: 5844.0076
# Epoch 1944/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 55.18
# 28/28 [==============================] - 11s 388ms/step - d_loss: -421.0496 - g_loss: 8728.0333
# Epoch 1945/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 60.53
# 28/28 [==============================] - 10s 375ms/step - d_loss: 2546.5496 - g_loss: 6625.4226
# Epoch 1946/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 68.37
# 28/28 [==============================] - 10s 383ms/step - d_loss: 5887.6362 - g_loss: 4072.5323
# Epoch 1947/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 102.37
# 28/28 [==============================] - 10s 379ms/step - d_loss: -2731.5803 - g_loss: 2349.6172
# Epoch 1948/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 96.65
# 28/28 [==============================] - 10s 376ms/step - d_loss: 2660.7003 - g_loss: 6647.6308
# Epoch 1949/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 112.37
# 28/28 [==============================] - 10s 379ms/step - d_loss: -464.1533 - g_loss: 5962.1271
# Epoch 1950/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 118.27
# 28/28 [==============================] - 10s 384ms/step - d_loss: 3144.1418 - g_loss: 4189.7235
# Epoch 1951/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 105.15
# 28/28 [==============================] - 10s 375ms/step - d_loss: 832.9084 - g_loss: 2358.2039
# Epoch 1952/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 53.83
# 28/28 [==============================] - 10s 383ms/step - d_loss: 913.3060 - g_loss: 3850.3223
# Epoch 1953/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 40.67
# 28/28 [==============================] - 10s 374ms/step - d_loss: 671.0239 - g_loss: 3046.0764
# Epoch 1954/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 33.75
# 28/28 [==============================] - 10s 379ms/step - d_loss: -4321.3629 - g_loss: 564.1084
# Epoch 1955/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 58.95
# 28/28 [==============================] - 10s 376ms/step - d_loss: 2946.2628 - g_loss: -999.6470
# Epoch 1956/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 93.43
# 28/28 [==============================] - 11s 396ms/step - d_loss: 2676.3706 - g_loss: -1010.0163
# Epoch 1957/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 60.92
# 28/28 [==============================] - 10s 374ms/step - d_loss: -3964.0382 - g_loss: -996.3456
# Epoch 1958/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 65.22
# 28/28 [==============================] - 11s 389ms/step - d_loss: 5544.1864 - g_loss: -2735.6259
# Epoch 1959/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 49.38
# 28/28 [==============================] - 10s 374ms/step - d_loss: -1203.9322 - g_loss: -583.6930
# Epoch 1960/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 39.19
# 28/28 [==============================] - 10s 371ms/step - d_loss: -264.7427 - g_loss: 2032.9557
# Epoch 1961/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 75.71
# 28/28 [==============================] - 10s 369ms/step - d_loss: -3450.3683 - g_loss: 2392.5580
# Epoch 1962/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 68.72
# 28/28 [==============================] - 11s 395ms/step - d_loss: 1934.1211 - g_loss: 1003.5485
# Epoch 1963/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 74.01
# 28/28 [==============================] - 10s 370ms/step - d_loss: 3198.5844 - g_loss: -2887.8172
# Epoch 1964/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 81.83
# 28/28 [==============================] - 11s 397ms/step - d_loss: 2678.8037 - g_loss: -3620.9529
# Epoch 1965/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 34ms/step
# FID SCORE: 42.86
# 28/28 [==============================] - 10s 377ms/step - d_loss: 1217.1440 - g_loss: -351.7820
# Epoch 1966/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 88.21
# 28/28 [==============================] - 11s 390ms/step - d_loss: 184.3858 - g_loss: -1326.6280
# Epoch 1967/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 57.24
# 28/28 [==============================] - 10s 369ms/step - d_loss: 3043.5458 - g_loss: -1975.0052
# Epoch 1968/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 61.91
# 28/28 [==============================] - 11s 390ms/step - d_loss: -785.7352 - g_loss: -1195.5632
# Epoch 1969/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 103.31
# 28/28 [==============================] - 11s 387ms/step - d_loss: -169.9675 - g_loss: -2632.5152
# Epoch 1970/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 33.09
# 28/28 [==============================] - 11s 390ms/step - d_loss: 212.7837 - g_loss: -3631.0416
# Epoch 1971/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 37.36
# 28/28 [==============================] - 10s 381ms/step - d_loss: -710.9259 - g_loss: -1615.8490
# Epoch 1972/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 71.6
# 28/28 [==============================] - 10s 377ms/step - d_loss: -991.8381 - g_loss: -529.0203
# Epoch 1973/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 73.57
# 28/28 [==============================] - 10s 374ms/step - d_loss: -448.7484 - g_loss: -1850.9659
# Epoch 1974/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 45.2
# 28/28 [==============================] - 11s 392ms/step - d_loss: -142.6431 - g_loss: -626.8612
# Epoch 1975/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 62.53
# 28/28 [==============================] - 10s 376ms/step - d_loss: 537.9651 - g_loss: -1050.3572
# Epoch 1976/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 34.28
# 28/28 [==============================] - 10s 384ms/step - d_loss: 735.8338 - g_loss: 520.6923
# Epoch 1977/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 57.0
# 28/28 [==============================] - 10s 372ms/step - d_loss: -1485.8745 - g_loss: 2194.4963
# Epoch 1978/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 31.42
# 28/28 [==============================] - 10s 384ms/step - d_loss: -1244.3877 - g_loss: 2551.7744
# Epoch 1979/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 46.29
# 28/28 [==============================] - 10s 379ms/step - d_loss: -2471.6572 - g_loss: 178.6187
# Epoch 1980/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 53.05
# 28/28 [==============================] - 11s 385ms/step - d_loss: -2733.0205 - g_loss: -1653.3606
# Epoch 1981/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 50.0
# 28/28 [==============================] - 10s 376ms/step - d_loss: -808.3432 - g_loss: 973.7281
# Epoch 1982/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 48.83
# 28/28 [==============================] - 10s 382ms/step - d_loss: 1736.2013 - g_loss: 5302.6347
# Epoch 1983/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 72.25
# 28/28 [==============================] - 10s 378ms/step - d_loss: 2857.0857 - g_loss: 4336.2430
# Epoch 1984/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 69.97
# 28/28 [==============================] - 10s 379ms/step - d_loss: 1504.1243 - g_loss: 5582.3140
# Epoch 1985/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 72.45
# 28/28 [==============================] - 10s 374ms/step - d_loss: -213.3454 - g_loss: 4896.2991
# Epoch 1986/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 75.41
# 28/28 [==============================] - 11s 385ms/step - d_loss: 1491.2679 - g_loss: 405.3016
# Epoch 1987/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 36.15
# 28/28 [==============================] - 10s 375ms/step - d_loss: -249.8534 - g_loss: 1507.4759
# Epoch 1988/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 60.45
# 28/28 [==============================] - 11s 388ms/step - d_loss: -1101.3545 - g_loss: 1587.3431
# Epoch 1989/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 31ms/step
# FID SCORE: 70.92
# 28/28 [==============================] - 10s 375ms/step - d_loss: 1759.5632 - g_loss: 2225.2995
# Epoch 1990/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# FID SCORE: 47.85
# 28/28 [==============================] - 10s 378ms/step - d_loss: 445.2407 - g_loss: 3677.1368
# Epoch 1991/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 34.48
# 28/28 [==============================] - 10s 371ms/step - d_loss: 569.1470 - g_loss: 4801.8305
# Epoch 1992/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 45.2
# 28/28 [==============================] - 11s 385ms/step - d_loss: 1737.6479 - g_loss: 5621.6976
# Epoch 1993/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 64.68
# 28/28 [==============================] - 10s 379ms/step - d_loss: 1919.8082 - g_loss: 2132.9697
# Epoch 1994/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 27.02
# 28/28 [==============================] - 10s 379ms/step - d_loss: -907.6712 - g_loss: 1993.2801
# Epoch 1995/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 71.63
# 28/28 [==============================] - 10s 377ms/step - d_loss: 480.9549 - g_loss: 2405.0737
# Epoch 1996/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 61.53
# 28/28 [==============================] - 10s 380ms/step - d_loss: 1806.2321 - g_loss: 2827.8253
# Epoch 1997/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 30ms/step
# FID SCORE: 42.99
# 28/28 [==============================] - 10s 375ms/step - d_loss: 573.9450 - g_loss: 2277.2573
# Epoch 1998/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 47.88
# 28/28 [==============================] - 11s 386ms/step - d_loss: -1645.5813 - g_loss: 2457.1726
# Epoch 1999/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 28ms/step
# FID SCORE: 60.55
# 28/28 [==============================] - 10s 381ms/step - d_loss: 1231.5038 - g_loss: 749.3499
# Epoch 2000/2000
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 29ms/step
# FID SCORE: 47.03
# 28/28 [==============================] - 11s 385ms/step - d_loss: 6.1489 - g_loss: -1535.4364
# CPU times: user 14h 24min 16s, sys: 16h 34min 45s, total: 1d 6h 59min 2s
# Wall time: 5h 47min 29s

# %%
min(fid_scores)
# Out:
# 4.18

# %%
rounded_fid_scores = [np.round(i) for i in fid_scores]
min_fid = min(rounded_fid_scores)
latest_epoch_for_min_fid = 1 + max([epoch for epoch,fid_score in enumerate(rounded_fid_scores) if fid_score == min_fid])
print(latest_epoch_for_min_fid)
# Out:
# 982

# %%
# take best generator and plot 64 images with it
best_generator = tf.keras.models.load_model("VMI_gen_982_(4.18).h5")
random_latent_vectors = tf.random.normal(shape=(BATCH_SIZE, noise_dim))
generated_batch = best_generator(random_latent_vectors)
synthetic_images = generated_batch.numpy()
WGAN_CALLBACK().plot_multiple_images(synthetic_images, 8)                    
plt.show()

# %%
# Plotting fid scores corresponding to each epoch
plt.figure(figsize = (30,5))
plt.plot(fid_scores, linewidth = 3, linestyle = '-', marker = 'o', markersize = 10, markerfacecolor='red', label = "FID_SCORE", color = 'k')
plt.axhline(y = min(fid_scores), color = 'green', linestyle = '--', label = 'minimum fid score')
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("FID_SCORE", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(fid_scores)),np.arange(1,len(fid_scores)+1),rotation=90)
plt.legend()
plt.title("FID SCORES FOR EACH EPOCH", fontsize = 20, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### **PLOTTING GENERATOR VS DISCRIMINATOR LOSSES**

# %%
plt.figure(figsize = (30,5))
plt.plot(wgan_history.history['g_loss'], linewidth = 3, marker = 'o', markersize = 10, markerfacecolor='k',label = "Generator's Loss")
plt.plot(wgan_history.history['d_loss'], linewidth = 3, marker = '*', markersize = 10, markerfacecolor='k',label = "Discriminator's Loss")
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("LOSS", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(wgan_history.history['g_loss'])),np.arange(1,len(wgan_history.history['g_loss'])+1),rotation=90)
plt.legend()
plt.title("GENERATOR VS DISCRIMINATOR LOSS", fontsize = 20, fontweight = 'bold')
plt.show()
