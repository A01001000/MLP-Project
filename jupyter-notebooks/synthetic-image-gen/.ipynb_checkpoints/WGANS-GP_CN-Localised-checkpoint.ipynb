# %% [markdown]
# # **WGANS WITH GRADIENT PENALTY FOR SYNTHESIZING ALZHEIMER'S MRI**

# %% [markdown]
# ### **IMPORTING THE NECESSARY DEPENDENCIES**

# %%
import os
import cv2
import random
import shutil
import warnings
import numpy as np
import seaborn as sns
from tqdm import tqdm
from numpy import cov
from PIL import Image
from numpy import trace
import tensorflow as tf
from numpy import asarray
from tensorflow import keras
from scipy.linalg import sqrtm
from numpy import iscomplexobj
import matplotlib.pyplot as plt
from numpy.random import randint
warnings.filterwarnings("ignore")
from tensorflow.keras import layers
from skimage.transform import resize
from IPython.display import FileLink
from keras.datasets.mnist import load_data
from keras.applications.inception_v3 import InceptionV3
from skimage.metrics import structural_similarity as ssim
from keras.applications.inception_v3 import preprocess_input
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# 2025-03-21 01:58:07.278528: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-21 01:58:07.420452: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-21 01:58:07.462715: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-21 01:58:08.119805: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/mlp/lib:/usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/lib/x86_64-linux-gnu/:/opt/conda/lib
# 2025-03-21 01:58:08.119931: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/mlp/lib:/usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/lib/x86_64-linux-gnu/:/opt/conda/lib
# 2025-03-21 01:58:08.119940: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ### **DECLARING PATHS AND VARIABLES**

# %%
tf.random.set_seed(5638)
random.seed(5638)

# %%
class_name = 'CN_local'
working_directory = '../../../synthetic/'+class_name+"/"
os.makedirs(working_directory, exist_ok=True)
dataset_path = '../../../localisation_outputs/train/'

noise_dim = 256
IMG_SHAPE = (128, 128, 1)
BATCH_SIZE = 32 #increase to speed up BUT will use up more memory

# %% [markdown]
# ### **PREPARING THE DATASET**

# %%
def prepare_dataset(class_name):
    # Path to the class where the real images are; in the orignal dataset
    class_path = dataset_path + class_name + '/'
    images = []
    for image_name in os.listdir(class_path):
        if random.uniform(0., 1.) < 0.6:
            images.append(cv2.imread(class_path + image_name, cv2.COLOR_BGR2GRAY))
    # images = [cv2.imread(class_path + image_name, cv2.COLOR_BGR2GRAY) for image_name in os.listdir(class_path)]
    resized_images = np.array([cv2.resize(i, (IMG_SHAPE[0],IMG_SHAPE[1])) for i in images]).astype(np.float32)
    # Reshape each sample to (128, 128, 1) and normalize the pixel values in the [-1, 1] range
    reshaped_images = resized_images.reshape(resized_images.shape[0], *IMG_SHAPE)
    dataset = (reshaped_images - 127.5) / 127.5
    return dataset

train_images = prepare_dataset(class_name)

# %%
def conv_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding="same",
    use_bias=True,
    use_bn=False,
    use_dropout=False,
    drop_value=0.5
    ):

    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

def upsample_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    up_size=(2, 2),
    padding="same",
    use_bn=False,
    use_bias=True,
    use_dropout=False,
    drop_value=0.3
    ):

    x = layers.UpSampling2D(up_size)(x)
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    if activation:
        x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

# %% [markdown]
# ### **CREATE THE DISCRIMINATOR** (the critic in the original WGAN)

# %%
def get_discriminator_model():
    # input = 128 x 128, output = 64 x 64 
    img_input = layers.Input(shape=IMG_SHAPE)
    x = conv_block(
        img_input,
        32,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=False,
        drop_value=0.3
        )
    
    # input = 64 x 64, output = 32 x 32
    x = conv_block(
        x,
        64,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 32 x 32, output = 16 x 16
    x = conv_block(
        x,
        128,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 16 x 16, output = 8 x 8
    x = conv_block(
        x,
        256,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 8 x 8, output = 4 x 4
    x = conv_block(
        x,
        512,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 4 x 4, output = 1 
    x = layers.Flatten()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(1)(x)

    d_model = keras.models.Model(img_input, x, name="discriminator")
    return d_model

d_model = get_discriminator_model()
# tf.keras.utils.plot_model(d_model, to_file='discriminator.jpg', show_shapes=True, rankdir='TB')
# Out:
# 2025-03-21 01:58:09.348965: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-21 01:58:09.482682: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20750 MB memory:  -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9

# %% [markdown]
# ### **CREATE THE GENERATOR**

# %%
def get_generator_model():
    # input = (noise_dim, ), output = 4 x 4
    noise = layers.Input(shape=(noise_dim,))
    x = layers.Dense(4 * 4 * 2048, use_bias=False)(noise)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Reshape((4, 4, 2048))(x)
    
    # input = 4 x 4, output = 8 x 8
    x = upsample_block(
        x,
        1024,
        layers.LeakyReLU(0.2),
        kernel_size =(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 8 x 8, output = 16 x 16
    x = upsample_block(
        x,
        512,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 16 x 16, output = 32 x 32
    x = upsample_block(
        x,
        256,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 32 x 32, output = 64 x 64
    x = upsample_block(
        x,
        128,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 64 x 64, output = 128 x 128
    x = upsample_block(x, 1, layers.Activation("tanh"), strides=(1, 1), use_bias=False, use_bn=True)
    
    g_model = keras.models.Model(noise, x, name="generator")
    return g_model


g_model = get_generator_model()
# tf.keras.utils.plot_model(g_model, to_file='generator.jpg', show_shapes=True, rankdir='TB')

# %% [markdown]
# ### **CREATE THE WGAN-GP MODEL**
#
# Now that we have defined our generator and discriminator, it's time to implement the WGAN-GP model. We will also override the train_step for training.

# %%
class WGAN(keras.Model):
    def __init__(
        self,
        discriminator,
        generator,
        latent_dim,
        discriminator_extra_steps=5,
        gp_weight=10.0,
    ):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.d_steps = discriminator_extra_steps
        self.gp_weight = gp_weight

    def compile(self, d_optimizer, g_optimizer, d_loss_fn, g_loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss_fn = d_loss_fn
        self.g_loss_fn = g_loss_fn 

    def gradient_penalty(self, batch_size, real_images, fake_images):
        """Calculates the gradient penalty.

        This loss is calculated on an interpolated image
        and added to the discriminator loss.
        """
        # Get the interpolated image
        alpha = tf.random.normal([batch_size, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            # 1. Get the discriminator output for this interpolated image.
            pred = self.discriminator(interpolated, training=True)

        # 2. Calculate the gradients w.r.t to this interpolated image.
        grads = gp_tape.gradient(pred, [interpolated])[0]
        # 3. Calculate the norm of the gradients.
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        if isinstance(real_images, tuple):
            real_images = real_images[0]

        # Get the batch size
        batch_size = tf.shape(real_images)[0]

        # For each batch, we are going to perform the
        # following steps as laid out in the original paper:
        # 1. Train the generator and get the generator loss
        # 2. Train the discriminator and get the discriminator loss
        # 3. Calculate the gradient penalty
        # 4. Multiply this gradient penalty with a constant weight factor
        # 5. Add the gradient penalty to the discriminator loss
        # 6. Return the generator and discriminator losses as a loss dictionary

        # Train the discriminator first. 
        for i in range(self.d_steps):
            # Get the latent vector
            random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
            with tf.GradientTape() as tape:
                # Generate fake images from the latent vector
                fake_images = self.generator(random_latent_vectors, training=True)
                # Get the logits for the fake images
                fake_logits = self.discriminator(fake_images, training=True)
                # Get the logits for the real images
                real_logits = self.discriminator(real_images, training=True)

                # Calculate the discriminator loss using the fake and real image logits
                d_cost = self.d_loss_fn(real_img=real_logits, fake_img=fake_logits)
                # Calculate the gradient penalty
                gp = self.gradient_penalty(batch_size, real_images, fake_images)
                # Add the gradient penalty to the original discriminator loss
                d_loss = d_cost + gp * self.gp_weight

            # Get the gradients w.r.t the discriminator loss
            d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
            # Update the weights of the discriminator using the discriminator optimizer
            self.d_optimizer.apply_gradients(
                zip(d_gradient, self.discriminator.trainable_variables)
            )

        # Train the generator
        # Get the latent vector
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        with tf.GradientTape() as tape:
            # Generate fake images using the generator
            generated_images = self.generator(random_latent_vectors, training=True)
            # Get the discriminator logits for fake images
            gen_img_logits = self.discriminator(generated_images, training=True)
            # Calculate the generator loss
            g_loss = self.g_loss_fn(gen_img_logits)

        # Get the gradients w.r.t the generator loss
        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        # Update the weights of the generator using the generator optimizer
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )

        return {"d_loss": d_loss, "g_loss": g_loss}

# %% [markdown]
# ### **CREATE A CUSTOM CALLBACK**

# %%
def clear_workspace(directory):
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
class WGAN_CALLBACK(keras.callbacks.Callback):
    def __init__(self, n_epochs = 20, batch_size = BATCH_SIZE, latent_vector_dim = 128, fid_scores_filepath='fid_scores.npy'):
        self.batch_size = batch_size
        self.noise_dim = latent_vector_dim
        self.fid_scores = []
        self.n_epochs = n_epochs
        self.fid_scores_filepath = fid_scores_filepath
        
        # Load FID scores if they exist
        if os.path.exists(self.fid_scores_filepath):
            self.fid_scores = np.load(self.fid_scores_filepath, allow_pickle=True).tolist()
        
    @property
    def get_fid_scores(self):
        return self.fid_scores
    
    def plot_multiple_images(self,images, n_cols):
        n_cols = n_cols or len(images)
        n_rows = len(images) // n_cols
        if images.shape[-1] == 1:
            images = np.squeeze(images, axis=-1)
        plt.figure(figsize=(n_cols, n_rows))   
        plt.tight_layout()
        plt.suptitle('BEST GENERATOR', fontweight = 'bold')
        for index, image in enumerate(images):
            plt.subplot(n_rows, n_cols, index + 1)
            plt.imshow(image, cmap="gray")
            plt.axis("off")
    
    def calculate_fid(self, generated_images, real_images):
        # scale an array of images to a new size
        def scale_images(images, new_shape):
            images_list = []
            for image in images:
                # resize with nearest neighbor interpolation
                resized_image = cv2.cvtColor(cv2.resize(image, new_shape, cv2.INTER_NEAREST), cv2.COLOR_GRAY2BGR)
                # store the resized images
                images_list.append(resized_image)
            return asarray(images_list)
        # prepare the inception v3 model
        model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))
        # resize images
        generated_images = scale_images(generated_images, (299,299))
        real_images = scale_images(real_images, (299,299))
        # pre-process images
        generated_images = preprocess_input(generated_images)
        real_images = preprocess_input(real_images)
        # calculate feature embeddings
        embeddings1 = model.predict(generated_images)
        embeddings2 = model.predict(real_images)
        # calculate mean and covariance statistics
        mu1, sigma1 = embeddings1.mean(axis=0), cov(embeddings1, rowvar=False)
        mu2, sigma2 = embeddings2.mean(axis=0), cov(embeddings2, rowvar=False)
        # calculate sum squared difference between means
        ssdiff = np.sum((mu1 - mu2)**2.0)
        # calculate sqrt of product between cov
        covmean = sqrtm(sigma1.dot(sigma2))
        # check and correct imaginary numbers from sqrt
        if iscomplexobj(covmean):
            covmean = covmean.real
        # calculate fid score
        fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
        return np.round(fid,2)

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.batch_size, self.noise_dim))
        generator = self.model.generator
        generated_batch = generator(random_latent_vectors)
        generated_batch = generated_batch.numpy()
        random_number = np.random.randint(train_images.shape[0] - self.batch_size)
        real_batch = train_images[random_number: random_number + self.batch_size]
        current_fid = self.calculate_fid(generated_batch, real_batch)
        self.fid_scores.append(current_fid)  
        print('\033[1mFID SCORE: {}\033[0m'.format(current_fid))
        
        self.model.save_weights(working_directory + class_name + "_wgan_weights.h5")
        
        if current_fid <= min(self.fid_scores): #originally 5 as threshold of og paper (got a score of 4.28)
            save_dir = working_directory + "best_gen/"
            clear_workspace(save_dir)
            generator.save(save_dir + class_name + "_gen_{}_({}).h30".format(epoch+1,current_fid),save_format='h5')
            print("Generator Saved")
        
        # Save FID scores to a file after each epoch
        np.save(self.fid_scores_filepath, np.array(self.fid_scores))

# %%
def download_synthetic_images(generator, number_of_images, class_name = 'None'):
    clear_workspace(working_directory)
    # Making sure that no two images have the same name
    counter = 1
    # To check if folder is full
    folder_full = False
    # Folder path to store synthetic images. Folder name is the same as the class name which is inside the working directory
    folder_path = working_directory + 'synthetic_' + class_name + '/'
    images_folder = os.path.join(folder_path)
    # Create this folder if it doesn't exists, otherwise do nothing
    os.makedirs(images_folder, exist_ok=True)
    # Unless I get the desired number of good quality synthetic images in this folder, keep on generating images
    pbar = tqdm(total=number_of_images, position=0, leave=True)
    while len(os.listdir(images_folder)) < number_of_images:
        # Generate a batch of synthetic images
        random_latent_vectors = tf.random.normal(shape=(BATCH_SIZE, noise_dim))
        synthetic_images_batch = generator(random_latent_vectors)
        # Convert tensors to numpy arrays 
        synthetic_images_batch = synthetic_images_batch.numpy()
        # Convert the scale of images from (-1,1) to (0,255) and data type from float to integers 
        for image in synthetic_images_batch:
            image = (image * 127.5) + 127.5
            image = image.astype(np.uint8)
            # If it is a single channel image then save it as it is
            if image.shape[2] == 1:
                cv2.imwrite(images_folder + class_name + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If it is a 3 channel image then first convert it to grayscale and then save it
            elif image.shape[2] == 3:
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                cv2.imwrite(images_folder + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If the folder now has the number of desired images, then come out of the loop
            if len(os.listdir(images_folder)) >= number_of_images:
                folder_full = True
                break
        if folder_full == True:
                break
            
    # Generate a link from where I can download the synthetic images
    os.system('zip -r synthetic_images.zip {} >/dev/null 2>&1'.format(folder_path))
    return FileLink(r'synthetic_images.zip')

# %% [markdown]
# ### **TRAIN THE END TO END MODEL**

# %%
def train_wgans(dataset, n_epochs, batch_size = BATCH_SIZE, optimizer = 'adam', gen_lr = 0.0001, dis_lr = 0.0001, checkpoint_dir="wgan_checkpoint",
                resume_training=False):
    if not resume_training:
        clear_workspace(working_directory)
        os.makedirs(working_directory + "best_gen/", exist_ok=True) 
        if os.path.exists('fid_scores.npy'):
            os.remove('fid_scores.npy')
    assert optimizer in ['adam','rmsprop', 'nadam'], "Invalid optimizer. Valid options are 'adam' or 'rmsprop' or 'nadam'."
    if optimizer == 'adam':
        generator_optimizer = keras.optimizers.Adam(learning_rate = gen_lr, beta_1=0, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Adam(learning_rate = dis_lr, beta_1=0, beta_2=0.9)
    elif optimizer == 'rmsprop':
        generator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = gen_lr)
        discriminator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = dis_lr)
    elif optimizer == 'nadam':
        generator_optimizer = keras.optimizers.Nadam(learning_rate = gen_lr, beta_1=0.5, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Nadam(learning_rate = dis_lr, beta_1=0.5, beta_2=0.9)

    # Define the loss functions for the discriminator,
    # which should be (fake_loss - real_loss).
    # We will add the gradient penalty later to this loss function.
    def discriminator_loss(real_img, fake_img):
        real_loss = tf.reduce_mean(real_img)
        fake_loss = tf.reduce_mean(fake_img)
        return fake_loss - real_loss

    # Define the loss functions for the generator.
    def generator_loss(fake_img):
        return -tf.reduce_mean(fake_img)

    # Instantiate the customer `WGAN_CALLBACK` Keras callback.
    custom_callback = WGAN_CALLBACK(n_epochs, batch_size = BATCH_SIZE, latent_vector_dim = noise_dim)

    # Get the wgan model
    wgan = WGAN(discriminator = d_model, generator = g_model, latent_dim = noise_dim, discriminator_extra_steps=5)

    # Compile the wgan model
    wgan.compile(
        d_optimizer = discriminator_optimizer,
        g_optimizer = generator_optimizer,
        g_loss_fn = generator_loss,
        d_loss_fn = discriminator_loss
    )
    
    # If resuming training, load the previously saved model
    checkpoint_path = working_directory + "MoI_wgan_weights.h5"
    if resume_training and os.path.exists(checkpoint_path):
        print(f"Resuming training from checkpoint: {checkpoint_path}")
        wgan.load_weights(checkpoint_path)

    # Start training
    wgan_history = wgan.fit(dataset, batch_size = BATCH_SIZE, epochs = n_epochs, callbacks=[custom_callback])
    fid_scores = custom_callback.get_fid_scores
    
    return wgan_history, fid_scores

# %%
# %%time
wgan_history, fid_scores = train_wgans(dataset = train_images, 
                                        n_epochs = 500, #originally 2000; when resuming training, will train for an additional number of epochs based on what put here
                                        optimizer = 'adam', 
                                        gen_lr = 0.0001, 
                                        dis_lr = 0.0001,
                                        checkpoint_dir="wgan_checkpoint",
                                        resume_training=False) #CHECK: false if first time running, true if resuming from checkpoint
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 12.27
# Generator Saved
# 41/41 [==============================] - 39s 721ms/step - d_loss: -63.7260 - g_loss: 10.2038
# Epoch 2/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 11.85
# Generator Saved
# 41/41 [==============================] - 32s 798ms/step - d_loss: -36.8930 - g_loss: -28.6523
# Epoch 3/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 11.9
# 41/41 [==============================] - 32s 791ms/step - d_loss: -37.7332 - g_loss: -5.0007
# Epoch 4/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 8.6
# Generator Saved
# 41/41 [==============================] - 31s 767ms/step - d_loss: -35.2799 - g_loss: 34.7158
# Epoch 5/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 10.24
# 41/41 [==============================] - 31s 755ms/step - d_loss: -33.5781 - g_loss: 75.0897
# Epoch 6/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 7.73
# Generator Saved
# 41/41 [==============================] - 32s 783ms/step - d_loss: -33.8503 - g_loss: 102.1293
# Epoch 7/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 9.24
# 41/41 [==============================] - 31s 756ms/step - d_loss: -36.5563 - g_loss: 134.3072
# Epoch 8/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 7.43
# Generator Saved
# 41/41 [==============================] - 32s 792ms/step - d_loss: -29.3562 - g_loss: 132.8022
# Epoch 9/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 9.26
# 41/41 [==============================] - 31s 753ms/step - d_loss: -31.7231 - g_loss: 173.4539
# Epoch 10/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 11.1
# 41/41 [==============================] - 34s 842ms/step - d_loss: -27.3699 - g_loss: 182.1691
# Epoch 11/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 10.36
# 41/41 [==============================] - 31s 759ms/step - d_loss: -29.0003 - g_loss: 191.0028
# Epoch 12/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 7.01
# Generator Saved
# 41/41 [==============================] - 31s 771ms/step - d_loss: -28.0585 - g_loss: 192.2667
# Epoch 13/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 7.36
# 41/41 [==============================] - 32s 785ms/step - d_loss: -29.3747 - g_loss: 186.7791
# Epoch 14/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 10.44
# 41/41 [==============================] - 31s 765ms/step - d_loss: -26.2186 - g_loss: 177.2407
# Epoch 15/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 8.47
# 41/41 [==============================] - 31s 758ms/step - d_loss: -27.4111 - g_loss: 173.8971
# Epoch 16/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 12.89
# 41/41 [==============================] - 31s 756ms/step - d_loss: -24.6722 - g_loss: 193.0298
# Epoch 17/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 9.51
# 41/41 [==============================] - 31s 759ms/step - d_loss: -25.0438 - g_loss: 186.5317
# Epoch 18/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 8.68
# 41/41 [==============================] - 31s 771ms/step - d_loss: -26.5128 - g_loss: 165.0521
# Epoch 19/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 9.05
# 41/41 [==============================] - 31s 768ms/step - d_loss: -25.1965 - g_loss: 174.3674
# Epoch 20/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 5.21
# Generator Saved
# 41/41 [==============================] - 31s 765ms/step - d_loss: -26.1449 - g_loss: 157.6585
# Epoch 21/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 4.27
# Generator Saved
# 41/41 [==============================] - 32s 778ms/step - d_loss: -23.4201 - g_loss: 142.0489
# Epoch 22/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.94
# Generator Saved
# 41/41 [==============================] - 31s 766ms/step - d_loss: -22.7615 - g_loss: 137.6343
# Epoch 23/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 8.9
# 41/41 [==============================] - 31s 758ms/step - d_loss: -22.1084 - g_loss: 165.9002
# Epoch 24/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 4.6
# 41/41 [==============================] - 31s 758ms/step - d_loss: -20.7354 - g_loss: 145.7650
# Epoch 25/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 3.55
# Generator Saved
# 41/41 [==============================] - 32s 781ms/step - d_loss: -22.4949 - g_loss: 126.2084
# Epoch 26/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 12.42
# 41/41 [==============================] - 31s 758ms/step - d_loss: -22.2544 - g_loss: 137.6386
# Epoch 27/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 13.88
# 41/41 [==============================] - 31s 762ms/step - d_loss: -20.1623 - g_loss: 136.2357
# Epoch 28/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.76
# 41/41 [==============================] - 31s 752ms/step - d_loss: -19.0924 - g_loss: 132.6609
# Epoch 29/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.84
# Generator Saved
# 41/41 [==============================] - 32s 777ms/step - d_loss: -18.8151 - g_loss: 116.0465
# Epoch 30/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 4.6
# 41/41 [==============================] - 31s 756ms/step - d_loss: -19.4632 - g_loss: 124.6768
# Epoch 31/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 7.41
# 41/41 [==============================] - 31s 773ms/step - d_loss: -18.3575 - g_loss: 137.4325
# Epoch 32/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 2.95
# 41/41 [==============================] - 31s 762ms/step - d_loss: -19.0201 - g_loss: 131.5519
# Epoch 33/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.17
# 41/41 [==============================] - 34s 843ms/step - d_loss: -18.7148 - g_loss: 137.8992
# Epoch 34/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 2.6
# Generator Saved
# 41/41 [==============================] - 32s 777ms/step - d_loss: -17.2835 - g_loss: 134.5694
# Epoch 35/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 15.35
# 41/41 [==============================] - 31s 770ms/step - d_loss: -16.0362 - g_loss: 138.2681
# Epoch 36/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 3.29
# 41/41 [==============================] - 31s 753ms/step - d_loss: -15.4676 - g_loss: 113.9608
# Epoch 37/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 5.59
# 41/41 [==============================] - 32s 782ms/step - d_loss: -17.8741 - g_loss: 130.8554
# Epoch 38/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 4.55
# 41/41 [==============================] - 31s 757ms/step - d_loss: -14.9958 - g_loss: 115.2749
# Epoch 39/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 3.91
# 41/41 [==============================] - 31s 765ms/step - d_loss: -15.6391 - g_loss: 126.8475
# Epoch 40/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 3.86
# 41/41 [==============================] - 32s 776ms/step - d_loss: -15.6207 - g_loss: 91.3668
# Epoch 41/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 6.77
# 41/41 [==============================] - 31s 763ms/step - d_loss: -13.6641 - g_loss: 83.4033
# Epoch 42/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 4.92
# 41/41 [==============================] - 31s 758ms/step - d_loss: -13.3082 - g_loss: 111.3435
# Epoch 43/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 3.34
# 41/41 [==============================] - 31s 762ms/step - d_loss: -12.0176 - g_loss: 77.4445
# Epoch 44/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.8
# 41/41 [==============================] - 31s 768ms/step - d_loss: -13.7995 - g_loss: 87.3331
# Epoch 45/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 1.65
# Generator Saved
# 41/41 [==============================] - 31s 769ms/step - d_loss: -13.7535 - g_loss: 69.6327
# Epoch 46/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 7.57
# 41/41 [==============================] - 34s 833ms/step - d_loss: -13.0352 - g_loss: 85.4884
# Epoch 47/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 9.44
# 41/41 [==============================] - 31s 755ms/step - d_loss: -11.8229 - g_loss: 77.6540
# Epoch 48/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 6.04
# 41/41 [==============================] - 31s 772ms/step - d_loss: -11.9455 - g_loss: 61.0628
# Epoch 49/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 8.38
# 41/41 [==============================] - 31s 761ms/step - d_loss: -11.6376 - g_loss: 49.7575
# Epoch 50/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.53
# 41/41 [==============================] - 31s 754ms/step - d_loss: -12.4473 - g_loss: 60.5086
# Epoch 51/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 3.73
# 41/41 [==============================] - 31s 761ms/step - d_loss: -10.9123 - g_loss: 64.4559
# Epoch 52/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 5.53
# 41/41 [==============================] - 32s 778ms/step - d_loss: -11.2224 - g_loss: 58.5949
# Epoch 53/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 5.36
# 41/41 [==============================] - 32s 777ms/step - d_loss: -10.6715 - g_loss: 46.8035
# Epoch 54/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 5.76
# 41/41 [==============================] - 34s 841ms/step - d_loss: -12.7935 - g_loss: 43.5801
# Epoch 55/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 5.18
# 41/41 [==============================] - 32s 782ms/step - d_loss: -11.3818 - g_loss: 55.2959
# Epoch 56/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.2
# 41/41 [==============================] - 31s 766ms/step - d_loss: -8.9541 - g_loss: 43.6284
# Epoch 57/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 4.14
# 41/41 [==============================] - 31s 758ms/step - d_loss: -11.2082 - g_loss: 47.7488
# Epoch 58/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 4.91
# 41/41 [==============================] - 31s 757ms/step - d_loss: -11.5745 - g_loss: 42.4066
# Epoch 59/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 3.08
# 41/41 [==============================] - 31s 774ms/step - d_loss: -11.4786 - g_loss: 53.5911
# Epoch 60/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 4.46
# 41/41 [==============================] - 31s 772ms/step - d_loss: -11.5172 - g_loss: 26.9958
# Epoch 61/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.33
# 41/41 [==============================] - 31s 756ms/step - d_loss: -9.1908 - g_loss: 21.1993
# Epoch 62/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 5.25
# 41/41 [==============================] - 31s 756ms/step - d_loss: -10.0702 - g_loss: 25.1447
# Epoch 63/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.99
# 41/41 [==============================] - 32s 790ms/step - d_loss: -10.1161 - g_loss: 27.9832
# Epoch 64/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.2
# 41/41 [==============================] - 31s 758ms/step - d_loss: -10.1703 - g_loss: 25.3123
# Epoch 65/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 4.94
# 41/41 [==============================] - 36s 892ms/step - d_loss: -9.6348 - g_loss: 29.2098
# Epoch 66/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 10.1
# 41/41 [==============================] - 31s 762ms/step - d_loss: -8.3596 - g_loss: 16.2317
# Epoch 67/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 8.04
# 41/41 [==============================] - 32s 785ms/step - d_loss: -9.6890 - g_loss: 11.0639
# Epoch 68/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 6.15
# 41/41 [==============================] - 31s 759ms/step - d_loss: -9.0742 - g_loss: 6.3375
# Epoch 69/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.32
# 41/41 [==============================] - 31s 752ms/step - d_loss: -8.5591 - g_loss: 9.3611
# Epoch 70/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 3.82
# 41/41 [==============================] - 31s 775ms/step - d_loss: -7.8144 - g_loss: 9.5335
# Epoch 71/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.88
# 41/41 [==============================] - 31s 764ms/step - d_loss: -8.2168 - g_loss: 10.4390
# Epoch 72/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.35
# 41/41 [==============================] - 31s 755ms/step - d_loss: -8.3601 - g_loss: 24.2235
# Epoch 73/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 4.59
# 41/41 [==============================] - 33s 804ms/step - d_loss: -7.9705 - g_loss: 16.2661
# Epoch 74/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 3.55
# 41/41 [==============================] - 32s 780ms/step - d_loss: -8.2778 - g_loss: 12.5217
# Epoch 75/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.37
# 41/41 [==============================] - 31s 772ms/step - d_loss: -8.6571 - g_loss: 9.6782
# Epoch 76/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.55
# 41/41 [==============================] - 31s 772ms/step - d_loss: -7.7520 - g_loss: 2.6055
# Epoch 77/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.85
# 41/41 [==============================] - 31s 771ms/step - d_loss: -8.4451 - g_loss: 9.6586
# Epoch 78/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.85
# 41/41 [==============================] - 32s 776ms/step - d_loss: -8.6499 - g_loss: 11.2306
# Epoch 79/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.75
# 41/41 [==============================] - 31s 758ms/step - d_loss: -8.1356 - g_loss: 3.8723
# Epoch 80/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.44
# 41/41 [==============================] - 31s 757ms/step - d_loss: -9.2039 - g_loss: 9.2896
# Epoch 81/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.14
# 41/41 [==============================] - 31s 758ms/step - d_loss: -8.2213 - g_loss: 5.1281
# Epoch 82/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 7.32
# 41/41 [==============================] - 32s 776ms/step - d_loss: -7.2514 - g_loss: -3.1495
# Epoch 83/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.83
# 41/41 [==============================] - 31s 760ms/step - d_loss: -7.4997 - g_loss: -2.7247
# Epoch 84/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 7.62
# 41/41 [==============================] - 39s 956ms/step - d_loss: -8.0080 - g_loss: -1.8533
# Epoch 85/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 2.89
# 41/41 [==============================] - 31s 770ms/step - d_loss: -8.9632 - g_loss: -7.8939
# Epoch 86/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.21
# 41/41 [==============================] - 31s 759ms/step - d_loss: -7.8768 - g_loss: -9.1767
# Epoch 87/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.65
# 41/41 [==============================] - 31s 756ms/step - d_loss: -8.1345 - g_loss: -1.9105
# Epoch 88/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.14
# 41/41 [==============================] - 31s 753ms/step - d_loss: -6.6112 - g_loss: -0.6227
# Epoch 89/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 5.53
# 41/41 [==============================] - 32s 776ms/step - d_loss: -8.1102 - g_loss: 0.4125
# Epoch 90/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.91
# 41/41 [==============================] - 33s 805ms/step - d_loss: -7.6179 - g_loss: 0.9325
# Epoch 91/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 7.7
# 41/41 [==============================] - 31s 761ms/step - d_loss: -9.1021 - g_loss: -2.8527
# Epoch 92/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.12
# 41/41 [==============================] - 33s 820ms/step - d_loss: -7.3069 - g_loss: -5.3435
# Epoch 93/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 3.6
# 41/41 [==============================] - 31s 772ms/step - d_loss: -6.7759 - g_loss: -3.3438
# Epoch 94/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.73
# 41/41 [==============================] - 31s 763ms/step - d_loss: -8.2255 - g_loss: -2.4114
# Epoch 95/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 4.64
# 41/41 [==============================] - 31s 759ms/step - d_loss: -7.6870 - g_loss: -6.4464
# Epoch 96/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.33
# 41/41 [==============================] - 31s 756ms/step - d_loss: -6.8222 - g_loss: -3.5185
# Epoch 97/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.35
# Generator Saved
# 41/41 [==============================] - 32s 782ms/step - d_loss: -7.2376 - g_loss: -3.4373
# Epoch 98/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 4.59
# 41/41 [==============================] - 31s 758ms/step - d_loss: -6.6976 - g_loss: -4.7238
# Epoch 99/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.84
# 41/41 [==============================] - 32s 776ms/step - d_loss: -7.6991 - g_loss: -0.5823
# Epoch 100/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.53
# 41/41 [==============================] - 32s 779ms/step - d_loss: -7.4020 - g_loss: -5.2214
# Epoch 101/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.01
# 41/41 [==============================] - 31s 756ms/step - d_loss: -8.8981 - g_loss: 0.8178
# Epoch 102/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.53
# 41/41 [==============================] - 31s 756ms/step - d_loss: -7.7436 - g_loss: -9.4925
# Epoch 103/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.33
# 41/41 [==============================] - 35s 867ms/step - d_loss: -5.4704 - g_loss: -19.1060
# Epoch 104/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 3.41
# 41/41 [==============================] - 31s 763ms/step - d_loss: -4.9434 - g_loss: -25.5423
# Epoch 105/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.72
# 41/41 [==============================] - 31s 762ms/step - d_loss: -6.1728 - g_loss: -9.1479
# Epoch 106/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.61
# 41/41 [==============================] - 31s 756ms/step - d_loss: -8.6304 - g_loss: -5.7131
# Epoch 107/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.31
# 41/41 [==============================] - 31s 759ms/step - d_loss: -7.2222 - g_loss: -10.3844
# Epoch 108/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.79
# 41/41 [==============================] - 31s 773ms/step - d_loss: -6.7860 - g_loss: -8.7321
# Epoch 109/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.65
# 41/41 [==============================] - 31s 757ms/step - d_loss: -5.1907 - g_loss: -7.0930
# Epoch 110/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 4.38
# 41/41 [==============================] - 31s 768ms/step - d_loss: -6.1525 - g_loss: -5.7155
# Epoch 111/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.28
# Generator Saved
# 41/41 [==============================] - 33s 810ms/step - d_loss: -6.9244 - g_loss: -0.7552
# Epoch 112/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.08
# 41/41 [==============================] - 31s 772ms/step - d_loss: -7.6281 - g_loss: -12.0432
# Epoch 113/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 4.18
# 41/41 [==============================] - 31s 772ms/step - d_loss: -5.9680 - g_loss: -2.2404
# Epoch 114/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.4
# 41/41 [==============================] - 31s 754ms/step - d_loss: -6.4224 - g_loss: -1.6326
# Epoch 115/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.26
# 41/41 [==============================] - 32s 782ms/step - d_loss: -8.2383 - g_loss: 0.6917
# Epoch 116/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.73
# 41/41 [==============================] - 31s 761ms/step - d_loss: -6.3785 - g_loss: 5.4914
# Epoch 117/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 1.26
# Generator Saved
# 41/41 [==============================] - 31s 769ms/step - d_loss: -7.1878 - g_loss: -1.0097
# Epoch 118/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.77
# 41/41 [==============================] - 32s 775ms/step - d_loss: -7.0020 - g_loss: -3.3528
# Epoch 119/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.66
# 41/41 [==============================] - 32s 777ms/step - d_loss: -6.3594 - g_loss: 2.5854
# Epoch 120/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 4.96
# 41/41 [==============================] - 31s 758ms/step - d_loss: -6.1862 - g_loss: 1.9479
# Epoch 121/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.45
# 41/41 [==============================] - 31s 758ms/step - d_loss: -6.1934 - g_loss: 0.6069
# Epoch 122/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.47
# 41/41 [==============================] - 39s 968ms/step - d_loss: -5.9079 - g_loss: 3.2369
# Epoch 123/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 3.09
# 41/41 [==============================] - 31s 772ms/step - d_loss: -6.7635 - g_loss: 3.6650
# Epoch 124/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.48
# 41/41 [==============================] - 31s 763ms/step - d_loss: -8.9248 - g_loss: 1.8890
# Epoch 125/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 3.76
# 41/41 [==============================] - 31s 758ms/step - d_loss: -5.1025 - g_loss: -7.6770
# Epoch 126/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.33
# 41/41 [==============================] - 31s 757ms/step - d_loss: -6.9597 - g_loss: -5.9315
# Epoch 127/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 2.1
# 41/41 [==============================] - 31s 769ms/step - d_loss: -3.2494 - g_loss: -26.7397
# Epoch 128/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.51
# 41/41 [==============================] - 32s 776ms/step - d_loss: -2.6928 - g_loss: -29.1119
# Epoch 129/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.66
# 41/41 [==============================] - 31s 764ms/step - d_loss: -6.2273 - g_loss: -13.4706
# Epoch 130/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.39
# 41/41 [==============================] - 33s 817ms/step - d_loss: -5.5681 - g_loss: -8.0129
# Epoch 131/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 5.01
# 41/41 [==============================] - 31s 757ms/step - d_loss: -6.4289 - g_loss: 0.3891
# Epoch 132/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.18
# 41/41 [==============================] - 31s 759ms/step - d_loss: -6.2315 - g_loss: -5.3430
# Epoch 133/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.59
# 41/41 [==============================] - 31s 763ms/step - d_loss: -6.4689 - g_loss: -7.2129
# Epoch 134/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.6
# 41/41 [==============================] - 32s 775ms/step - d_loss: -5.7747 - g_loss: -11.4044
# Epoch 135/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.12
# 41/41 [==============================] - 31s 768ms/step - d_loss: -5.3622 - g_loss: -7.4131
# Epoch 136/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.73
# 41/41 [==============================] - 31s 754ms/step - d_loss: -7.4516 - g_loss: -9.7564
# Epoch 137/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.54
# 41/41 [==============================] - 31s 756ms/step - d_loss: -5.1079 - g_loss: -10.1164
# Epoch 138/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.54
# 41/41 [==============================] - 31s 770ms/step - d_loss: -7.2757 - g_loss: 1.4364
# Epoch 139/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 3.06
# 41/41 [==============================] - 31s 759ms/step - d_loss: -3.4082 - g_loss: -8.2590
# Epoch 140/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.22
# 41/41 [==============================] - 31s 756ms/step - d_loss: -5.6330 - g_loss: -23.2531
# Epoch 141/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.74
# 41/41 [==============================] - 39s 965ms/step - d_loss: -4.2651 - g_loss: -10.1543
# Epoch 142/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 1.72
# 41/41 [==============================] - 32s 780ms/step - d_loss: -5.2361 - g_loss: -6.6437
# Epoch 143/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.58
# 41/41 [==============================] - 31s 760ms/step - d_loss: -6.2202 - g_loss: 6.3922
# Epoch 144/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.07
# 41/41 [==============================] - 31s 766ms/step - d_loss: -6.1336 - g_loss: -0.4037
# Epoch 145/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.88
# 41/41 [==============================] - 32s 776ms/step - d_loss: -5.7481 - g_loss: -4.1271
# Epoch 146/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.6
# 41/41 [==============================] - 31s 760ms/step - d_loss: -5.4490 - g_loss: 2.2400
# Epoch 147/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.43
# 41/41 [==============================] - 33s 805ms/step - d_loss: -6.9229 - g_loss: 7.1003
# Epoch 148/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 1.57
# 41/41 [==============================] - 31s 754ms/step - d_loss: -6.5999 - g_loss: -1.7947
# Epoch 149/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 2.74
# 41/41 [==============================] - 31s 774ms/step - d_loss: -5.7334 - g_loss: -6.4571
# Epoch 150/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.21
# 41/41 [==============================] - 31s 754ms/step - d_loss: -5.5533 - g_loss: 4.3309
# Epoch 151/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.24
# Generator Saved
# 41/41 [==============================] - 31s 770ms/step - d_loss: -6.0485 - g_loss: -10.6252
# Epoch 152/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.82
# 41/41 [==============================] - 31s 773ms/step - d_loss: -5.8913 - g_loss: 5.3450
# Epoch 153/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.36
# 41/41 [==============================] - 31s 771ms/step - d_loss: -3.2170 - g_loss: 12.7232
# Epoch 154/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 1.99
# 41/41 [==============================] - 31s 761ms/step - d_loss: -7.6750 - g_loss: -8.9184
# Epoch 155/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.13
# 41/41 [==============================] - 31s 764ms/step - d_loss: 9.2119 - g_loss: -37.0404
# Epoch 156/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.54
# 41/41 [==============================] - 31s 754ms/step - d_loss: -9.3684 - g_loss: -47.8971
# Epoch 157/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.08
# 41/41 [==============================] - 32s 775ms/step - d_loss: -4.6845 - g_loss: -16.9907
# Epoch 158/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.73
# 41/41 [==============================] - 31s 760ms/step - d_loss: 0.5859 - g_loss: -19.9745
# Epoch 159/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.78
# 41/41 [==============================] - 31s 771ms/step - d_loss: -0.8023 - g_loss: -62.5639
# Epoch 160/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 1.73
# 41/41 [==============================] - 36s 893ms/step - d_loss: -3.7601 - g_loss: -4.5954
# Epoch 161/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.68
# 41/41 [==============================] - 31s 759ms/step - d_loss: -7.6220 - g_loss: -9.1645
# Epoch 162/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.88
# 41/41 [==============================] - 31s 764ms/step - d_loss: -5.9373 - g_loss: 1.4387
# Epoch 163/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.75
# 41/41 [==============================] - 30s 745ms/step - d_loss: 0.3414 - g_loss: -4.3784
# Epoch 164/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.65
# 41/41 [==============================] - 32s 778ms/step - d_loss: -3.0495 - g_loss: -3.0981
# Epoch 165/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.05
# Generator Saved
# 41/41 [==============================] - 32s 781ms/step - d_loss: -4.2457 - g_loss: -22.3820
# Epoch 166/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.75
# 41/41 [==============================] - 31s 773ms/step - d_loss: -4.8560 - g_loss: 7.0458
# Epoch 167/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.74
# 41/41 [==============================] - 31s 753ms/step - d_loss: -5.8498 - g_loss: 0.7620
# Epoch 168/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.05
# 41/41 [==============================] - 34s 848ms/step - d_loss: -4.0616 - g_loss: -6.3953
# Epoch 169/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.2
# 41/41 [==============================] - 31s 759ms/step - d_loss: -6.1800 - g_loss: -18.2519
# Epoch 170/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.27
# 41/41 [==============================] - 31s 766ms/step - d_loss: -5.4342 - g_loss: -25.5359
# Epoch 171/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.5
# 41/41 [==============================] - 31s 754ms/step - d_loss: -1.7566 - g_loss: -51.6425
# Epoch 172/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.29
# 41/41 [==============================] - 32s 775ms/step - d_loss: -5.7546 - g_loss: -23.2614
# Epoch 173/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.41
# 41/41 [==============================] - 31s 758ms/step - d_loss: -5.2537 - g_loss: 9.8651
# Epoch 174/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.89
# 41/41 [==============================] - 31s 756ms/step - d_loss: -3.1396 - g_loss: 28.4573
# Epoch 175/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.53
# 41/41 [==============================] - 31s 752ms/step - d_loss: -3.8003 - g_loss: 20.0805
# Epoch 176/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 1.91
# 41/41 [==============================] - 31s 773ms/step - d_loss: -3.3707 - g_loss: -1.8115
# Epoch 177/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.79
# 41/41 [==============================] - 31s 760ms/step - d_loss: -5.6312 - g_loss: 2.1549
# Epoch 178/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 1.58
# 41/41 [==============================] - 31s 757ms/step - d_loss: -3.8144 - g_loss: -7.3666
# Epoch 179/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 2.05
# 41/41 [==============================] - 40s 999ms/step - d_loss: -3.3493 - g_loss: -5.6903
# Epoch 180/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.59
# 41/41 [==============================] - 31s 757ms/step - d_loss: -6.5532 - g_loss: 3.2111
# Epoch 181/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.47
# 41/41 [==============================] - 31s 764ms/step - d_loss: -8.5112 - g_loss: 47.7217
# Epoch 182/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.21
# 41/41 [==============================] - 31s 756ms/step - d_loss: 1.7568 - g_loss: 2.1077
# Epoch 183/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.73
# 41/41 [==============================] - 32s 782ms/step - d_loss: 3.3435 - g_loss: 11.6931
# Epoch 184/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.56
# 41/41 [==============================] - 31s 762ms/step - d_loss: 5.0501 - g_loss: -35.3131
# Epoch 185/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.0
# 41/41 [==============================] - 34s 833ms/step - d_loss: -0.7869 - g_loss: 5.5728
# Epoch 186/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.6
# 41/41 [==============================] - 30s 745ms/step - d_loss: 1.4390 - g_loss: 0.6723
# Epoch 187/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 1.9
# 41/41 [==============================] - 32s 787ms/step - d_loss: -9.0776 - g_loss: -18.9084
# Epoch 188/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 3.59
# 41/41 [==============================] - 31s 756ms/step - d_loss: -15.4036 - g_loss: -108.6763
# Epoch 189/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 2.11
# 41/41 [==============================] - 31s 756ms/step - d_loss: 2.6037 - g_loss: -44.1007
# Epoch 190/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.41
# 41/41 [==============================] - 31s 752ms/step - d_loss: -4.0601 - g_loss: -132.0524
# Epoch 191/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 1.65
# 41/41 [==============================] - 31s 774ms/step - d_loss: -3.7263 - g_loss: -152.9491
# Epoch 192/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.2
# 41/41 [==============================] - 31s 758ms/step - d_loss: 4.5833 - g_loss: -24.6417
# Epoch 193/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.81
# 41/41 [==============================] - 31s 758ms/step - d_loss: -3.6048 - g_loss: 18.2582
# Epoch 194/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 1.49
# 41/41 [==============================] - 31s 773ms/step - d_loss: -3.9386 - g_loss: 89.6179
# Epoch 195/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.55
# 41/41 [==============================] - 31s 760ms/step - d_loss: -6.6133 - g_loss: 10.2091
# Epoch 196/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 4.36
# 41/41 [==============================] - 31s 765ms/step - d_loss: -33.1638 - g_loss: 14.2028
# Epoch 197/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 1.89
# 41/41 [==============================] - 31s 753ms/step - d_loss: -4.7177 - g_loss: 3.2591
# Epoch 198/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 1.95
# 41/41 [==============================] - 38s 942ms/step - d_loss: -11.2521 - g_loss: 137.5212
# Epoch 199/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.73
# 41/41 [==============================] - 31s 765ms/step - d_loss: 29.5954 - g_loss: 102.9210
# Epoch 200/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.79
# 41/41 [==============================] - 31s 769ms/step - d_loss: -0.7688 - g_loss: 43.4288
# Epoch 201/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.8
# 41/41 [==============================] - 31s 755ms/step - d_loss: 3.5947 - g_loss: -61.5859
# Epoch 202/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 1.95
# 41/41 [==============================] - 31s 772ms/step - d_loss: 14.4765 - g_loss: -56.1530
# Epoch 203/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 2.3
# 41/41 [==============================] - 31s 762ms/step - d_loss: -3.8805 - g_loss: -21.6566
# Epoch 204/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 0.86
# Generator Saved
# 41/41 [==============================] - 32s 789ms/step - d_loss: 1.5569 - g_loss: -14.1529
# Epoch 205/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.62
# 41/41 [==============================] - 31s 754ms/step - d_loss: -1.9886 - g_loss: -16.1786
# Epoch 206/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.7
# 41/41 [==============================] - 34s 826ms/step - d_loss: -16.0394 - g_loss: 18.4879
# Epoch 207/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 1.43
# 41/41 [==============================] - 31s 767ms/step - d_loss: -18.2884 - g_loss: 81.2719
# Epoch 208/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 3.25
# 41/41 [==============================] - 31s 762ms/step - d_loss: -9.6247 - g_loss: 83.9162
# Epoch 209/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 2.01
# 41/41 [==============================] - 32s 778ms/step - d_loss: 1.1993 - g_loss: 199.9520
# Epoch 210/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.97
# 41/41 [==============================] - 31s 762ms/step - d_loss: 4.0195 - g_loss: 58.1542
# Epoch 211/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 1.52
# 41/41 [==============================] - 31s 755ms/step - d_loss: 6.3710 - g_loss: 23.0450
# Epoch 212/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 1.89
# 41/41 [==============================] - 31s 754ms/step - d_loss: 2.3068 - g_loss: 108.0809
# Epoch 213/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 2.47
# 41/41 [==============================] - 32s 777ms/step - d_loss: -12.9445 - g_loss: 342.4188
# ...
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 61.54
# 84/84 [==============================] - 120s 1s/step - d_loss: -81.6349 - g_loss: -187.2068
# Epoch 441/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -112.4787 - g_loss: -425.46
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 80.89
# 84/84 [==============================] - 120s 1s/step - d_loss: -110.0692 - g_loss: -456.6980
# Epoch 442/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -184.1306 - g_loss: -2452.92
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 67.9
# 84/84 [==============================] - 120s 1s/step - d_loss: -192.8323 - g_loss: -2432.9623
# Epoch 443/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 230.1393 - g_loss: -1604.58
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 84.99
# 84/84 [==============================] - 120s 1s/step - d_loss: 255.9825 - g_loss: -1587.9524
# Epoch 444/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -168.1146 - g_loss: -208.99
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 67.33
# 84/84 [==============================] - 121s 1s/step - d_loss: -162.6412 - g_loss: -217.8274
# Epoch 445/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 72.3700 - g_loss: -747.85
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 89.07
# 84/84 [==============================] - 120s 1s/step - d_loss: 76.6625 - g_loss: -753.1047
# Epoch 446/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -60.8922 - g_loss: -1407.96
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 82.1
# 84/84 [==============================] - 120s 1s/step - d_loss: -59.7285 - g_loss: -1418.4691
# Epoch 447/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 98.0907 - g_loss: -1909.39
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 86.53
# 84/84 [==============================] - 121s 1s/step - d_loss: 100.6727 - g_loss: -1910.7558
# Epoch 448/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 55.8341 - g_loss: -1273.20
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 73.84
# 84/84 [==============================] - 120s 1s/step - d_loss: 55.1171 - g_loss: -1259.8753
# Epoch 449/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 0.7517 - g_loss: -149.205
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 90.32
# 84/84 [==============================] - 120s 1s/step - d_loss: 4.2905 - g_loss: -151.6164
# Epoch 450/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -4.7993 - g_loss: -158.22
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 72.8
# 84/84 [==============================] - 120s 1s/step - d_loss: -2.6663 - g_loss: -158.5799
# Epoch 451/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.7448 - g_loss: -68.16
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 58.38
# 84/84 [==============================] - 121s 1s/step - d_loss: -9.1084 - g_loss: -68.4327
# Epoch 452/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -1.1753 - g_loss: -149.41
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 62.61
# 84/84 [==============================] - 121s 1s/step - d_loss: -1.2399 - g_loss: -150.0253
# Epoch 453/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 1.9474 - g_loss: 143.376
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 59.2
# 84/84 [==============================] - 121s 1s/step - d_loss: 7.2770 - g_loss: 142.5773
# Epoch 454/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -14.2214 - g_loss: -241.63
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 49.38
# 84/84 [==============================] - 122s 1s/step - d_loss: -12.5451 - g_loss: -243.5905
# Epoch 455/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -11.3393 - g_loss: -167.14
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 40.99
# 84/84 [==============================] - 123s 1s/step - d_loss: -10.4149 - g_loss: -162.0569
# Epoch 456/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -50.1439 - g_loss: 14.97
# 1/1 [==============================] - 0s 59ms/step
# FID SCORE: 63.74
# 84/84 [==============================] - 125s 1s/step - d_loss: -49.0978 - g_loss: 6.2200
# Epoch 457/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 67.2469 - g_loss: 108.88
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 51.1
# 84/84 [==============================] - 125s 1s/step - d_loss: 67.7730 - g_loss: 117.8737
# Epoch 458/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 9.9387 - g_loss: -294.044
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 75.97
# 84/84 [==============================] - 124s 1s/step - d_loss: -2.4205 - g_loss: -299.6425
# Epoch 459/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -36.4980 - g_loss: -1898.06
# 1/1 [==============================] - 0s 58ms/step
# FID SCORE: 72.92
# 84/84 [==============================] - 123s 1s/step - d_loss: -49.8547 - g_loss: -1880.3169
# Epoch 460/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 5.3819 - g_loss: -2116.347
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 73.61
# 84/84 [==============================] - 123s 1s/step - d_loss: -12.3723 - g_loss: -2079.2567
# Epoch 461/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 134.4494 - g_loss: -776.62
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 54.24
# 84/84 [==============================] - 122s 1s/step - d_loss: 123.4482 - g_loss: -767.9048
# Epoch 462/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 13.3206 - g_loss: 253.39
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 60.83
# 84/84 [==============================] - 121s 1s/step - d_loss: 14.0352 - g_loss: 255.6159
# Epoch 463/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 1.2559 - g_loss: 134.50
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 74.66
# 84/84 [==============================] - 120s 1s/step - d_loss: -1.8515 - g_loss: 126.7716
# Epoch 464/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 33.0104 - g_loss: -570.19
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 75.85
# 84/84 [==============================] - 121s 1s/step - d_loss: 31.4966 - g_loss: -567.9735
# Epoch 465/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -41.3586 - g_loss: 120.15
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 68.52
# 84/84 [==============================] - 121s 1s/step - d_loss: -51.8398 - g_loss: 118.4201
# Epoch 466/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 52.7698 - g_loss: 364.20
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 70.73
# 84/84 [==============================] - 121s 1s/step - d_loss: 58.0843 - g_loss: 356.7150
# Epoch 467/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 35.3953 - g_loss: -1163.34
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 52.58
# 84/84 [==============================] - 120s 1s/step - d_loss: 37.4441 - g_loss: -1161.9454
# Epoch 468/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -87.6934 - g_loss: -1915.09
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 73.7
# 84/84 [==============================] - 121s 1s/step - d_loss: -81.9285 - g_loss: -1917.6951
# Epoch 469/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 12.7655 - g_loss: -1607.53
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 44.99
# 84/84 [==============================] - 121s 1s/step - d_loss: 17.5487 - g_loss: -1601.1175
# Epoch 470/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -34.5059 - g_loss: -701.81
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 43.62
# 84/84 [==============================] - 120s 1s/step - d_loss: -23.5698 - g_loss: -704.8679
# Epoch 471/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 23.2597 - g_loss: -126.70
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 38.97
# 84/84 [==============================] - 121s 1s/step - d_loss: 27.2926 - g_loss: -127.8224
# Epoch 472/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 106.6789 - g_loss: -63.01
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 45.96
# 84/84 [==============================] - 121s 1s/step - d_loss: 110.1682 - g_loss: -67.3436
# Epoch 473/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 39.3838 - g_loss: -217.85
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 48.95
# 84/84 [==============================] - 120s 1s/step - d_loss: 40.5872 - g_loss: -216.0406
# Epoch 474/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -32.5629 - g_loss: 5.87
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 56.26
# 84/84 [==============================] - 120s 1s/step - d_loss: -39.2364 - g_loss: 2.1847
# Epoch 475/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -31.5404 - g_loss: -518.10
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 73.44
# 84/84 [==============================] - 120s 1s/step - d_loss: -29.1532 - g_loss: -526.3590
# Epoch 476/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 12.2899 - g_loss: -1432.96
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 58.21
# 84/84 [==============================] - 121s 1s/step - d_loss: 23.1749 - g_loss: -1443.7648
# Epoch 477/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 43.4259 - g_loss: -2882.82
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 57.79
# 84/84 [==============================] - 121s 1s/step - d_loss: 55.5468 - g_loss: -2899.8741
# Epoch 478/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 121.5938 - g_loss: -2635.58
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 44.58
# 84/84 [==============================] - 121s 1s/step - d_loss: 112.2114 - g_loss: -2637.8031
# Epoch 479/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 127.0357 - g_loss: -3734.75
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 50.12
# 84/84 [==============================] - 120s 1s/step - d_loss: 135.3693 - g_loss: -3751.3457
# Epoch 480/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -40.4196 - g_loss: -6611.06
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 53.5
# 84/84 [==============================] - 120s 1s/step - d_loss: -24.3831 - g_loss: -6594.8848
# Epoch 481/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -13.4457 - g_loss: -4919.69
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 62.71
# 84/84 [==============================] - 121s 1s/step - d_loss: -3.4205 - g_loss: -4894.5102
# Epoch 482/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -10.3637 - g_loss: -3070.94
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 37.2
# 84/84 [==============================] - 122s 1s/step - d_loss: -4.9677 - g_loss: -3062.8612
# Epoch 483/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -133.0671 - g_loss: -5794.72
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 65.77
# 84/84 [==============================] - 121s 1s/step - d_loss: -161.6878 - g_loss: -5810.2755
# Epoch 484/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 163.0695 - g_loss: -3624.29
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 82.85
# 84/84 [==============================] - 121s 1s/step - d_loss: 152.3536 - g_loss: -3599.6280
# Epoch 485/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 184.5137 - g_loss: -2037.77
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 47.67
# 84/84 [==============================] - 121s 1s/step - d_loss: 171.8451 - g_loss: -2028.7763
# Epoch 486/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -13.4505 - g_loss: -932.81
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 75.64
# 84/84 [==============================] - 122s 1s/step - d_loss: 36.6149 - g_loss: -955.4807
# Epoch 487/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 10.5446 - g_loss: 485.52
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 52.09
# 84/84 [==============================] - 121s 1s/step - d_loss: -4.1831 - g_loss: 512.5322
# Epoch 488/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -149.8547 - g_loss: 1033.12
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 67.33
# 84/84 [==============================] - 120s 1s/step - d_loss: -151.6041 - g_loss: 1048.7741
# Epoch 489/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 96.9207 - g_loss: 2673.677
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 80.82
# 84/84 [==============================] - 120s 1s/step - d_loss: 93.4946 - g_loss: 2709.4859
# Epoch 490/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 382.4721 - g_loss: 3528.04
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 69.43
# 84/84 [==============================] - 121s 1s/step - d_loss: 410.2725 - g_loss: 3475.1926
# Epoch 491/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 180.4397 - g_loss: 1995.76
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 102.84
# 84/84 [==============================] - 121s 1s/step - d_loss: 192.3983 - g_loss: 1998.7428
# Epoch 492/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 0.1069 - g_loss: 2608.278
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 115.74
# 84/84 [==============================] - 120s 1s/step - d_loss: 3.1497 - g_loss: 2569.9300
# Epoch 493/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -314.0399 - g_loss: 3437.64
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 114.16
# 84/84 [==============================] - 121s 1s/step - d_loss: -305.2958 - g_loss: 3413.7887
# Epoch 494/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -80.7270 - g_loss: 5453.02
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 68.6
# 84/84 [==============================] - 120s 1s/step - d_loss: -113.4173 - g_loss: 5411.1489
# Epoch 495/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 61.8155 - g_loss: 1864.41
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 99.85
# 84/84 [==============================] - 120s 1s/step - d_loss: 57.1899 - g_loss: 1851.9078
# Epoch 496/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -220.1308 - g_loss: 882.14
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 80.86
# 84/84 [==============================] - 121s 1s/step - d_loss: -269.3750 - g_loss: 825.3588
# Epoch 497/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -12.3254 - g_loss: 1563.11
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 89.65
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.2801 - g_loss: 1582.0133
# Epoch 498/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -357.2312 - g_loss: 1010.50
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 96.15
# 84/84 [==============================] - 120s 1s/step - d_loss: -349.5847 - g_loss: 1018.5247
# Epoch 499/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 146.9227 - g_loss: -2386.04
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 104.94
# 84/84 [==============================] - 120s 1s/step - d_loss: 148.9842 - g_loss: -2383.0705
# Epoch 500/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 161.2267 - g_loss: 2270.58
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 80.01
# 84/84 [==============================] - 120s 1s/step - d_loss: 151.6505 - g_loss: 2287.3244
# CPU times: user 8h 15min 10s, sys: 35min 46s, total: 8h 50min 56s
# Wall time: 16h 42min 46s

# %% [markdown]
# ### **GET FID_SCORES & PLOT IMAGES**

# %%
min_fid_unrounded = min(fid_scores)
min_fid_unrounded
# Out:
# 0.86

# %%
rounded_fid_scores = [np.round(i) for i in fid_scores]
min_fid = min(rounded_fid_scores)
latest_epoch_for_min_fid = 1 + max([epoch for epoch,fid_score in enumerate(rounded_fid_scores) if fid_score == min_fid])
print(latest_epoch_for_min_fid)
# Out:
# 230

# %%
# take best generator and plot 64 images with it
try:
    best_gen_file = f"CN_local_gen_204_(0.86).h30"
    best_generator = tf.keras.models.load_model(working_directory + "best_gen/" + best_gen_file)
    random_latent_vectors = tf.random.normal(shape=(64, noise_dim))
    generated_batch = best_generator(random_latent_vectors)
    synthetic_images = generated_batch.numpy()
    WGAN_CALLBACK().plot_multiple_images(synthetic_images, 8)                    
    plt.show()
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Plotting fid scores corresponding to each epoch
plt.figure(figsize = (30,5))
plt.plot(fid_scores, linewidth = 3, linestyle = '-', marker = 'o', markersize = 10, markerfacecolor='red', label = "FID_SCORE", color = 'k')
plt.axhline(y = min(fid_scores), color = 'green', linestyle = '--', label = 'minimum fid score')
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("FID_SCORE", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(fid_scores)),np.arange(1,len(fid_scores)+1),rotation=90)
plt.legend()
plt.title("FID SCORES FOR EACH EPOCH", fontsize = 20, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### **PLOTTING GENERATOR VS DISCRIMINATOR LOSSES**

# %%
plt.figure(figsize = (30,5))
plt.plot(wgan_history.history['g_loss'], linewidth = 3, marker = 'o', markersize = 10, markerfacecolor='k',label = "Generator's Loss")
plt.plot(wgan_history.history['d_loss'], linewidth = 3, marker = '*', markersize = 10, markerfacecolor='k',label = "Discriminator's Loss")
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("LOSS", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(wgan_history.history['g_loss'])),np.arange(1,len(wgan_history.history['g_loss'])+1),rotation=90)
plt.legend()
plt.title("GENERATOR VS DISCRIMINATOR LOSS", fontsize = 20, fontweight = 'bold')
plt.show()
