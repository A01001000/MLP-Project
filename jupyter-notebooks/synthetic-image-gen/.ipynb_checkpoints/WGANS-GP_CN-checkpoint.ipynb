# %% [markdown]
# # **WGANS WITH GRADIENT PENALTY FOR SYNTHESIZING ALZHEIMER'S MRI**

# %% [markdown]
# ### **IMPORTING THE NECESSARY DEPENDENCIES**

# %%
import os
import cv2
import random
import shutil
import warnings
import numpy as np
import seaborn as sns
from tqdm import tqdm
from numpy import cov
from PIL import Image
from numpy import trace
import tensorflow as tf
from numpy import asarray
from tensorflow import keras
from scipy.linalg import sqrtm
from numpy import iscomplexobj
import matplotlib.pyplot as plt
from numpy.random import randint
warnings.filterwarnings("ignore")
from tensorflow.keras import layers
from skimage.transform import resize
from IPython.display import FileLink
from keras.datasets.mnist import load_data
from keras.applications.inception_v3 import InceptionV3
from skimage.metrics import structural_similarity as ssim
from keras.applications.inception_v3 import preprocess_input
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# 2025-03-21 14:07:17.703902: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-21 14:07:18.280157: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-21 14:07:18.575541: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-21 14:07:20.229670: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/mlp/lib:/usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/lib/x86_64-linux-gnu/:/opt/conda/lib
# 2025-03-21 14:07:20.229872: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/mlp/lib:/usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/lib/x86_64-linux-gnu/:/opt/conda/lib
# 2025-03-21 14:07:20.229883: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ### **DECLARING PATHS AND VARIABLES**

# %%
tf.random.set_seed(5638)
random.seed(5638)

# %%
class_name = 'CN'
working_directory = '../../../synthetic/'+class_name+"/"
os.makedirs(working_directory, exist_ok=True)
dataset_path = '../../../final_preprocessed2/train/'

noise_dim = 256
IMG_SHAPE = (128, 128, 1)
BATCH_SIZE = 32 #increase to speed up BUT will use up more memory

# %% [markdown]
# ### **PREPARING THE DATASET**

# %%
def prepare_dataset(class_name):
    # Path to the class where the real images are; in the orignal dataset
    class_path = dataset_path + class_name + '/'
    images = []
    for image_name in os.listdir(class_path):
        if random.uniform(0., 1.) < 0.6:
            images.append(cv2.imread(class_path + image_name, cv2.COLOR_BGR2GRAY))
    # images = [cv2.imread(class_path + image_name, cv2.COLOR_BGR2GRAY) for image_name in os.listdir(class_path)]
    resized_images = np.array([cv2.resize(i, (IMG_SHAPE[0],IMG_SHAPE[1])) for i in images]).astype(np.float32)
    # Reshape each sample to (128, 128, 1) and normalize the pixel values in the [-1, 1] range
    reshaped_images = resized_images.reshape(resized_images.shape[0], *IMG_SHAPE)
    dataset = (reshaped_images - 127.5) / 127.5
    return dataset

train_images = prepare_dataset(class_name)

# %%
def conv_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding="same",
    use_bias=True,
    use_bn=False,
    use_dropout=False,
    drop_value=0.5
    ):

    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

def upsample_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    up_size=(2, 2),
    padding="same",
    use_bn=False,
    use_bias=True,
    use_dropout=False,
    drop_value=0.3
    ):

    x = layers.UpSampling2D(up_size)(x)
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    if activation:
        x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

# %% [markdown]
# ### **CREATE THE DISCRIMINATOR** (the critic in the original WGAN)

# %%
def get_discriminator_model():
    # input = 128 x 128, output = 64 x 64 
    img_input = layers.Input(shape=IMG_SHAPE)
    x = conv_block(
        img_input,
        32,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=False,
        drop_value=0.3
        )
    
    # input = 64 x 64, output = 32 x 32
    x = conv_block(
        x,
        64,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 32 x 32, output = 16 x 16
    x = conv_block(
        x,
        128,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 16 x 16, output = 8 x 8
    x = conv_block(
        x,
        256,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 8 x 8, output = 4 x 4
    x = conv_block(
        x,
        512,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 4 x 4, output = 1 
    x = layers.Flatten()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(1)(x)

    d_model = keras.models.Model(img_input, x, name="discriminator")
    return d_model

d_model = get_discriminator_model()
# tf.keras.utils.plot_model(d_model, to_file='discriminator.jpg', show_shapes=True, rankdir='TB')
# Out:
# 2025-03-21 14:09:23.748992: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-21 14:09:23.918595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20750 MB memory:  -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9

# %% [markdown]
# ### **CREATE THE GENERATOR**

# %%
def get_generator_model():
    # input = (noise_dim, ), output = 4 x 4
    noise = layers.Input(shape=(noise_dim,))
    x = layers.Dense(4 * 4 * 2048, use_bias=False)(noise)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Reshape((4, 4, 2048))(x)
    
    # input = 4 x 4, output = 8 x 8
    x = upsample_block(
        x,
        1024,
        layers.LeakyReLU(0.2),
        kernel_size =(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 8 x 8, output = 16 x 16
    x = upsample_block(
        x,
        512,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 16 x 16, output = 32 x 32
    x = upsample_block(
        x,
        256,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 32 x 32, output = 64 x 64
    x = upsample_block(
        x,
        128,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 64 x 64, output = 128 x 128
    x = upsample_block(x, 1, layers.Activation("tanh"), strides=(1, 1), use_bias=False, use_bn=True)
    
    g_model = keras.models.Model(noise, x, name="generator")
    return g_model


g_model = get_generator_model()
# tf.keras.utils.plot_model(g_model, to_file='generator.jpg', show_shapes=True, rankdir='TB')

# %% [markdown]
# ### **CREATE THE WGAN-GP MODEL**
#
# Now that we have defined our generator and discriminator, it's time to implement the WGAN-GP model. We will also override the train_step for training.

# %%
class WGAN(keras.Model):
    def __init__(
        self,
        discriminator,
        generator,
        latent_dim,
        discriminator_extra_steps=5,
        gp_weight=10.0,
    ):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.d_steps = discriminator_extra_steps
        self.gp_weight = gp_weight

    def compile(self, d_optimizer, g_optimizer, d_loss_fn, g_loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss_fn = d_loss_fn
        self.g_loss_fn = g_loss_fn 

    def gradient_penalty(self, batch_size, real_images, fake_images):
        """Calculates the gradient penalty.

        This loss is calculated on an interpolated image
        and added to the discriminator loss.
        """
        # Get the interpolated image
        alpha = tf.random.normal([batch_size, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            # 1. Get the discriminator output for this interpolated image.
            pred = self.discriminator(interpolated, training=True)

        # 2. Calculate the gradients w.r.t to this interpolated image.
        grads = gp_tape.gradient(pred, [interpolated])[0]
        # 3. Calculate the norm of the gradients.
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        if isinstance(real_images, tuple):
            real_images = real_images[0]

        # Get the batch size
        batch_size = tf.shape(real_images)[0]

        # For each batch, we are going to perform the
        # following steps as laid out in the original paper:
        # 1. Train the generator and get the generator loss
        # 2. Train the discriminator and get the discriminator loss
        # 3. Calculate the gradient penalty
        # 4. Multiply this gradient penalty with a constant weight factor
        # 5. Add the gradient penalty to the discriminator loss
        # 6. Return the generator and discriminator losses as a loss dictionary

        # Train the discriminator first. 
        for i in range(self.d_steps):
            # Get the latent vector
            random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
            with tf.GradientTape() as tape:
                # Generate fake images from the latent vector
                fake_images = self.generator(random_latent_vectors, training=True)
                # Get the logits for the fake images
                fake_logits = self.discriminator(fake_images, training=True)
                # Get the logits for the real images
                real_logits = self.discriminator(real_images, training=True)

                # Calculate the discriminator loss using the fake and real image logits
                d_cost = self.d_loss_fn(real_img=real_logits, fake_img=fake_logits)
                # Calculate the gradient penalty
                gp = self.gradient_penalty(batch_size, real_images, fake_images)
                # Add the gradient penalty to the original discriminator loss
                d_loss = d_cost + gp * self.gp_weight

            # Get the gradients w.r.t the discriminator loss
            d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
            # Update the weights of the discriminator using the discriminator optimizer
            self.d_optimizer.apply_gradients(
                zip(d_gradient, self.discriminator.trainable_variables)
            )

        # Train the generator
        # Get the latent vector
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        with tf.GradientTape() as tape:
            # Generate fake images using the generator
            generated_images = self.generator(random_latent_vectors, training=True)
            # Get the discriminator logits for fake images
            gen_img_logits = self.discriminator(generated_images, training=True)
            # Calculate the generator loss
            g_loss = self.g_loss_fn(gen_img_logits)

        # Get the gradients w.r.t the generator loss
        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        # Update the weights of the generator using the generator optimizer
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )

        return {"d_loss": d_loss, "g_loss": g_loss}

# %% [markdown]
# ### **CREATE A CUSTOM CALLBACK**

# %%
def clear_workspace(directory):
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
class WGAN_CALLBACK(keras.callbacks.Callback):
    def __init__(self, n_epochs = 20, batch_size = BATCH_SIZE, latent_vector_dim = 128, fid_scores_filepath='fid_scores.npy'):
        self.batch_size = batch_size
        self.noise_dim = latent_vector_dim
        self.fid_scores = []
        self.n_epochs = n_epochs
        self.fid_scores_filepath = working_directory + fid_scores_filepath
        
        # Load FID scores if they exist
        if os.path.exists(self.fid_scores_filepath):
            self.fid_scores = np.load(self.fid_scores_filepath, allow_pickle=True).tolist()
        
    @property
    def get_fid_scores(self):
        return self.fid_scores
    
    def plot_multiple_images(self,images, n_cols):
        n_cols = n_cols or len(images)
        n_rows = len(images) // n_cols
        if images.shape[-1] == 1:
            images = np.squeeze(images, axis=-1)
        plt.figure(figsize=(n_cols, n_rows))   
        plt.tight_layout()
        plt.suptitle('BEST GENERATOR', fontweight = 'bold')
        for index, image in enumerate(images):
            plt.subplot(n_rows, n_cols, index + 1)
            plt.imshow(image, cmap="gray")
            plt.axis("off")
    
    def calculate_fid(self, generated_images, real_images):
        # scale an array of images to a new size
        def scale_images(images, new_shape):
            images_list = []
            for image in images:
                # resize with nearest neighbor interpolation
                resized_image = cv2.cvtColor(cv2.resize(image, new_shape, cv2.INTER_NEAREST), cv2.COLOR_GRAY2BGR)
                # store the resized images
                images_list.append(resized_image)
            return asarray(images_list)
        # prepare the inception v3 model
        model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))
        # resize images
        generated_images = scale_images(generated_images, (299,299))
        real_images = scale_images(real_images, (299,299))
        # pre-process images
        generated_images = preprocess_input(generated_images)
        real_images = preprocess_input(real_images)
        # calculate feature embeddings
        embeddings1 = model.predict(generated_images)
        embeddings2 = model.predict(real_images)
        # calculate mean and covariance statistics
        mu1, sigma1 = embeddings1.mean(axis=0), cov(embeddings1, rowvar=False)
        mu2, sigma2 = embeddings2.mean(axis=0), cov(embeddings2, rowvar=False)
        # calculate sum squared difference between means
        ssdiff = np.sum((mu1 - mu2)**2.0)
        # calculate sqrt of product between cov
        covmean = sqrtm(sigma1.dot(sigma2))
        # check and correct imaginary numbers from sqrt
        if iscomplexobj(covmean):
            covmean = covmean.real
        # calculate fid score
        fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
        return np.round(fid,2)

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.batch_size, self.noise_dim))
        generator = self.model.generator
        generated_batch = generator(random_latent_vectors)
        generated_batch = generated_batch.numpy()
        random_number = np.random.randint(train_images.shape[0] - self.batch_size)
        real_batch = train_images[random_number: random_number + self.batch_size]
        current_fid = self.calculate_fid(generated_batch, real_batch)
        self.fid_scores.append(current_fid)  
        print('\033[1mFID SCORE: {}\033[0m'.format(current_fid))
        
        self.model.save_weights(working_directory + class_name + "_wgan_weights.h5")
        
        if current_fid <= min(self.fid_scores): #originally 5 as threshold of og paper (got a score of 4.28)
            save_dir = working_directory + "best_gen/"
            clear_workspace(save_dir)
            generator.save(save_dir + class_name + "_gen_{}_({}).h30".format(epoch+1,current_fid),save_format='h5')
            print("Generator Saved")
        
        # Save FID scores to a file after each epoch
        np.save(self.fid_scores_filepath, np.array(self.fid_scores))

# %%
def download_synthetic_images(generator, number_of_images, class_name = 'None'):
    clear_workspace(working_directory)
    # Making sure that no two images have the same name
    counter = 1
    # To check if folder is full
    folder_full = False
    # Folder path to store synthetic images. Folder name is the same as the class name which is inside the working directory
    folder_path = working_directory + 'synthetic_' + class_name + '/'
    images_folder = os.path.join(folder_path)
    # Create this folder if it doesn't exists, otherwise do nothing
    os.makedirs(images_folder, exist_ok=True)
    # Unless I get the desired number of good quality synthetic images in this folder, keep on generating images
    pbar = tqdm(total=number_of_images, position=0, leave=True)
    while len(os.listdir(images_folder)) < number_of_images:
        # Generate a batch of synthetic images
        random_latent_vectors = tf.random.normal(shape=(BATCH_SIZE, noise_dim))
        synthetic_images_batch = generator(random_latent_vectors)
        # Convert tensors to numpy arrays 
        synthetic_images_batch = synthetic_images_batch.numpy()
        # Convert the scale of images from (-1,1) to (0,255) and data type from float to integers 
        for image in synthetic_images_batch:
            image = (image * 127.5) + 127.5
            image = image.astype(np.uint8)
            # If it is a single channel image then save it as it is
            if image.shape[2] == 1:
                cv2.imwrite(images_folder + class_name + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If it is a 3 channel image then first convert it to grayscale and then save it
            elif image.shape[2] == 3:
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                cv2.imwrite(images_folder + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If the folder now has the number of desired images, then come out of the loop
            if len(os.listdir(images_folder)) >= number_of_images:
                folder_full = True
                break
        if folder_full == True:
                break
            
    # Generate a link from where I can download the synthetic images
    os.system('zip -r synthetic_images.zip {} >/dev/null 2>&1'.format(folder_path))
    return FileLink(r'synthetic_images.zip')

# %% [markdown]
# ### **TRAIN THE END TO END MODEL**

# %%
def train_wgans(dataset, n_epochs, batch_size = BATCH_SIZE, optimizer = 'adam', gen_lr = 0.0001, dis_lr = 0.0001, checkpoint_dir="wgan_checkpoint",
                resume_training=False):
    if not resume_training:
        clear_workspace(working_directory)
        os.makedirs(working_directory + "best_gen/", exist_ok=True) 
        if os.path.exists('fid_scores.npy'):
            os.remove('fid_scores.npy')
    assert optimizer in ['adam','rmsprop', 'nadam'], "Invalid optimizer. Valid options are 'adam' or 'rmsprop' or 'nadam'."
    if optimizer == 'adam':
        generator_optimizer = keras.optimizers.Adam(learning_rate = gen_lr, beta_1=0, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Adam(learning_rate = dis_lr, beta_1=0, beta_2=0.9)
    elif optimizer == 'rmsprop':
        generator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = gen_lr)
        discriminator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = dis_lr)
    elif optimizer == 'nadam':
        generator_optimizer = keras.optimizers.Nadam(learning_rate = gen_lr, beta_1=0.5, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Nadam(learning_rate = dis_lr, beta_1=0.5, beta_2=0.9)

    # Define the loss functions for the discriminator,
    # which should be (fake_loss - real_loss).
    # We will add the gradient penalty later to this loss function.
    def discriminator_loss(real_img, fake_img):
        real_loss = tf.reduce_mean(real_img)
        fake_loss = tf.reduce_mean(fake_img)
        return fake_loss - real_loss

    # Define the loss functions for the generator.
    def generator_loss(fake_img):
        return -tf.reduce_mean(fake_img)

    # Instantiate the customer `WGAN_CALLBACK` Keras callback.
    custom_callback = WGAN_CALLBACK(n_epochs, batch_size = BATCH_SIZE, latent_vector_dim = noise_dim)

    # Get the wgan model
    wgan = WGAN(discriminator = d_model, generator = g_model, latent_dim = noise_dim, discriminator_extra_steps=5)

    # Compile the wgan model
    wgan.compile(
        d_optimizer = discriminator_optimizer,
        g_optimizer = generator_optimizer,
        g_loss_fn = generator_loss,
        d_loss_fn = discriminator_loss
    )
    
    # If resuming training, load the previously saved model
    checkpoint_path = working_directory + "MoI_wgan_weights.h5"
    if resume_training and os.path.exists(checkpoint_path):
        print(f"Resuming training from checkpoint: {checkpoint_path}")
        wgan.load_weights(checkpoint_path)

    # Start training
    wgan_history = wgan.fit(dataset, batch_size = BATCH_SIZE, epochs = n_epochs, callbacks=[custom_callback])
    fid_scores = custom_callback.get_fid_scores
    
    return wgan_history, fid_scores

# %%
# %%time
wgan_history, fid_scores = train_wgans(dataset = train_images, 
                                        n_epochs = 500, #originally 2000; when resuming training, will train for an additional number of epochs based on what put here
                                        optimizer = 'adam', 
                                        gen_lr = 0.0001, 
                                        dis_lr = 0.0001,
                                        checkpoint_dir="wgan_checkpoint",
                                        resume_training=False) #CHECK: false if first time running, true if resuming from checkpoint
# Out:
# Epoch 1/500
# 2025-03-21 14:19:31.995794: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8900
# 2025-03-21 14:19:32.310488: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 125.77
# Generator Saved
# 73/73 [==============================] - 75s 748ms/step - d_loss: -233.8216 - g_loss: 1.4236
# Epoch 2/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 125.68
# Generator Saved
# 73/73 [==============================] - 49s 670ms/step - d_loss: -211.3018 - g_loss: -46.7366
# Epoch 3/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 115.38
# Generator Saved
# 73/73 [==============================] - 50s 683ms/step - d_loss: -224.0926 - g_loss: 130.0642
# Epoch 4/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 106.87
# Generator Saved
# 73/73 [==============================] - 49s 679ms/step - d_loss: -213.2669 - g_loss: 338.5135
# Epoch 5/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 116.5
# 73/73 [==============================] - 50s 691ms/step - d_loss: -222.2913 - g_loss: 436.8029
# Epoch 6/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 125.93
# 73/73 [==============================] - 49s 679ms/step - d_loss: -219.9285 - g_loss: 476.5197
# Epoch 7/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 118.95
# 73/73 [==============================] - 49s 671ms/step - d_loss: -208.3874 - g_loss: 533.3727
# Epoch 8/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 115.0
# 73/73 [==============================] - 49s 672ms/step - d_loss: -211.7492 - g_loss: 548.6825
# Epoch 9/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 118.23
# 73/73 [==============================] - 50s 684ms/step - d_loss: -208.5497 - g_loss: 545.5139
# Epoch 10/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 111.66
# 73/73 [==============================] - 49s 673ms/step - d_loss: -196.8137 - g_loss: 590.3432
# Epoch 11/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 111.27
# 73/73 [==============================] - 49s 672ms/step - d_loss: -193.7146 - g_loss: 558.7947
# Epoch 12/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 119.11
# 73/73 [==============================] - 49s 677ms/step - d_loss: -181.6587 - g_loss: 606.0550
# Epoch 13/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 115.31
# 73/73 [==============================] - 49s 676ms/step - d_loss: -176.3389 - g_loss: 716.9199
# Epoch 14/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 119.83
# 73/73 [==============================] - 49s 673ms/step - d_loss: -167.9339 - g_loss: 636.3885
# Epoch 15/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 113.77
# 73/73 [==============================] - 52s 713ms/step - d_loss: -166.2248 - g_loss: 607.9155
# Epoch 16/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 120.41
# 73/73 [==============================] - 49s 676ms/step - d_loss: -161.6196 - g_loss: 684.6354
# Epoch 17/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 109.47
# 73/73 [==============================] - 49s 674ms/step - d_loss: -163.1223 - g_loss: 748.2365
# Epoch 18/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 115.76
# 73/73 [==============================] - 49s 675ms/step - d_loss: -156.6070 - g_loss: 745.8288
# Epoch 19/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 106.99
# 73/73 [==============================] - 50s 680ms/step - d_loss: -150.0358 - g_loss: 648.5484
# Epoch 20/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 112.77
# 73/73 [==============================] - 49s 680ms/step - d_loss: -143.6446 - g_loss: 580.5439
# Epoch 21/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 109.73
# 73/73 [==============================] - 50s 686ms/step - d_loss: -141.7125 - g_loss: 555.1884
# Epoch 22/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 113.39
# 73/73 [==============================] - 50s 681ms/step - d_loss: -143.1070 - g_loss: 588.5632
# Epoch 23/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 99.25
# Generator Saved
# 73/73 [==============================] - 49s 680ms/step - d_loss: -139.0805 - g_loss: 584.6511
# Epoch 24/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 87.97
# Generator Saved
# 73/73 [==============================] - 50s 681ms/step - d_loss: -131.2563 - g_loss: 504.9220
# Epoch 25/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 100.38
# 73/73 [==============================] - 50s 680ms/step - d_loss: -129.9474 - g_loss: 485.1926
# Epoch 26/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 97.84
# 73/73 [==============================] - 49s 679ms/step - d_loss: -127.3965 - g_loss: 493.8021
# Epoch 27/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 94.0
# 73/73 [==============================] - 49s 676ms/step - d_loss: -123.6800 - g_loss: 460.1480
# Epoch 28/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 98.06
# 73/73 [==============================] - 50s 687ms/step - d_loss: -119.8421 - g_loss: 442.7930
# Epoch 29/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 103.75
# 73/73 [==============================] - 50s 682ms/step - d_loss: -116.4008 - g_loss: 482.8098
# Epoch 30/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 96.98
# 73/73 [==============================] - 49s 677ms/step - d_loss: -113.4505 - g_loss: 497.7856
# Epoch 31/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 110.52
# 73/73 [==============================] - 50s 682ms/step - d_loss: -109.4440 - g_loss: 490.7685
# Epoch 32/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 106.22
# 73/73 [==============================] - 51s 694ms/step - d_loss: -111.9631 - g_loss: 505.4318
# Epoch 33/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 108.61
# 73/73 [==============================] - 49s 676ms/step - d_loss: -122.3330 - g_loss: 517.1647
# Epoch 34/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 112.86
# 73/73 [==============================] - 49s 675ms/step - d_loss: -121.9103 - g_loss: 511.6152
# Epoch 35/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 91.35
# 73/73 [==============================] - 50s 688ms/step - d_loss: -118.7761 - g_loss: 486.2433
# Epoch 36/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 104.66
# 73/73 [==============================] - 49s 677ms/step - d_loss: -114.1737 - g_loss: 439.5051
# Epoch 37/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 97.34
# 73/73 [==============================] - 49s 680ms/step - d_loss: -112.8595 - g_loss: 414.4657
# Epoch 38/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 103.06
# 73/73 [==============================] - 53s 728ms/step - d_loss: -109.5900 - g_loss: 407.3241
# Epoch 39/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 105.64
# 73/73 [==============================] - 49s 677ms/step - d_loss: -104.2343 - g_loss: 390.1889
# Epoch 40/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 84.22
# Generator Saved
# 73/73 [==============================] - 50s 681ms/step - d_loss: -101.9131 - g_loss: 361.2372
# Epoch 41/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 72.25
# Generator Saved
# 73/73 [==============================] - 51s 698ms/step - d_loss: -95.9278 - g_loss: 336.0466
# Epoch 42/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 63.11
# Generator Saved
# 73/73 [==============================] - 49s 680ms/step - d_loss: -85.7414 - g_loss: 345.0308
# Epoch 43/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 101.83
# 73/73 [==============================] - 49s 676ms/step - d_loss: -89.4583 - g_loss: 409.0502
# Epoch 44/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 89.06
# 73/73 [==============================] - 53s 733ms/step - d_loss: -87.9805 - g_loss: 394.9643
# Epoch 45/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 74.06
# 73/73 [==============================] - 49s 675ms/step - d_loss: -85.5525 - g_loss: 347.3463
# Epoch 46/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 80.24
# 73/73 [==============================] - 49s 675ms/step - d_loss: -79.1631 - g_loss: 297.4953
# Epoch 47/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 67.3
# 73/73 [==============================] - 50s 682ms/step - d_loss: -72.4996 - g_loss: 311.3137
# Epoch 48/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 73.04
# 73/73 [==============================] - 50s 684ms/step - d_loss: -67.3075 - g_loss: 278.1903
# Epoch 49/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 62.07
# Generator Saved
# 73/73 [==============================] - 50s 688ms/step - d_loss: -66.1681 - g_loss: 267.2106
# Epoch 50/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 64.11
# 73/73 [==============================] - 51s 708ms/step - d_loss: -64.5260 - g_loss: 301.7124
# Epoch 51/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 56.22
# Generator Saved
# 73/73 [==============================] - 50s 689ms/step - d_loss: -63.2172 - g_loss: 285.1458
# Epoch 52/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 53.41
# Generator Saved
# 73/73 [==============================] - 50s 685ms/step - d_loss: -62.3758 - g_loss: 290.1359
# Epoch 53/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 51.27
# Generator Saved
# 73/73 [==============================] - 50s 683ms/step - d_loss: -59.2129 - g_loss: 287.4498
# Epoch 54/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 72.29
# 73/73 [==============================] - 50s 683ms/step - d_loss: -58.7565 - g_loss: 296.9792
# Epoch 55/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 73.3
# 73/73 [==============================] - 50s 686ms/step - d_loss: -58.4821 - g_loss: 297.2792
# Epoch 56/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 71.72
# 73/73 [==============================] - 51s 700ms/step - d_loss: -61.6939 - g_loss: 279.8061
# Epoch 57/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 68.24
# 73/73 [==============================] - 50s 686ms/step - d_loss: -59.7709 - g_loss: 236.1911
# Epoch 58/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 62.34
# 73/73 [==============================] - 50s 685ms/step - d_loss: -54.9916 - g_loss: 236.6187
# Epoch 59/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 63.74
# 73/73 [==============================] - 49s 675ms/step - d_loss: -56.8642 - g_loss: 220.6686
# Epoch 60/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 62.06
# 73/73 [==============================] - 50s 688ms/step - d_loss: -54.9183 - g_loss: 197.6359
# Epoch 61/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 74.73
# 73/73 [==============================] - 49s 676ms/step - d_loss: -52.4335 - g_loss: 199.2242
# Epoch 62/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 59.07
# 73/73 [==============================] - 52s 708ms/step - d_loss: -49.3882 - g_loss: 202.6959
# Epoch 63/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 62.66
# 73/73 [==============================] - 50s 683ms/step - d_loss: -48.9244 - g_loss: 173.4340
# Epoch 64/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 44.32
# Generator Saved
# 73/73 [==============================] - 50s 681ms/step - d_loss: -48.3090 - g_loss: 185.5025
# Epoch 65/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 50.82
# 73/73 [==============================] - 49s 674ms/step - d_loss: -46.2646 - g_loss: 149.1142
# Epoch 66/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 44.78
# 73/73 [==============================] - 50s 686ms/step - d_loss: -44.3340 - g_loss: 140.4322
# Epoch 67/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 48.54
# 73/73 [==============================] - 50s 683ms/step - d_loss: -43.8597 - g_loss: 147.1691
# Epoch 68/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# FID SCORE: 55.15
# 73/73 [==============================] - 53s 726ms/step - d_loss: -44.2002 - g_loss: 154.6348
# Epoch 69/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 42.92
# Generator Saved
# 73/73 [==============================] - 50s 681ms/step - d_loss: -41.4077 - g_loss: 148.4910
# Epoch 70/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 54.58
# 73/73 [==============================] - 49s 679ms/step - d_loss: -43.1566 - g_loss: 141.9145
# Epoch 71/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 39.9
# Generator Saved
# 73/73 [==============================] - 50s 683ms/step - d_loss: -40.3300 - g_loss: 139.8385
# Epoch 72/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 47.47
# 73/73 [==============================] - 49s 674ms/step - d_loss: -38.0080 - g_loss: 134.4825
# Epoch 73/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 48.27
# 73/73 [==============================] - 50s 681ms/step - d_loss: -38.2235 - g_loss: 138.3174
# Epoch 74/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 41.81
# 73/73 [==============================] - 53s 725ms/step - d_loss: -37.2524 - g_loss: 127.2227
# Epoch 75/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 47.19
# 73/73 [==============================] - 49s 677ms/step - d_loss: -36.3433 - g_loss: 130.2462
# Epoch 76/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 46.52
# 73/73 [==============================] - 50s 683ms/step - d_loss: -35.6360 - g_loss: 130.8520
# Epoch 77/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 44.74
# 73/73 [==============================] - 49s 675ms/step - d_loss: -34.7916 - g_loss: 124.6789
# Epoch 78/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 36.26
# Generator Saved
# 73/73 [==============================] - 50s 683ms/step - d_loss: -33.7407 - g_loss: 129.0105
# Epoch 79/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 52.66
# 73/73 [==============================] - 49s 676ms/step - d_loss: -32.1339 - g_loss: 129.0373
# Epoch 80/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 52.02
# 73/73 [==============================] - 53s 732ms/step - d_loss: -30.6896 - g_loss: 112.1530
# Epoch 81/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 43.62
# 73/73 [==============================] - 50s 683ms/step - d_loss: -30.7819 - g_loss: 115.1075
# Epoch 82/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 63.14
# 73/73 [==============================] - 49s 677ms/step - d_loss: -30.5169 - g_loss: 105.4023
# Epoch 83/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 38.28
# 73/73 [==============================] - 50s 691ms/step - d_loss: -29.1422 - g_loss: 109.2603
# Epoch 84/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 32.81
# Generator Saved
# 73/73 [==============================] - 50s 683ms/step - d_loss: -28.9029 - g_loss: 111.8883
# Epoch 85/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 62.8
# 73/73 [==============================] - 50s 681ms/step - d_loss: -28.1269 - g_loss: 104.2272
# Epoch 86/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 45.59
# 73/73 [==============================] - 51s 697ms/step - d_loss: -27.2648 - g_loss: 107.0140
# Epoch 87/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 59.91
# 73/73 [==============================] - 49s 677ms/step - d_loss: -26.1329 - g_loss: 96.1784
# Epoch 88/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 35.03
# 73/73 [==============================] - 49s 674ms/step - d_loss: -26.3219 - g_loss: 82.6370
# Epoch 89/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 25.54
# Generator Saved
# 73/73 [==============================] - 50s 689ms/step - d_loss: -24.4114 - g_loss: 77.1273
# Epoch 90/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 39.15
# 73/73 [==============================] - 49s 678ms/step - d_loss: -24.6918 - g_loss: 78.4050
# Epoch 91/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 67.47
# 73/73 [==============================] - 49s 675ms/step - d_loss: -24.7879 - g_loss: 86.4617
# Epoch 92/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 31.72
# 73/73 [==============================] - 53s 727ms/step - d_loss: -23.2965 - g_loss: 87.2027
# Epoch 93/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 29.4
# 73/73 [==============================] - 50s 684ms/step - d_loss: -22.7625 - g_loss: 84.5298
# Epoch 94/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 29.88
# 73/73 [==============================] - 49s 674ms/step - d_loss: -23.5844 - g_loss: 86.2018
# Epoch 95/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 34.56
# 73/73 [==============================] - 50s 690ms/step - d_loss: -21.5459 - g_loss: 81.0135
# Epoch 96/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 44.03
# 73/73 [==============================] - 49s 680ms/step - d_loss: -21.1035 - g_loss: 79.5934
# Epoch 97/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 35.58
# 73/73 [==============================] - 49s 673ms/step - d_loss: -20.8918 - g_loss: 78.0831
# Epoch 98/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 33.63
# 73/73 [==============================] - 52s 721ms/step - d_loss: -20.8554 - g_loss: 78.8087
# Epoch 99/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 65.49
# 73/73 [==============================] - 50s 690ms/step - d_loss: -21.0977 - g_loss: 75.7129
# Epoch 100/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 37.72
# 73/73 [==============================] - 50s 682ms/step - d_loss: -19.7530 - g_loss: 68.0555
# Epoch 101/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 19.22
# Generator Saved
# 73/73 [==============================] - 50s 687ms/step - d_loss: -20.3695 - g_loss: 70.7262
# Epoch 102/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 33.49
# 73/73 [==============================] - 50s 682ms/step - d_loss: -18.2350 - g_loss: 48.2885
# Epoch 103/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 48.76
# 73/73 [==============================] - 49s 678ms/step - d_loss: -19.1205 - g_loss: 49.0946
# Epoch 104/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 48.7
# 73/73 [==============================] - 53s 724ms/step - d_loss: -18.9221 - g_loss: 51.9925
# Epoch 105/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 46.1
# 73/73 [==============================] - 50s 688ms/step - d_loss: -17.7286 - g_loss: 54.6562
# Epoch 106/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 26.62
# 73/73 [==============================] - 49s 676ms/step - d_loss: -17.5844 - g_loss: 54.4730
# Epoch 107/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 23.92
# 73/73 [==============================] - 49s 675ms/step - d_loss: -17.8163 - g_loss: 49.7284
# Epoch 108/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 31.3
# 73/73 [==============================] - 50s 681ms/step - d_loss: -17.1290 - g_loss: 48.6109
# Epoch 109/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 60.73
# 73/73 [==============================] - 49s 678ms/step - d_loss: -17.2367 - g_loss: 34.1146
# Epoch 110/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 32.73
# 73/73 [==============================] - 53s 724ms/step - d_loss: -16.7870 - g_loss: 35.9071
# Epoch 111/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 41.62
# 73/73 [==============================] - 50s 682ms/step - d_loss: -16.3457 - g_loss: 32.7915
# Epoch 112/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 20.79
# 73/73 [==============================] - 50s 686ms/step - d_loss: -15.4494 - g_loss: 33.7234
# Epoch 113/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 36.08
# 73/73 [==============================] - 49s 675ms/step - d_loss: -15.6427 - g_loss: 35.7769
# Epoch 114/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 40.14
# 73/73 [==============================] - 49s 676ms/step - d_loss: -15.8051 - g_loss: 34.6333
# Epoch 115/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 27.34
# 73/73 [==============================] - 50s 684ms/step - d_loss: -15.1972 - g_loss: 33.7056
# Epoch 116/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 54.14
# 73/73 [==============================] - 53s 723ms/step - d_loss: -15.1598 - g_loss: 40.5444
# Epoch 117/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 41.21
# 73/73 [==============================] - 49s 676ms/step - d_loss: -14.4130 - g_loss: 35.6615
# Epoch 118/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 33.57
# 73/73 [==============================] - 50s 683ms/step - d_loss: -14.4723 - g_loss: 34.1893
# Epoch 119/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 25.83
# 73/73 [==============================] - 49s 675ms/step - d_loss: -13.6221 - g_loss: 25.0645
# Epoch 120/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 19.39
# 73/73 [==============================] - 50s 682ms/step - d_loss: -13.9046 - g_loss: 24.7337
# Epoch 121/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 30.44
# 73/73 [==============================] - 50s 682ms/step - d_loss: -13.5035 - g_loss: 24.8475
# Epoch 122/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 40.79
# 73/73 [==============================] - 53s 723ms/step - d_loss: -13.5318 - g_loss: 31.0386
# Epoch 123/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 32.96
# 73/73 [==============================] - 49s 677ms/step - d_loss: -12.9127 - g_loss: 26.3678
# Epoch 124/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 38.73
# 73/73 [==============================] - 50s 683ms/step - d_loss: -13.4188 - g_loss: 25.1082
# Epoch 125/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 40.51
# 73/73 [==============================] - 49s 676ms/step - d_loss: -12.9433 - g_loss: 22.6036
# Epoch 126/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 25.53
# 73/73 [==============================] - 50s 683ms/step - d_loss: -13.1492 - g_loss: 21.2443
# Epoch 127/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 32.25
# 73/73 [==============================] - 50s 687ms/step - d_loss: -13.4270 - g_loss: 22.3236
# Epoch 128/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 30.67
# 73/73 [==============================] - 52s 717ms/step - d_loss: -11.9717 - g_loss: 18.4606
# Epoch 129/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 30.85
# 73/73 [==============================] - 50s 683ms/step - d_loss: -12.3367 - g_loss: 19.3717
# Epoch 130/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 26.84
# 73/73 [==============================] - 49s 674ms/step - d_loss: -11.5217 - g_loss: 19.4317
# Epoch 131/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 23.84
# 73/73 [==============================] - 50s 683ms/step - d_loss: -11.7412 - g_loss: 14.0998
# Epoch 132/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 22.03
# 73/73 [==============================] - 49s 679ms/step - d_loss: -11.8017 - g_loss: 16.5406
# Epoch 133/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 34.59
# 73/73 [==============================] - 49s 678ms/step - d_loss: -11.8471 - g_loss: 18.4547
# Epoch 134/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 59.69
# 73/73 [==============================] - 53s 734ms/step - d_loss: -11.8639 - g_loss: 16.7402
# Epoch 135/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 27.49
# 73/73 [==============================] - 50s 681ms/step - d_loss: -11.8074 - g_loss: 14.9159
# Epoch 136/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 38.44
# 73/73 [==============================] - 49s 676ms/step - d_loss: -10.5851 - g_loss: 12.6529
# Epoch 137/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 15.95
# Generator Saved
# 73/73 [==============================] - 50s 693ms/step - d_loss: -11.1843 - g_loss: 13.9965
# Epoch 138/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 26.08
# 73/73 [==============================] - 50s 686ms/step - d_loss: -11.4135 - g_loss: 10.7011
# Epoch 139/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 31.69
# 73/73 [==============================] - 49s 678ms/step - d_loss: -11.6040 - g_loss: 11.4009
# Epoch 140/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 21.34
# 73/73 [==============================] - 51s 704ms/step - d_loss: -11.0192 - g_loss: 10.1820
# Epoch 141/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 29.17
# 73/73 [==============================] - 50s 685ms/step - d_loss: -11.1151 - g_loss: 8.5370
# Epoch 142/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 19.81
# 73/73 [==============================] - 49s 675ms/step - d_loss: -11.1424 - g_loss: 9.9567
# Epoch 143/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 16.04
# 73/73 [==============================] - 50s 682ms/step - d_loss: -11.5870 - g_loss: 6.6592
# Epoch 144/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 18.4
# 73/73 [==============================] - 49s 679ms/step - d_loss: -11.1002 - g_loss: 6.3303
# Epoch 145/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 22.62
# 73/73 [==============================] - 49s 680ms/step - d_loss: -10.4467 - g_loss: 9.6333
# Epoch 146/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 45.94
# 73/73 [==============================] - 53s 728ms/step - d_loss: -11.3872 - g_loss: 9.0546
# Epoch 147/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 21.06
# 73/73 [==============================] - 50s 685ms/step - d_loss: -10.7543 - g_loss: 7.9099
# Epoch 148/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 19.46
# 73/73 [==============================] - 49s 675ms/step - d_loss: -10.6865 - g_loss: 6.4030
# Epoch 149/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 13.54
# Generator Saved
# 73/73 [==============================] - 50s 691ms/step - d_loss: -9.6812 - g_loss: 3.0753
# Epoch 150/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 17.29
# 73/73 [==============================] - 50s 689ms/step - d_loss: -10.5080 - g_loss: 5.0615
# Epoch 151/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 19.4
# 73/73 [==============================] - 50s 686ms/step - d_loss: -10.4344 - g_loss: -0.0441
# Epoch 152/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 19.81
# 73/73 [==============================] - 51s 698ms/step - d_loss: -10.1046 - g_loss: 2.5844
# Epoch 153/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 20.19
# 73/73 [==============================] - 50s 687ms/step - d_loss: -10.2312 - g_loss: 0.1486
# Epoch 154/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 18.52
# 73/73 [==============================] - 49s 678ms/step - d_loss: -10.1527 - g_loss: 4.1505
# Epoch 155/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 24.48
# 73/73 [==============================] - 50s 682ms/step - d_loss: -9.5912 - g_loss: 4.3173
# Epoch 156/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 19.47
# 73/73 [==============================] - 50s 686ms/step - d_loss: -9.4807 - g_loss: 4.8144
# Epoch 157/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 37.8
# 73/73 [==============================] - 49s 679ms/step - d_loss: -9.3684 - g_loss: 7.9773
# Epoch 158/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 23.4
# 73/73 [==============================] - 51s 697ms/step - d_loss: -9.2572 - g_loss: 6.4572
# Epoch 159/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 22.17
# 73/73 [==============================] - 50s 681ms/step - d_loss: -9.7092 - g_loss: 7.8452
# Epoch 160/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 21.81
# 73/73 [==============================] - 50s 685ms/step - d_loss: -8.9440 - g_loss: 3.7808
# Epoch 161/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 48.68
# 73/73 [==============================] - 50s 681ms/step - d_loss: -9.1853 - g_loss: 4.8113
# Epoch 162/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 17.63
# 73/73 [==============================] - 49s 676ms/step - d_loss: -8.3924 - g_loss: -1.1037
# Epoch 163/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 19.45
# 73/73 [==============================] - 50s 688ms/step - d_loss: -9.7143 - g_loss: 4.3057
# Epoch 164/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 17.49
# 73/73 [==============================] - 53s 728ms/step - d_loss: -9.0337 - g_loss: 4.5217
# Epoch 165/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 27.38
# 73/73 [==============================] - 49s 676ms/step - d_loss: -9.7635 - g_loss: 2.9951
# Epoch 166/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 18.79
# 73/73 [==============================] - 50s 685ms/step - d_loss: -9.1718 - g_loss: 3.0633
# Epoch 167/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 24.7
# 73/73 [==============================] - 49s 677ms/step - d_loss: -8.6239 - g_loss: 3.8423
# Epoch 168/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 18.09
# 73/73 [==============================] - 49s 675ms/step - d_loss: -9.2497 - g_loss: 3.5449
# Epoch 169/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 17.63
# 73/73 [==============================] - 50s 685ms/step - d_loss: -8.8802 - g_loss: 5.5564
# Epoch 170/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 16.71
# 73/73 [==============================] - 53s 724ms/step - d_loss: -9.6123 - g_loss: 2.8087
# Epoch 171/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 24.96
# 73/73 [==============================] - 49s 678ms/step - d_loss: -9.3170 - g_loss: -0.3786
# Epoch 172/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 31.2
# 73/73 [==============================] - 49s 674ms/step - d_loss: -8.7241 - g_loss: 1.3724
# Epoch 173/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 23.02
# 73/73 [==============================] - 50s 685ms/step - d_loss: -9.9896 - g_loss: 2.7157
# Epoch 174/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 22.93
# 73/73 [==============================] - 49s 678ms/step - d_loss: -9.3853 - g_loss: 2.0307
# Epoch 175/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 24.51
# 73/73 [==============================] - 49s 677ms/step - d_loss: -8.4330 - g_loss: -1.1816
# Epoch 176/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 18.32
# 73/73 [==============================] - 53s 731ms/step - d_loss: -8.3709 - g_loss: 2.6088
# Epoch 177/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 27.82
# 73/73 [==============================] - 49s 678ms/step - d_loss: -8.7590 - g_loss: 5.3495
# Epoch 178/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 18.04
# 73/73 [==============================] - 49s 675ms/step - d_loss: -9.5029 - g_loss: 0.5114
# Epoch 179/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 22.31
# 73/73 [==============================] - 50s 689ms/step - d_loss: -8.8100 - g_loss: 2.3816
# Epoch 180/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 22.87
# 73/73 [==============================] - 49s 680ms/step - d_loss: -9.1573 - g_loss: 4.3690
# Epoch 181/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 17.03
# 73/73 [==============================] - 49s 677ms/step - d_loss: -8.6366 - g_loss: 4.1492
# Epoch 182/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 23.01
# 73/73 [==============================] - 54s 741ms/step - d_loss: -9.7463 - g_loss: 3.2173
# Epoch 183/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 19.79
# 73/73 [==============================] - 49s 679ms/step - d_loss: -9.6260 - g_loss: 4.2097
# Epoch 184/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 26.1
# 73/73 [==============================] - 49s 677ms/step - d_loss: -9.2473 - g_loss: -2.1674
# Epoch 185/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 17.25
# 73/73 [==============================] - 49s 675ms/step - d_loss: -8.3292 - g_loss: -0.6178
# Epoch 186/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 26.28
# 73/73 [==============================] - 50s 691ms/step - d_loss: -9.6714 - g_loss: 0.6516
# Epoch 187/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 25.79
# 73/73 [==============================] - 49s 675ms/step - d_loss: -8.0155 - g_loss: 1.8980
# Epoch 188/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 20.57
# 73/73 [==============================] - 52s 718ms/step - d_loss: -7.6316 - g_loss: -0.5791
# Epoch 189/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 28.98
# 73/73 [==============================] - 50s 684ms/step - d_loss: -9.5767 - g_loss: 4.0932
# Epoch 190/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 15.38
# 73/73 [==============================] - 49s 678ms/step - d_loss: -9.4367 - g_loss: 2.0042
# Epoch 191/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 32.01
# 73/73 [==============================] - 49s 677ms/step - d_loss: -8.7610 - g_loss: 5.8558
# Epoch 192/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 39.74
# 73/73 [==============================] - 50s 682ms/step - d_loss: -7.7446 - g_loss: 5.6366
# Epoch 193/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 15.79
# 73/73 [==============================] - 49s 676ms/step - d_loss: -8.4044 - g_loss: 6.0712
# Epoch 194/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 20.16
# 73/73 [==============================] - 53s 728ms/step - d_loss: -8.6856 - g_loss: 4.0781
# Epoch 195/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 19.38
# 73/73 [==============================] - 50s 685ms/step - d_loss: -7.6306 - g_loss: 3.7239
# Epoch 196/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 17.85
# 73/73 [==============================] - 50s 685ms/step - d_loss: -8.5568 - g_loss: 6.3723
# Epoch 197/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 48ms/step
# FID SCORE: 14.19
# 73/73 [==============================] - 49s 678ms/step - d_loss: -7.4475 - g_loss: 5.6472
# Epoch 198/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 18.73
# 73/73 [==============================] - 50s 683ms/step - d_loss: -7.9068 - g_loss: 1.9916
# Epoch 199/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 13.99
# 73/73 [==============================] - 50s 687ms/step - d_loss: -8.7135 - g_loss: 5.1018
# Epoch 200/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 23.07
# 73/73 [==============================] - 51s 703ms/step - d_loss: -7.5608 - g_loss: 4.7536
# Epoch 201/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 21.15
# 73/73 [==============================] - 49s 679ms/step - d_loss: -8.6215 - g_loss: -0.0728
# Epoch 202/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 15.93
# 73/73 [==============================] - 50s 684ms/step - d_loss: -8.4603 - g_loss: 1.4118
# Epoch 203/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 23.55
# 73/73 [==============================] - 49s 677ms/step - d_loss: -7.5280 - g_loss: 7.7086
# Epoch 204/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 15.47
# 73/73 [==============================] - 50s 681ms/step - d_loss: -10.0500 - g_loss: 2.5769
# Epoch 205/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 17.15
# 73/73 [==============================] - 50s 686ms/step - d_loss: -8.6112 - g_loss: 7.5013
# Epoch 206/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 19.74
# 73/73 [==============================] - 51s 703ms/step - d_loss: -8.1071 - g_loss: 6.7376
# Epoch 207/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 47ms/step
# FID SCORE: 23.48
# 73/73 [==============================] - 49s 678ms/step - d_loss: -7.7589 - g_loss: 4.6269
# Epoch 208/500
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 15.57
# 73/73 [==============================] - 50s 684ms/step - d_loss: -7.1265 - g_loss: 2.2014
# Epoch 209/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 28.58
# 73/73 [==============================] - 49s 677ms/step - d_loss: -7.2782 - g_loss: 6.4464
# Epoch 210/500
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 49ms/step
# FID SCORE: 39.87
# 73/73 [==============================] - 49s 677ms/step - d_loss: -8.7839 - g_loss: 6.3545
# ...
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 61.54
# 84/84 [==============================] - 120s 1s/step - d_loss: -81.6349 - g_loss: -187.2068
# Epoch 441/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -112.4787 - g_loss: -425.46
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 80.89
# 84/84 [==============================] - 120s 1s/step - d_loss: -110.0692 - g_loss: -456.6980
# Epoch 442/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -184.1306 - g_loss: -2452.92
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 67.9
# 84/84 [==============================] - 120s 1s/step - d_loss: -192.8323 - g_loss: -2432.9623
# Epoch 443/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 230.1393 - g_loss: -1604.58
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 84.99
# 84/84 [==============================] - 120s 1s/step - d_loss: 255.9825 - g_loss: -1587.9524
# Epoch 444/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -168.1146 - g_loss: -208.99
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 67.33
# 84/84 [==============================] - 121s 1s/step - d_loss: -162.6412 - g_loss: -217.8274
# Epoch 445/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 72.3700 - g_loss: -747.85
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 89.07
# 84/84 [==============================] - 120s 1s/step - d_loss: 76.6625 - g_loss: -753.1047
# Epoch 446/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -60.8922 - g_loss: -1407.96
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 82.1
# 84/84 [==============================] - 120s 1s/step - d_loss: -59.7285 - g_loss: -1418.4691
# Epoch 447/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 98.0907 - g_loss: -1909.39
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 86.53
# 84/84 [==============================] - 121s 1s/step - d_loss: 100.6727 - g_loss: -1910.7558
# Epoch 448/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 55.8341 - g_loss: -1273.20
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 73.84
# 84/84 [==============================] - 120s 1s/step - d_loss: 55.1171 - g_loss: -1259.8753
# Epoch 449/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 0.7517 - g_loss: -149.205
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 90.32
# 84/84 [==============================] - 120s 1s/step - d_loss: 4.2905 - g_loss: -151.6164
# Epoch 450/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -4.7993 - g_loss: -158.22
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 72.8
# 84/84 [==============================] - 120s 1s/step - d_loss: -2.6663 - g_loss: -158.5799
# Epoch 451/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.7448 - g_loss: -68.16
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 58.38
# 84/84 [==============================] - 121s 1s/step - d_loss: -9.1084 - g_loss: -68.4327
# Epoch 452/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -1.1753 - g_loss: -149.41
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 62.61
# 84/84 [==============================] - 121s 1s/step - d_loss: -1.2399 - g_loss: -150.0253
# Epoch 453/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 1.9474 - g_loss: 143.376
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 59.2
# 84/84 [==============================] - 121s 1s/step - d_loss: 7.2770 - g_loss: 142.5773
# Epoch 454/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -14.2214 - g_loss: -241.63
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 49.38
# 84/84 [==============================] - 122s 1s/step - d_loss: -12.5451 - g_loss: -243.5905
# Epoch 455/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -11.3393 - g_loss: -167.14
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 40.99
# 84/84 [==============================] - 123s 1s/step - d_loss: -10.4149 - g_loss: -162.0569
# Epoch 456/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -50.1439 - g_loss: 14.97
# 1/1 [==============================] - 0s 59ms/step
# FID SCORE: 63.74
# 84/84 [==============================] - 125s 1s/step - d_loss: -49.0978 - g_loss: 6.2200
# Epoch 457/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 67.2469 - g_loss: 108.88
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 51.1
# 84/84 [==============================] - 125s 1s/step - d_loss: 67.7730 - g_loss: 117.8737
# Epoch 458/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 9.9387 - g_loss: -294.044
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 75.97
# 84/84 [==============================] - 124s 1s/step - d_loss: -2.4205 - g_loss: -299.6425
# Epoch 459/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -36.4980 - g_loss: -1898.06
# 1/1 [==============================] - 0s 58ms/step
# FID SCORE: 72.92
# 84/84 [==============================] - 123s 1s/step - d_loss: -49.8547 - g_loss: -1880.3169
# Epoch 460/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 5.3819 - g_loss: -2116.347
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 73.61
# 84/84 [==============================] - 123s 1s/step - d_loss: -12.3723 - g_loss: -2079.2567
# Epoch 461/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 134.4494 - g_loss: -776.62
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 54.24
# 84/84 [==============================] - 122s 1s/step - d_loss: 123.4482 - g_loss: -767.9048
# Epoch 462/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 13.3206 - g_loss: 253.39
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 60.83
# 84/84 [==============================] - 121s 1s/step - d_loss: 14.0352 - g_loss: 255.6159
# Epoch 463/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 1.2559 - g_loss: 134.50
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 74.66
# 84/84 [==============================] - 120s 1s/step - d_loss: -1.8515 - g_loss: 126.7716
# Epoch 464/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 33.0104 - g_loss: -570.19
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 75.85
# 84/84 [==============================] - 121s 1s/step - d_loss: 31.4966 - g_loss: -567.9735
# Epoch 465/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -41.3586 - g_loss: 120.15
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 68.52
# 84/84 [==============================] - 121s 1s/step - d_loss: -51.8398 - g_loss: 118.4201
# Epoch 466/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 52.7698 - g_loss: 364.20
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 70.73
# 84/84 [==============================] - 121s 1s/step - d_loss: 58.0843 - g_loss: 356.7150
# Epoch 467/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 35.3953 - g_loss: -1163.34
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 52.58
# 84/84 [==============================] - 120s 1s/step - d_loss: 37.4441 - g_loss: -1161.9454
# Epoch 468/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -87.6934 - g_loss: -1915.09
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 73.7
# 84/84 [==============================] - 121s 1s/step - d_loss: -81.9285 - g_loss: -1917.6951
# Epoch 469/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 12.7655 - g_loss: -1607.53
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 44.99
# 84/84 [==============================] - 121s 1s/step - d_loss: 17.5487 - g_loss: -1601.1175
# Epoch 470/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -34.5059 - g_loss: -701.81
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 43.62
# 84/84 [==============================] - 120s 1s/step - d_loss: -23.5698 - g_loss: -704.8679
# Epoch 471/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 23.2597 - g_loss: -126.70
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 38.97
# 84/84 [==============================] - 121s 1s/step - d_loss: 27.2926 - g_loss: -127.8224
# Epoch 472/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 106.6789 - g_loss: -63.01
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 45.96
# 84/84 [==============================] - 121s 1s/step - d_loss: 110.1682 - g_loss: -67.3436
# Epoch 473/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 39.3838 - g_loss: -217.85
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 48.95
# 84/84 [==============================] - 120s 1s/step - d_loss: 40.5872 - g_loss: -216.0406
# Epoch 474/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -32.5629 - g_loss: 5.87
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 56.26
# 84/84 [==============================] - 120s 1s/step - d_loss: -39.2364 - g_loss: 2.1847
# Epoch 475/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -31.5404 - g_loss: -518.10
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 73.44
# 84/84 [==============================] - 120s 1s/step - d_loss: -29.1532 - g_loss: -526.3590
# Epoch 476/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 12.2899 - g_loss: -1432.96
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 58.21
# 84/84 [==============================] - 121s 1s/step - d_loss: 23.1749 - g_loss: -1443.7648
# Epoch 477/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 43.4259 - g_loss: -2882.82
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 57.79
# 84/84 [==============================] - 121s 1s/step - d_loss: 55.5468 - g_loss: -2899.8741
# Epoch 478/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 121.5938 - g_loss: -2635.58
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 44.58
# 84/84 [==============================] - 121s 1s/step - d_loss: 112.2114 - g_loss: -2637.8031
# Epoch 479/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 127.0357 - g_loss: -3734.75
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 50.12
# 84/84 [==============================] - 120s 1s/step - d_loss: 135.3693 - g_loss: -3751.3457
# Epoch 480/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -40.4196 - g_loss: -6611.06
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 53.5
# 84/84 [==============================] - 120s 1s/step - d_loss: -24.3831 - g_loss: -6594.8848
# Epoch 481/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -13.4457 - g_loss: -4919.69
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 62.71
# 84/84 [==============================] - 121s 1s/step - d_loss: -3.4205 - g_loss: -4894.5102
# Epoch 482/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -10.3637 - g_loss: -3070.94
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 37.2
# 84/84 [==============================] - 122s 1s/step - d_loss: -4.9677 - g_loss: -3062.8612
# Epoch 483/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -133.0671 - g_loss: -5794.72
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 65.77
# 84/84 [==============================] - 121s 1s/step - d_loss: -161.6878 - g_loss: -5810.2755
# Epoch 484/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 163.0695 - g_loss: -3624.29
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 82.85
# 84/84 [==============================] - 121s 1s/step - d_loss: 152.3536 - g_loss: -3599.6280
# Epoch 485/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 184.5137 - g_loss: -2037.77
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 47.67
# 84/84 [==============================] - 121s 1s/step - d_loss: 171.8451 - g_loss: -2028.7763
# Epoch 486/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -13.4505 - g_loss: -932.81
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 75.64
# 84/84 [==============================] - 122s 1s/step - d_loss: 36.6149 - g_loss: -955.4807
# Epoch 487/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 10.5446 - g_loss: 485.52
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 52.09
# 84/84 [==============================] - 121s 1s/step - d_loss: -4.1831 - g_loss: 512.5322
# Epoch 488/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -149.8547 - g_loss: 1033.12
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 67.33
# 84/84 [==============================] - 120s 1s/step - d_loss: -151.6041 - g_loss: 1048.7741
# Epoch 489/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 96.9207 - g_loss: 2673.677
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 80.82
# 84/84 [==============================] - 120s 1s/step - d_loss: 93.4946 - g_loss: 2709.4859
# Epoch 490/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 382.4721 - g_loss: 3528.04
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 69.43
# 84/84 [==============================] - 121s 1s/step - d_loss: 410.2725 - g_loss: 3475.1926
# Epoch 491/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 180.4397 - g_loss: 1995.76
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 102.84
# 84/84 [==============================] - 121s 1s/step - d_loss: 192.3983 - g_loss: 1998.7428
# Epoch 492/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 0.1069 - g_loss: 2608.278
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 115.74
# 84/84 [==============================] - 120s 1s/step - d_loss: 3.1497 - g_loss: 2569.9300
# Epoch 493/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -314.0399 - g_loss: 3437.64
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 114.16
# 84/84 [==============================] - 121s 1s/step - d_loss: -305.2958 - g_loss: 3413.7887
# Epoch 494/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -80.7270 - g_loss: 5453.02
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 68.6
# 84/84 [==============================] - 120s 1s/step - d_loss: -113.4173 - g_loss: 5411.1489
# Epoch 495/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 61.8155 - g_loss: 1864.41
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 99.85
# 84/84 [==============================] - 120s 1s/step - d_loss: 57.1899 - g_loss: 1851.9078
# Epoch 496/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -220.1308 - g_loss: 882.14
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 80.86
# 84/84 [==============================] - 121s 1s/step - d_loss: -269.3750 - g_loss: 825.3588
# Epoch 497/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -12.3254 - g_loss: 1563.11
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 89.65
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.2801 - g_loss: 1582.0133
# Epoch 498/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -357.2312 - g_loss: 1010.50
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 96.15
# 84/84 [==============================] - 120s 1s/step - d_loss: -349.5847 - g_loss: 1018.5247
# Epoch 499/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 146.9227 - g_loss: -2386.04
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 104.94
# 84/84 [==============================] - 120s 1s/step - d_loss: 148.9842 - g_loss: -2383.0705
# Epoch 500/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 161.2267 - g_loss: 2270.58
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 80.01
# 84/84 [==============================] - 120s 1s/step - d_loss: 151.6505 - g_loss: 2287.3244
# CPU times: user 8h 15min 10s, sys: 35min 46s, total: 8h 50min 56s
# Wall time: 16h 42min 46s

# %% [markdown]
# ### **GET FID_SCORES & PLOT IMAGES**

# %%
min_fid_unrounded = min(fid_scores)
min_fid_unrounded
# Out:
# 11.12

# %%
rounded_fid_scores = [np.round(i) for i in fid_scores]
min_fid = min(rounded_fid_scores)
latest_epoch_for_min_fid = 1 + max([epoch for epoch,fid_score in enumerate(rounded_fid_scores) if fid_score == min_fid])
print(latest_epoch_for_min_fid)
# Out:
# 291

# %%
# take best generator and plot 64 images with it
try:
    best_gen_file = f"CN_gen_291_(11.12).h30"
    best_generator = tf.keras.models.load_model(working_directory + "best_gen/" + best_gen_file)
    random_latent_vectors = tf.random.normal(shape=(64, noise_dim))
    generated_batch = best_generator(random_latent_vectors)
    synthetic_images = generated_batch.numpy()
    WGAN_CALLBACK().plot_multiple_images(synthetic_images, 8)                    
    plt.show()
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Plotting fid scores corresponding to each epoch
plt.figure(figsize = (30,5))
plt.plot(fid_scores, linewidth = 3, linestyle = '-', marker = 'o', markersize = 10, markerfacecolor='red', label = "FID_SCORE", color = 'k')
plt.axhline(y = min(fid_scores), color = 'green', linestyle = '--', label = 'minimum fid score')
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("FID_SCORE", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(fid_scores)),np.arange(1,len(fid_scores)+1),rotation=90)
plt.legend()
plt.title("FID SCORES FOR EACH EPOCH", fontsize = 20, fontweight = 'bold')
plt.show()

# %% [markdown]
# ### **PLOTTING GENERATOR VS DISCRIMINATOR LOSSES**

# %%
plt.figure(figsize = (30,5))
plt.plot(wgan_history.history['g_loss'], linewidth = 3, marker = 'o', markersize = 10, markerfacecolor='k',label = "Generator's Loss")
plt.plot(wgan_history.history['d_loss'], linewidth = 3, marker = '*', markersize = 10, markerfacecolor='k',label = "Discriminator's Loss")
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("LOSS", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(wgan_history.history['g_loss'])),np.arange(1,len(wgan_history.history['g_loss'])+1),rotation=90)
plt.legend()
plt.title("GENERATOR VS DISCRIMINATOR LOSS", fontsize = 20, fontweight = 'bold')
plt.show()
