# %% [markdown]
# # **WGANS WITH GRADIENT PENALTY FOR SYNTHESIZING ALZHEIMER'S MRI**

# %% [markdown]
# ### **IMPORTING THE NECESSARY DEPENDENCIES**

# %%
import os
import cv2
import random
import shutil
import warnings
import numpy as np
import seaborn as sns
from tqdm import tqdm
from numpy import cov
from PIL import Image
from numpy import trace
import tensorflow as tf
from numpy import asarray
from tensorflow import keras
from scipy.linalg import sqrtm
from numpy import iscomplexobj
import matplotlib.pyplot as plt
from numpy.random import randint
warnings.filterwarnings("ignore")
from tensorflow.keras import layers
from skimage.transform import resize
from IPython.display import FileLink
from keras.datasets.mnist import load_data
from keras.applications.inception_v3 import InceptionV3
from skimage.metrics import structural_similarity as ssim
from keras.applications.inception_v3 import preprocess_input
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# 2025-03-21 01:58:07.278528: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-21 01:58:07.420452: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-21 01:58:07.462715: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-21 01:58:08.119805: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/mlp/lib:/usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/lib/x86_64-linux-gnu/:/opt/conda/lib
# 2025-03-21 01:58:08.119931: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/envs/mlp/lib:/usr/local/cuda/lib64:/usr/local/nccl2/lib:/usr/local/cuda/extras/CUPTI/lib64:/usr/lib/x86_64-linux-gnu/:/opt/conda/lib
# 2025-03-21 01:58:08.119940: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ### **DECLARING PATHS AND VARIABLES**

# %%
tf.random.set_seed(5638)
random.seed(5638)

# %%
class_name = 'CN_local'
working_directory = '../../../synthetic/'+class_name+"/"
os.makedirs(working_directory, exist_ok=True)
dataset_path = '../../../localisation_outputs/train/'

noise_dim = 256
IMG_SHAPE = (128, 128, 1)
BATCH_SIZE = 32 #increase to speed up BUT will use up more memory

# %% [markdown]
# ### **PREPARING THE DATASET**

# %%
def prepare_dataset(class_name):
    # Path to the class where the real images are; in the orignal dataset
    class_path = dataset_path + class_name + '/'
    images = []
    for image_name in os.listdir(class_path):
        if random.uniform(0., 1.) < 0.6:
            images.append(cv2.imread(class_path + image_name, cv2.COLOR_BGR2GRAY))
    # images = [cv2.imread(class_path + image_name, cv2.COLOR_BGR2GRAY) for image_name in os.listdir(class_path)]
    resized_images = np.array([cv2.resize(i, (IMG_SHAPE[0],IMG_SHAPE[1])) for i in images]).astype(np.float32)
    # Reshape each sample to (128, 128, 1) and normalize the pixel values in the [-1, 1] range
    reshaped_images = resized_images.reshape(resized_images.shape[0], *IMG_SHAPE)
    dataset = (reshaped_images - 127.5) / 127.5
    return dataset

train_images = prepare_dataset(class_name)

# %%
def conv_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding="same",
    use_bias=True,
    use_bn=False,
    use_dropout=False,
    drop_value=0.5
    ):

    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

def upsample_block(
    x,
    filters,
    activation,
    kernel_size=(3, 3),
    strides=(1, 1),
    up_size=(2, 2),
    padding="same",
    use_bn=False,
    use_bias=True,
    use_dropout=False,
    drop_value=0.3
    ):

    x = layers.UpSampling2D(up_size)(x)
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding=padding, use_bias=use_bias)(x)
    if use_bn:
        x = layers.BatchNormalization()(x)
    if activation:
        x = activation(x)
    if use_dropout:
        x = layers.Dropout(drop_value)(x)
    return x

# %% [markdown]
# ### **CREATE THE DISCRIMINATOR** (the critic in the original WGAN)

# %%
def get_discriminator_model():
    # input = 128 x 128, output = 64 x 64 
    img_input = layers.Input(shape=IMG_SHAPE)
    x = conv_block(
        img_input,
        32,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=False,
        drop_value=0.3
        )
    
    # input = 64 x 64, output = 32 x 32
    x = conv_block(
        x,
        64,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 32 x 32, output = 16 x 16
    x = conv_block(
        x,
        128,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 16 x 16, output = 8 x 8
    x = conv_block(
        x,
        256,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 8 x 8, output = 4 x 4
    x = conv_block(
        x,
        512,
        activation=layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(2, 2),
        padding="same",
        use_bn=False,
        use_bias=True,
        use_dropout=True,
        drop_value=0.3
        )
    
    # input = 4 x 4, output = 1 
    x = layers.Flatten()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(1)(x)

    d_model = keras.models.Model(img_input, x, name="discriminator")
    return d_model

d_model = get_discriminator_model()
# tf.keras.utils.plot_model(d_model, to_file='discriminator.jpg', show_shapes=True, rankdir='TB')
# Out:
# 2025-03-21 01:58:09.348965: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-21 01:58:09.482682: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20750 MB memory:  -> device: 0, name: NVIDIA L4, pci bus id: 0000:00:03.0, compute capability: 8.9

# %% [markdown]
# ### **CREATE THE GENERATOR**

# %%
def get_generator_model():
    # input = (noise_dim, ), output = 4 x 4
    noise = layers.Input(shape=(noise_dim,))
    x = layers.Dense(4 * 4 * 2048, use_bias=False)(noise)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU(0.2)(x)
    x = layers.Reshape((4, 4, 2048))(x)
    
    # input = 4 x 4, output = 8 x 8
    x = upsample_block(
        x,
        1024,
        layers.LeakyReLU(0.2),
        kernel_size =(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 8 x 8, output = 16 x 16
    x = upsample_block(
        x,
        512,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 16 x 16, output = 32 x 32
    x = upsample_block(
        x,
        256,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 32 x 32, output = 64 x 64
    x = upsample_block(
        x,
        128,
        layers.LeakyReLU(0.2),
        kernel_size=(5, 5),
        strides=(1, 1),
        use_bias=False,
        use_bn=True,
        padding="same",
        use_dropout=False
    )
    
    # input = 64 x 64, output = 128 x 128
    x = upsample_block(x, 1, layers.Activation("tanh"), strides=(1, 1), use_bias=False, use_bn=True)
    
    g_model = keras.models.Model(noise, x, name="generator")
    return g_model


g_model = get_generator_model()
# tf.keras.utils.plot_model(g_model, to_file='generator.jpg', show_shapes=True, rankdir='TB')

# %% [markdown]
# ### **CREATE THE WGAN-GP MODEL**
#
# Now that we have defined our generator and discriminator, it's time to implement the WGAN-GP model. We will also override the train_step for training.

# %%
class WGAN(keras.Model):
    def __init__(
        self,
        discriminator,
        generator,
        latent_dim,
        discriminator_extra_steps=5,
        gp_weight=10.0,
    ):
        super().__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.d_steps = discriminator_extra_steps
        self.gp_weight = gp_weight

    def compile(self, d_optimizer, g_optimizer, d_loss_fn, g_loss_fn):
        super().compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss_fn = d_loss_fn
        self.g_loss_fn = g_loss_fn 

    def gradient_penalty(self, batch_size, real_images, fake_images):
        """Calculates the gradient penalty.

        This loss is calculated on an interpolated image
        and added to the discriminator loss.
        """
        # Get the interpolated image
        alpha = tf.random.normal([batch_size, 1, 1, 1], 0.0, 1.0)
        diff = fake_images - real_images
        interpolated = real_images + alpha * diff

        with tf.GradientTape() as gp_tape:
            gp_tape.watch(interpolated)
            # 1. Get the discriminator output for this interpolated image.
            pred = self.discriminator(interpolated, training=True)

        # 2. Calculate the gradients w.r.t to this interpolated image.
        grads = gp_tape.gradient(pred, [interpolated])[0]
        # 3. Calculate the norm of the gradients.
        norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2, 3]))
        gp = tf.reduce_mean((norm - 1.0) ** 2)
        return gp

    def train_step(self, real_images):
        if isinstance(real_images, tuple):
            real_images = real_images[0]

        # Get the batch size
        batch_size = tf.shape(real_images)[0]

        # For each batch, we are going to perform the
        # following steps as laid out in the original paper:
        # 1. Train the generator and get the generator loss
        # 2. Train the discriminator and get the discriminator loss
        # 3. Calculate the gradient penalty
        # 4. Multiply this gradient penalty with a constant weight factor
        # 5. Add the gradient penalty to the discriminator loss
        # 6. Return the generator and discriminator losses as a loss dictionary

        # Train the discriminator first. 
        for i in range(self.d_steps):
            # Get the latent vector
            random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
            with tf.GradientTape() as tape:
                # Generate fake images from the latent vector
                fake_images = self.generator(random_latent_vectors, training=True)
                # Get the logits for the fake images
                fake_logits = self.discriminator(fake_images, training=True)
                # Get the logits for the real images
                real_logits = self.discriminator(real_images, training=True)

                # Calculate the discriminator loss using the fake and real image logits
                d_cost = self.d_loss_fn(real_img=real_logits, fake_img=fake_logits)
                # Calculate the gradient penalty
                gp = self.gradient_penalty(batch_size, real_images, fake_images)
                # Add the gradient penalty to the original discriminator loss
                d_loss = d_cost + gp * self.gp_weight

            # Get the gradients w.r.t the discriminator loss
            d_gradient = tape.gradient(d_loss, self.discriminator.trainable_variables)
            # Update the weights of the discriminator using the discriminator optimizer
            self.d_optimizer.apply_gradients(
                zip(d_gradient, self.discriminator.trainable_variables)
            )

        # Train the generator
        # Get the latent vector
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        with tf.GradientTape() as tape:
            # Generate fake images using the generator
            generated_images = self.generator(random_latent_vectors, training=True)
            # Get the discriminator logits for fake images
            gen_img_logits = self.discriminator(generated_images, training=True)
            # Calculate the generator loss
            g_loss = self.g_loss_fn(gen_img_logits)

        # Get the gradients w.r.t the generator loss
        gen_gradient = tape.gradient(g_loss, self.generator.trainable_variables)
        # Update the weights of the generator using the generator optimizer
        self.g_optimizer.apply_gradients(
            zip(gen_gradient, self.generator.trainable_variables)
        )

        return {"d_loss": d_loss, "g_loss": g_loss}

# %% [markdown]
# ### **CREATE A CUSTOM CALLBACK**

# %%
def clear_workspace(directory):
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
class WGAN_CALLBACK(keras.callbacks.Callback):
    def __init__(self, n_epochs = 20, batch_size = BATCH_SIZE, latent_vector_dim = 128, fid_scores_filepath='fid_scores.npy'):
        self.batch_size = batch_size
        self.noise_dim = latent_vector_dim
        self.fid_scores = []
        self.n_epochs = n_epochs
        self.fid_scores_filepath = fid_scores_filepath
        
        # Load FID scores if they exist
        if os.path.exists(self.fid_scores_filepath):
            self.fid_scores = np.load(self.fid_scores_filepath, allow_pickle=True).tolist()
        
    @property
    def get_fid_scores(self):
        return self.fid_scores
    
    def plot_multiple_images(self,images, n_cols):
        n_cols = n_cols or len(images)
        n_rows = len(images) // n_cols
        if images.shape[-1] == 1:
            images = np.squeeze(images, axis=-1)
        plt.figure(figsize=(n_cols, n_rows))   
        plt.tight_layout()
        plt.suptitle('BEST GENERATOR', fontweight = 'bold')
        for index, image in enumerate(images):
            plt.subplot(n_rows, n_cols, index + 1)
            plt.imshow(image, cmap="gray")
            plt.axis("off")
    
    def calculate_fid(self, generated_images, real_images):
        # scale an array of images to a new size
        def scale_images(images, new_shape):
            images_list = []
            for image in images:
                # resize with nearest neighbor interpolation
                resized_image = cv2.cvtColor(cv2.resize(image, new_shape, cv2.INTER_NEAREST), cv2.COLOR_GRAY2BGR)
                # store the resized images
                images_list.append(resized_image)
            return asarray(images_list)
        # prepare the inception v3 model
        model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))
        # resize images
        generated_images = scale_images(generated_images, (299,299))
        real_images = scale_images(real_images, (299,299))
        # pre-process images
        generated_images = preprocess_input(generated_images)
        real_images = preprocess_input(real_images)
        # calculate feature embeddings
        embeddings1 = model.predict(generated_images)
        embeddings2 = model.predict(real_images)
        # calculate mean and covariance statistics
        mu1, sigma1 = embeddings1.mean(axis=0), cov(embeddings1, rowvar=False)
        mu2, sigma2 = embeddings2.mean(axis=0), cov(embeddings2, rowvar=False)
        # calculate sum squared difference between means
        ssdiff = np.sum((mu1 - mu2)**2.0)
        # calculate sqrt of product between cov
        covmean = sqrtm(sigma1.dot(sigma2))
        # check and correct imaginary numbers from sqrt
        if iscomplexobj(covmean):
            covmean = covmean.real
        # calculate fid score
        fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
        return np.round(fid,2)

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(shape=(self.batch_size, self.noise_dim))
        generator = self.model.generator
        generated_batch = generator(random_latent_vectors)
        generated_batch = generated_batch.numpy()
        random_number = np.random.randint(train_images.shape[0] - self.batch_size)
        real_batch = train_images[random_number: random_number + self.batch_size]
        current_fid = self.calculate_fid(generated_batch, real_batch)
        self.fid_scores.append(current_fid)  
        print('\033[1mFID SCORE: {}\033[0m'.format(current_fid))
        
        self.model.save_weights(working_directory + "_wgan_weights.h5")
        
        if current_fid <= min(self.fid_scores): #originally 5 as threshold of og paper (got a score of 4.28)
            save_dir = working_directory + "best_gen/"
            clear_workspace(save_dir)
            generator.save(save_dir + "_gen_{}_({}).h30".format(epoch+1,current_fid),save_format='h5')
            print("Generator Saved")
        
        # Save FID scores to a file after each epoch
        np.save(self.fid_scores_filepath, np.array(self.fid_scores))

# %%
def download_synthetic_images(generator, number_of_images, class_name = 'None'):
    clear_workspace(working_directory)
    # Making sure that no two images have the same name
    counter = 1
    # To check if folder is full
    folder_full = False
    # Folder path to store synthetic images. Folder name is the same as the class name which is inside the working directory
    folder_path = working_directory + 'synthetic_' + class_name + '/'
    images_folder = os.path.join(folder_path)
    # Create this folder if it doesn't exists, otherwise do nothing
    os.makedirs(images_folder, exist_ok=True)
    # Unless I get the desired number of good quality synthetic images in this folder, keep on generating images
    pbar = tqdm(total=number_of_images, position=0, leave=True)
    while len(os.listdir(images_folder)) < number_of_images:
        # Generate a batch of synthetic images
        random_latent_vectors = tf.random.normal(shape=(BATCH_SIZE, noise_dim))
        synthetic_images_batch = generator(random_latent_vectors)
        # Convert tensors to numpy arrays 
        synthetic_images_batch = synthetic_images_batch.numpy()
        # Convert the scale of images from (-1,1) to (0,255) and data type from float to integers 
        for image in synthetic_images_batch:
            image = (image * 127.5) + 127.5
            image = image.astype(np.uint8)
            # If it is a single channel image then save it as it is
            if image.shape[2] == 1:
                cv2.imwrite(images_folder + class_name + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If it is a 3 channel image then first convert it to grayscale and then save it
            elif image.shape[2] == 3:
                gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                cv2.imwrite(images_folder + ' ({}).jpg'.format(counter), image)
                pbar.update(1)
                # Incrementing the counter so that no two images have the same name
                counter += 1
            # If the folder now has the number of desired images, then come out of the loop
            if len(os.listdir(images_folder)) >= number_of_images:
                folder_full = True
                break
        if folder_full == True:
                break
            
    # Generate a link from where I can download the synthetic images
    os.system('zip -r synthetic_images.zip {} >/dev/null 2>&1'.format(folder_path))
    return FileLink(r'synthetic_images.zip')

# %% [markdown]
# ### **TRAIN THE END TO END MODEL**

# %%
def train_wgans(dataset, n_epochs, batch_size = BATCH_SIZE, optimizer = 'adam', gen_lr = 0.0001, dis_lr = 0.0001, checkpoint_dir="wgan_checkpoint",
                resume_training=False):
    if not resume_training:
        clear_workspace(working_directory)
        os.makedirs(working_directory + "best_gen/", exist_ok=True) 
        if os.path.exists('fid_scores.npy'):
            os.remove('fid_scores.npy')
    assert optimizer in ['adam','rmsprop', 'nadam'], "Invalid optimizer. Valid options are 'adam' or 'rmsprop' or 'nadam'."
    if optimizer == 'adam':
        generator_optimizer = keras.optimizers.Adam(learning_rate = gen_lr, beta_1=0, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Adam(learning_rate = dis_lr, beta_1=0, beta_2=0.9)
    elif optimizer == 'rmsprop':
        generator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = gen_lr)
        discriminator_optimizer = tf.keras.optimizers.RMSprop(learning_rate = dis_lr)
    elif optimizer == 'nadam':
        generator_optimizer = keras.optimizers.Nadam(learning_rate = gen_lr, beta_1=0.5, beta_2=0.9)
        discriminator_optimizer = keras.optimizers.Nadam(learning_rate = dis_lr, beta_1=0.5, beta_2=0.9)

    # Define the loss functions for the discriminator,
    # which should be (fake_loss - real_loss).
    # We will add the gradient penalty later to this loss function.
    def discriminator_loss(real_img, fake_img):
        real_loss = tf.reduce_mean(real_img)
        fake_loss = tf.reduce_mean(fake_img)
        return fake_loss - real_loss

    # Define the loss functions for the generator.
    def generator_loss(fake_img):
        return -tf.reduce_mean(fake_img)

    # Instantiate the customer `WGAN_CALLBACK` Keras callback.
    custom_callback = WGAN_CALLBACK(n_epochs, batch_size = BATCH_SIZE, latent_vector_dim = noise_dim)

    # Get the wgan model
    wgan = WGAN(discriminator = d_model, generator = g_model, latent_dim = noise_dim, discriminator_extra_steps=5)

    # Compile the wgan model
    wgan.compile(
        d_optimizer = discriminator_optimizer,
        g_optimizer = generator_optimizer,
        g_loss_fn = generator_loss,
        d_loss_fn = discriminator_loss
    )
    
    # If resuming training, load the previously saved model
    checkpoint_path = working_directory + "MoI_wgan_weights.h5"
    if resume_training and os.path.exists(checkpoint_path):
        print(f"Resuming training from checkpoint: {checkpoint_path}")
        wgan.load_weights(checkpoint_path)

    # Start training
    wgan_history = wgan.fit(dataset, batch_size = BATCH_SIZE, epochs = n_epochs, callbacks=[custom_callback])
    fid_scores = custom_callback.get_fid_scores
    
    return wgan_history, fid_scores

# %%
# %%time
wgan_history, fid_scores = train_wgans(dataset = train_images, 
                                        n_epochs = 500, #originally 2000; when resuming training, will train for an additional number of epochs based on what put here
                                        optimizer = 'adam', 
                                        gen_lr = 0.0001, 
                                        dis_lr = 0.0001,
                                        checkpoint_dir="wgan_checkpoint",
                                        resume_training=False) #CHECK: false if first time running, true if resuming from checkpoint
# Out:
# Epoch 1/500
# 2025-03-21 01:58:20.717440: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-03-21 01:58:20.744963: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8900
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 12.75
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:1
#
# Cell In[12], line 52, in train_wgans(dataset, n_epochs, batch_size, optimizer, gen_lr, dis_lr, checkpoint_dir, resume_training)
#      49     wgan.load_weights(checkpoint_path)
#      51 # Start training
# ---> 52 wgan_history = wgan.fit(dataset, batch_size = BATCH_SIZE, epochs = n_epochs, callbacks=[custom_callback])
#      53 fid_scores = custom_callback.get_fid_scores
#      55 return wgan_history, fid_scores
#
# File /opt/conda/envs/mlp/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# Cell In[10], line 80, in WGAN_CALLBACK.on_epoch_end(self, epoch, logs)
#      78 if current_fid <= min(self.fid_scores): #originally 5 as threshold of og paper (got a score of 4.28)
#      79     save_dir = working_directory + "best_gen/" + class_name +"/"
# ---> 80     clear_workspace(save_dir)
#      81     generator.save(save_dir + "_gen_{}_({}).h30".format(epoch+1,current_fid),save_format='h5')
#      82     print("Generator Saved")
#
# Cell In[9], line 2, in clear_workspace(directory)
#       1 def clear_workspace(directory):
# ----> 2     for filename in os.listdir(directory):
#       3         file_path = os.path.join(directory, filename)
#       4         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../synthetic/CN_local/best_gen/CN_local/'
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 44.55
# 84/84 [==============================] - 120s 1s/step - d_loss: -40.1632 - g_loss: 147.0686
# Epoch 62/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -38.8942 - g_loss: 132.59
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 51.77
# 84/84 [==============================] - 120s 1s/step - d_loss: -38.9153 - g_loss: 132.6968
# Epoch 63/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -38.8795 - g_loss: 135.63
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 52.61
# 84/84 [==============================] - 120s 1s/step - d_loss: -39.0179 - g_loss: 135.8392
# Epoch 64/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -36.7011 - g_loss: 143.46
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 41.54
# Generator Saved
# 84/84 [==============================] - 121s 1s/step - d_loss: -36.6868 - g_loss: 143.0950
# Epoch 65/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -36.2353 - g_loss: 147.14
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 34.3
# Generator Saved
# 84/84 [==============================] - 120s 1s/step - d_loss: -36.2111 - g_loss: 147.0227
# FID SCORE: 49.52
# 84/84 [==============================] - 120s 1s/step - d_loss: -26.7866 - g_loss: 108.8484
# Epoch 78/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -25.8979 - g_loss: 94.37
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 50.48
# 84/84 [==============================] - 120s 1s/step - d_loss: -25.9075 - g_loss: 94.5148
# Epoch 79/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -24.5806 - g_loss: 96.52
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 43.08
# 84/84 [==============================] - 120s 1s/step - d_loss: -24.7054 - g_loss: 96.4301
# Epoch 80/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -24.7808 - g_loss: 96.75
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 54.84
# 84/84 [==============================] - 121s 1s/step - d_loss: -24.8238 - g_loss: 96.6909
# Epoch 81/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -23.6186 - g_loss: 93.95
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 36.36
# 84/84 [==============================] - 120s 1s/step - d_loss: -23.6017 - g_loss: 94.0616
# Epoch 82/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -23.3934 - g_loss: 91.13
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 47.91
# 84/84 [==============================] - 120s 1s/step - d_loss: -23.3938 - g_loss: 91.2311
# Epoch 83/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -22.2930 - g_loss: 90.68
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 17.37
# Generator Saved
# 84/84 [==============================] - 121s 1s/step - d_loss: -22.1545 - g_loss: 90.6213
# Epoch 84/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -23.1281 - g_loss: 87.89
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 28.82
# 84/84 [==============================] - 120s 1s/step - d_loss: -23.1023 - g_loss: 87.7480
# Epoch 85/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -22.3029 - g_loss: 84.24
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 52.62
# 84/84 [==============================] - 119s 1s/step - d_loss: -22.2690 - g_loss: 84.0870
# Epoch 86/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -21.1347 - g_loss: 80.80
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 47.83
# 84/84 [==============================] - 120s 1s/step - d_loss: -20.9925 - g_loss: 80.8551
# Epoch 87/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -21.1069 - g_loss: 74.78
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 43.97
# 84/84 [==============================] - 120s 1s/step - d_loss: -21.3371 - g_loss: 74.8828
# Epoch 88/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -20.5272 - g_loss: 71.20
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 32.19
# 84/84 [==============================] - 120s 1s/step - d_loss: -20.5266 - g_loss: 71.2914
# Epoch 89/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -20.6192 - g_loss: 69.00
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 38.15
# 84/84 [==============================] - 121s 1s/step - d_loss: -20.5880 - g_loss: 68.7535
# Epoch 90/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -20.4798 - g_loss: 68.50
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 23.88
# 84/84 [==============================] - 120s 1s/step - d_loss: -20.4389 - g_loss: 68.4515
# Epoch 91/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -19.2529 - g_loss: 62.20
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 33.87
# 84/84 [==============================] - 120s 1s/step - d_loss: -19.2095 - g_loss: 62.1662
# Epoch 92/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -19.8300 - g_loss: 62.69
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 32.65
# 84/84 [==============================] - 120s 1s/step - d_loss: -19.7229 - g_loss: 62.5304
# Epoch 93/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -19.1075 - g_loss: 60.12
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 41.3
# 84/84 [==============================] - 119s 1s/step - d_loss: -19.1540 - g_loss: 60.1182
# Epoch 94/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -18.5748 - g_loss: 56.70
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 31.72
# 84/84 [==============================] - 120s 1s/step - d_loss: -18.6399 - g_loss: 56.7013
# Epoch 95/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -17.8794 - g_loss: 53.62
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 34.13
# 84/84 [==============================] - 120s 1s/step - d_loss: -17.8809 - g_loss: 53.5423
# Epoch 96/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -17.8051 - g_loss: 52.99
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 24.06
# 84/84 [==============================] - 120s 1s/step - d_loss: -17.7527 - g_loss: 52.9782
# Epoch 97/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -17.7192 - g_loss: 51.48
# 1/1 [==============================] - 0s 58ms/step
# FID SCORE: 32.55
# 84/84 [==============================] - 120s 1s/step - d_loss: -17.8460 - g_loss: 51.5356
# Epoch 98/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -17.5985 - g_loss: 51.42
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 16.81
# Generator Saved
# 84/84 [==============================] - 120s 1s/step - d_loss: -17.6291 - g_loss: 51.4669
# Epoch 99/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -16.2753 - g_loss: 44.53
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 22.2
# 84/84 [==============================] - 120s 1s/step - d_loss: -16.2468 - g_loss: 44.5478
# Epoch 100/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -16.8089 - g_loss: 46.31
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 34.02
# 84/84 [==============================] - 120s 1s/step - d_loss: -16.7129 - g_loss: 46.2622
# Epoch 101/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -16.5325 - g_loss: 43.55
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 30.76
# 84/84 [==============================] - 120s 1s/step - d_loss: -16.5084 - g_loss: 43.4581
# Epoch 102/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -15.3953 - g_loss: 41.04
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 35.66
# 84/84 [==============================] - 119s 1s/step - d_loss: -15.3420 - g_loss: 41.0834
# Epoch 103/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -15.3196 - g_loss: 41.28
# 1/1 [==============================] - 0s 63ms/step
# FID SCORE: 22.88
# 84/84 [==============================] - 120s 1s/step - d_loss: -15.3326 - g_loss: 41.3056
# Epoch 104/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -15.7939 - g_loss: 40.95
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 34.66
# 84/84 [==============================] - 120s 1s/step - d_loss: -15.7644 - g_loss: 41.0733
# Epoch 105/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -15.0336 - g_loss: 39.54
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 35.77
# 84/84 [==============================] - 120s 1s/step - d_loss: -15.0219 - g_loss: 39.5656
# Epoch 106/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -14.5400 - g_loss: 40.96
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 25.84
# 84/84 [==============================] - 120s 1s/step - d_loss: -14.5226 - g_loss: 40.9725
# Epoch 107/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -14.8614 - g_loss: 39.45
# 1/1 [==============================] - 0s 83ms/step
# FID SCORE: 21.86
# 84/84 [==============================] - 120s 1s/step - d_loss: -14.9039 - g_loss: 39.3830
# Epoch 108/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -14.7093 - g_loss: 38.52
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 25.29
# 84/84 [==============================] - 121s 1s/step - d_loss: -14.6663 - g_loss: 38.5652
# Epoch 109/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -13.2647 - g_loss: 35.23
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 31.65
# 84/84 [==============================] - 120s 1s/step - d_loss: -13.2487 - g_loss: 35.2626
# Epoch 110/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -13.5552 - g_loss: 33.70
# 1/1 [==============================] - 0s 74ms/step
# FID SCORE: 20.96
# 84/84 [==============================] - 120s 1s/step - d_loss: -13.5447 - g_loss: 33.6665
# Epoch 111/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -14.6930 - g_loss: 35.04
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 27.83
# 84/84 [==============================] - 120s 1s/step - d_loss: -14.7270 - g_loss: 35.1172
# Epoch 112/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -13.5324 - g_loss: 35.85
# 1/1 [==============================] - 0s 81ms/step
# FID SCORE: 20.91
# 1/1 [==============================] - 0s 83ms/step
# FID SCORE: 23.63
# 84/84 [==============================] - 120s 1s/step - d_loss: -11.5760 - g_loss: 22.2666
# Epoch 125/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -11.3391 - g_loss: 21.76
# 1/1 [==============================] - 0s 81ms/step
# FID SCORE: 25.14
# 84/84 [==============================] - 120s 1s/step - d_loss: -11.4025 - g_loss: 21.7236
# Epoch 126/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -11.4212 - g_loss: 21.92
# 1/1 [==============================] - 0s 80ms/step
# FID SCORE: 18.97
# 84/84 [==============================] - 120s 1s/step - d_loss: -11.3764 - g_loss: 21.8823
# Epoch 127/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -11.2204 - g_loss: 19.86
# 1/1 [==============================] - 0s 79ms/step
# FID SCORE: 21.26
# 84/84 [==============================] - 120s 1s/step - d_loss: -11.2048 - g_loss: 19.8076
# Epoch 128/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -11.0663 - g_loss: 19.22
# 1/1 [==============================] - 0s 82ms/step
# FID SCORE: 33.4
# 84/84 [==============================] - 120s 1s/step - d_loss: -11.1547 - g_loss: 19.1495
# Epoch 129/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -11.6115 - g_loss: 17.44
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 22.54
# 84/84 [==============================] - 120s 1s/step - d_loss: -11.6374 - g_loss: 17.3384
# Epoch 130/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -11.1227 - g_loss: 19.18
# 1/1 [==============================] - 0s 79ms/step
# FID SCORE: 12.68
# Generator Saved
# 84/84 [==============================] - 121s 1s/step - d_loss: -11.0205 - g_loss: 19.2554
# Epoch 131/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -10.6849 - g_loss: 16.32
# 1/1 [==============================] - 0s 82ms/step
# FID SCORE: 20.58
# 84/84 [==============================] - 119s 1s/step - d_loss: -10.9211 - g_loss: 16.4904
# Epoch 132/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -10.6921 - g_loss: 16.35
# 1/1 [==============================] - 0s 80ms/step
# FID SCORE: 18.83
# 84/84 [==============================] - 120s 1s/step - d_loss: -10.8995 - g_loss: 16.3990
# Epoch 133/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -10.8004 - g_loss: 16.98
# 1/1 [==============================] - 0s 76ms/step
# FID SCORE: 17.06
# 84/84 [==============================] - 119s 1s/step - d_loss: -10.8357 - g_loss: 16.9868
# Epoch 134/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -10.5544 - g_loss: 18.90
# 1/1 [==============================] - 0s 77ms/step
# FID SCORE: 20.18
# 84/84 [==============================] - 120s 1s/step - d_loss: -10.5765 - g_loss: 18.9559
# Epoch 135/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -10.1599 - g_loss: 16.15
# 1/1 [==============================] - 0s 79ms/step
# FID SCORE: 25.62
# 84/84 [==============================] - 120s 1s/step - d_loss: -10.1990 - g_loss: 16.3381
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 18.5
# 84/84 [==============================] - 120s 1s/step - d_loss: -9.1354 - g_loss: 12.0804
# Epoch 160/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -9.2788 - g_loss: 4.94
# 1/1 [==============================] - 0s 58ms/step
# FID SCORE: 17.53
# 84/84 [==============================] - 120s 1s/step - d_loss: -9.2872 - g_loss: 5.0000
# Epoch 161/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -9.0684 - g_loss: 10.45
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 21.75
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.9176 - g_loss: 10.4580
# Epoch 162/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -9.4740 - g_loss: 7.89
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 26.1
# 84/84 [==============================] - 120s 1s/step - d_loss: -9.4863 - g_loss: 7.8593
# Epoch 163/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.3781 - g_loss: 3.16
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 13.78
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.3514 - g_loss: 3.1987
# Epoch 164/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.6276 - g_loss: 7.00
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 21.81
# 84/84 [==============================] - 121s 1s/step - d_loss: -8.6312 - g_loss: 7.0053
# Epoch 165/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -9.2170 - g_loss: 4.29
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 18.19
# 84/84 [==============================] - 120s 1s/step - d_loss: -9.4653 - g_loss: 4.2992
# Epoch 166/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.9145 - g_loss: 2.32
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 18.27
# 84/84 [==============================] - 119s 1s/step - d_loss: -8.8739 - g_loss: 2.3532
# Epoch 167/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.8097 - g_loss: 6.36
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 15.11
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.8037 - g_loss: 6.4723
# Epoch 168/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.0753 - g_loss: 5.10
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 14.55
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.0918 - g_loss: 5.1903
# Epoch 169/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.3140 - g_loss: 5.96
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 14.32
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.3263 - g_loss: 5.9476
# Epoch 170/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.4544 - g_loss: 3.66
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 24.55
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.4669 - g_loss: 3.5058
# Epoch 171/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.9350 - g_loss: 7.26
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 15.34
# 84/84 [==============================] - 121s 1s/step - d_loss: -8.8582 - g_loss: 7.2985
# Epoch 172/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.8512 - g_loss: 9.00
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 16.22
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.8661 - g_loss: 8.9867
# Epoch 173/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.4104 - g_loss: 8.34
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 16.03
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.3836 - g_loss: 8.3658
# Epoch 174/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.7171 - g_loss: 7.53
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 26.73
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.6877 - g_loss: 7.4816
# Epoch 175/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.6143 - g_loss: 3.33
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 19.64
# 84/84 [==============================] - 119s 1s/step - d_loss: -7.6542 - g_loss: 3.4551
# Epoch 176/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.7328 - g_loss: 11.26
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 22.26
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.9830 - g_loss: 11.3243
# Epoch 177/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.0024 - g_loss: 9.27
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 16.01
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.9386 - g_loss: 9.2192
# Epoch 178/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.9465 - g_loss: 4.91
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 20.05
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.8845 - g_loss: 4.9200
# Epoch 179/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.0324 - g_loss: 7.71
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 15.29
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.9848 - g_loss: 7.6859
# Epoch 180/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.1417 - g_loss: 7.15
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 14.65
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.1875 - g_loss: 7.2566
# Epoch 181/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.0885 - g_loss: 6.72
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 15.3
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.1581 - g_loss: 6.7014
# Epoch 182/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.2083 - g_loss: 5.46
# 1/1 [==============================] - 0s 59ms/step
# FID SCORE: 12.83
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.1667 - g_loss: 5.5384
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.7229 - g_loss: 4.2677
# Epoch 195/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.0482 - g_loss: 4.18
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 19.03
# 84/84 [==============================] - 121s 1s/step - d_loss: -8.1162 - g_loss: 4.1381
# Epoch 196/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.5839 - g_loss: 3.69
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 16.77
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.6153 - g_loss: 3.6358
# Epoch 197/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.3178 - g_loss: 6.68
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 18.16
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.2905 - g_loss: 6.6669
# Epoch 198/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.0765 - g_loss: 2.83
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 25.17
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.1319 - g_loss: 2.8374
# Epoch 199/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.1480 - g_loss: 1.05
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 17.4
# 84/84 [==============================] - 121s 1s/step - d_loss: -8.3327 - g_loss: 1.1291
# Epoch 200/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.0588 - g_loss: 0.140
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 18.33
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.2986 - g_loss: 0.4361
# Epoch 201/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.2771 - g_loss: -0.58
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 21.29
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.2056 - g_loss: -0.5562
# Epoch 202/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.0950 - g_loss: 5.07
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 13.07
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.1362 - g_loss: 5.0935
# Epoch 203/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.1098 - g_loss: 5.10
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 17.96
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.1578 - g_loss: 5.0490
# Epoch 204/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.7757 - g_loss: 1.26
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 18.01
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.8119 - g_loss: 1.3639
# Epoch 205/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.9326 - g_loss: 2.10
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 14.47
# 84/84 [==============================] - 120s 1s/step - d_loss: -6.9384 - g_loss: 2.1583
# Epoch 206/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.3901 - g_loss: -0.71
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 16.84
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.3255 - g_loss: -0.7228
# Epoch 207/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.7360 - g_loss: 0.112
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 19.11
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.7723 - g_loss: 0.2348
# Epoch 208/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.1240 - g_loss: -1.75
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 15.97
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.1788 - g_loss: -1.8356
# Epoch 209/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.1619 - g_loss: -2.39
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 13.61
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.0785 - g_loss: -2.3606
# Epoch 210/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.1935 - g_loss: -0.08
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 16.65
# 84/84 [==============================] - 121s 1s/step - d_loss: -8.1570 - g_loss: -0.0605
# Epoch 211/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.7096 - g_loss: -1.09
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 15.48
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.6874 - g_loss: -1.1112
# Epoch 212/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.2172 - g_loss: 0.25
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 11.86
# Generator Saved
# 84/84 [==============================] - 122s 1s/step - d_loss: -7.2643 - g_loss: 0.3113
# Epoch 213/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.0376 - g_loss: 1.20
# 1/1 [==============================] - 0s 58ms/step
# FID SCORE: 13.34
# 84/84 [==============================] - 122s 1s/step - d_loss: -7.0336 - g_loss: 1.2299
# Epoch 214/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.7114 - g_loss: 6.87
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 20.97
# 84/84 [==============================] - 121s 1s/step - d_loss: -6.7120 - g_loss: 6.9419
# Epoch 215/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.0008 - g_loss: 8.16
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 14.84
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.9207 - g_loss: 8.1782
# Epoch 216/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.7484 - g_loss: 4.05
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 18.72
# 84/84 [==============================] - 121s 1s/step - d_loss: -6.6664 - g_loss: 4.0724
# Epoch 217/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.5842 - g_loss: 2.41
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 12.55
# 84/84 [==============================] - 121s 1s/step - d_loss: -6.5573 - g_loss: 2.2662
# Epoch 218/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.0601 - g_loss: 1.53
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 15.14
# 84/84 [==============================] - 121s 1s/step - d_loss: -6.0225 - g_loss: 1.6139
# Epoch 219/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.1591 - g_loss: 3.71
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 24.81
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.3039 - g_loss: 3.5711
# Epoch 220/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.7709 - g_loss: 0.81
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 21.55
# 84/84 [==============================] - 122s 1s/step - d_loss: -6.8431 - g_loss: 0.8121
# Epoch 221/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -8.3358 - g_loss: 1.87
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 15.49
# 84/84 [==============================] - 121s 1s/step - d_loss: -8.3360 - g_loss: 1.8415
# Epoch 222/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.2626 - g_loss: 2.61
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 17.54
# 84/84 [==============================] - 120s 1s/step - d_loss: -6.2876 - g_loss: 2.5240
# Epoch 223/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.4129 - g_loss: 0.87
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 14.58
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.5130 - g_loss: 0.9300
# Epoch 224/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.8277 - g_loss: -3.63
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 13.98
# 84/84 [==============================] - 120s 1s/step - d_loss: -6.8662 - g_loss: -3.7472
# Epoch 225/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.6211 - g_loss: -4.87
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 14.59
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.6931 - g_loss: -4.9361
# Epoch 226/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.3990 - g_loss: -2.24
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 15.71
# 84/84 [==============================] - 120s 1s/step - d_loss: -7.3966 - g_loss: -2.2273
# Epoch 227/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.4352 - g_loss: -0.57
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 15.89
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.5339 - g_loss: -0.6785
# Epoch 228/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.3756 - g_loss: -2.71
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 17.75
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.4272 - g_loss: -2.6296
# Epoch 229/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.5592 - g_loss: -2.14
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 13.6
# 84/84 [==============================] - 121s 1s/step - d_loss: -6.5548 - g_loss: -1.9814
# Epoch 230/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.3951 - g_loss: -2.08
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 9.44
# Generator Saved
# 84/84 [==============================] - 122s 1s/step - d_loss: -6.5251 - g_loss: -2.1872
# Epoch 231/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.2363 - g_loss: -3.32
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 13.93
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.3662 - g_loss: -3.3602
# Epoch 232/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.1963 - g_loss: -2.00
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 23.68
# 84/84 [==============================] - 121s 1s/step - d_loss: -6.2241 - g_loss: -1.9830
# Epoch 233/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.3445 - g_loss: 0.72
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 13.82
# 84/84 [==============================] - 121s 1s/step - d_loss: -6.3316 - g_loss: 0.7439
# Epoch 234/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.3081 - g_loss: -1.91
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 17.8
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.3329 - g_loss: -1.9566
# Epoch 235/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.9468 - g_loss: -0.22
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 15.04
# 84/84 [==============================] - 121s 1s/step - d_loss: -6.8437 - g_loss: -0.2709
# Epoch 236/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -5.9190 - g_loss: -3.65
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 14.24
# 84/84 [==============================] - 121s 1s/step - d_loss: -5.8965 - g_loss: -3.6728
# Epoch 237/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.2905 - g_loss: -0.93
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 14.14
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.2640 - g_loss: -0.9756
# Epoch 238/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -7.1692 - g_loss: -2.93
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 19.44
# 84/84 [==============================] - 121s 1s/step - d_loss: -7.2350 - g_loss: -2.8216
# Epoch 239/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.9633 - g_loss: 0.46
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 16.32
# ...
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 61.54
# 84/84 [==============================] - 120s 1s/step - d_loss: -81.6349 - g_loss: -187.2068
# Epoch 441/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -112.4787 - g_loss: -425.46
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 80.89
# 84/84 [==============================] - 120s 1s/step - d_loss: -110.0692 - g_loss: -456.6980
# Epoch 442/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -184.1306 - g_loss: -2452.92
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 67.9
# 84/84 [==============================] - 120s 1s/step - d_loss: -192.8323 - g_loss: -2432.9623
# Epoch 443/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 230.1393 - g_loss: -1604.58
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 84.99
# 84/84 [==============================] - 120s 1s/step - d_loss: 255.9825 - g_loss: -1587.9524
# Epoch 444/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -168.1146 - g_loss: -208.99
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 67.33
# 84/84 [==============================] - 121s 1s/step - d_loss: -162.6412 - g_loss: -217.8274
# Epoch 445/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 72.3700 - g_loss: -747.85
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 89.07
# 84/84 [==============================] - 120s 1s/step - d_loss: 76.6625 - g_loss: -753.1047
# Epoch 446/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -60.8922 - g_loss: -1407.96
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 82.1
# 84/84 [==============================] - 120s 1s/step - d_loss: -59.7285 - g_loss: -1418.4691
# Epoch 447/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 98.0907 - g_loss: -1909.39
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 86.53
# 84/84 [==============================] - 121s 1s/step - d_loss: 100.6727 - g_loss: -1910.7558
# Epoch 448/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 55.8341 - g_loss: -1273.20
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 73.84
# 84/84 [==============================] - 120s 1s/step - d_loss: 55.1171 - g_loss: -1259.8753
# Epoch 449/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 0.7517 - g_loss: -149.205
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 90.32
# 84/84 [==============================] - 120s 1s/step - d_loss: 4.2905 - g_loss: -151.6164
# Epoch 450/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -4.7993 - g_loss: -158.22
# 1/1 [==============================] - 0s 50ms/step
# FID SCORE: 72.8
# 84/84 [==============================] - 120s 1s/step - d_loss: -2.6663 - g_loss: -158.5799
# Epoch 451/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -6.7448 - g_loss: -68.16
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 58.38
# 84/84 [==============================] - 121s 1s/step - d_loss: -9.1084 - g_loss: -68.4327
# Epoch 452/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -1.1753 - g_loss: -149.41
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 62.61
# 84/84 [==============================] - 121s 1s/step - d_loss: -1.2399 - g_loss: -150.0253
# Epoch 453/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 1.9474 - g_loss: 143.376
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 59.2
# 84/84 [==============================] - 121s 1s/step - d_loss: 7.2770 - g_loss: 142.5773
# Epoch 454/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -14.2214 - g_loss: -241.63
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 49.38
# 84/84 [==============================] - 122s 1s/step - d_loss: -12.5451 - g_loss: -243.5905
# Epoch 455/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -11.3393 - g_loss: -167.14
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 40.99
# 84/84 [==============================] - 123s 1s/step - d_loss: -10.4149 - g_loss: -162.0569
# Epoch 456/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -50.1439 - g_loss: 14.97
# 1/1 [==============================] - 0s 59ms/step
# FID SCORE: 63.74
# 84/84 [==============================] - 125s 1s/step - d_loss: -49.0978 - g_loss: 6.2200
# Epoch 457/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 67.2469 - g_loss: 108.88
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 51.1
# 84/84 [==============================] - 125s 1s/step - d_loss: 67.7730 - g_loss: 117.8737
# Epoch 458/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 9.9387 - g_loss: -294.044
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 75.97
# 84/84 [==============================] - 124s 1s/step - d_loss: -2.4205 - g_loss: -299.6425
# Epoch 459/500
# 1/1 [==============================] - 2s 2s/step- d_loss: -36.4980 - g_loss: -1898.06
# 1/1 [==============================] - 0s 58ms/step
# FID SCORE: 72.92
# 84/84 [==============================] - 123s 1s/step - d_loss: -49.8547 - g_loss: -1880.3169
# Epoch 460/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 5.3819 - g_loss: -2116.347
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 73.61
# 84/84 [==============================] - 123s 1s/step - d_loss: -12.3723 - g_loss: -2079.2567
# Epoch 461/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 134.4494 - g_loss: -776.62
# 1/1 [==============================] - 0s 57ms/step
# FID SCORE: 54.24
# 84/84 [==============================] - 122s 1s/step - d_loss: 123.4482 - g_loss: -767.9048
# Epoch 462/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 13.3206 - g_loss: 253.39
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 60.83
# 84/84 [==============================] - 121s 1s/step - d_loss: 14.0352 - g_loss: 255.6159
# Epoch 463/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 1.2559 - g_loss: 134.50
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 74.66
# 84/84 [==============================] - 120s 1s/step - d_loss: -1.8515 - g_loss: 126.7716
# Epoch 464/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 33.0104 - g_loss: -570.19
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 75.85
# 84/84 [==============================] - 121s 1s/step - d_loss: 31.4966 - g_loss: -567.9735
# Epoch 465/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -41.3586 - g_loss: 120.15
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 1s 1s/step- d_loss: 43.4259 - g_loss: -2882.82
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 57.79
# 84/84 [==============================] - 121s 1s/step - d_loss: 55.5468 - g_loss: -2899.8741
# Epoch 478/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 121.5938 - g_loss: -2635.58
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 44.58
# 84/84 [==============================] - 121s 1s/step - d_loss: 112.2114 - g_loss: -2637.8031
# Epoch 479/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 127.0357 - g_loss: -3734.75
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 50.12
# 84/84 [==============================] - 120s 1s/step - d_loss: 135.3693 - g_loss: -3751.3457
# Epoch 480/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -40.4196 - g_loss: -6611.06
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 53.5
# 84/84 [==============================] - 120s 1s/step - d_loss: -24.3831 - g_loss: -6594.8848
# Epoch 481/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -13.4457 - g_loss: -4919.69
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 62.71
# 84/84 [==============================] - 121s 1s/step - d_loss: -3.4205 - g_loss: -4894.5102
# Epoch 482/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -10.3637 - g_loss: -3070.94
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 37.2
# 84/84 [==============================] - 122s 1s/step - d_loss: -4.9677 - g_loss: -3062.8612
# Epoch 483/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -133.0671 - g_loss: -5794.72
# 1/1 [==============================] - 0s 55ms/step
# FID SCORE: 65.77
# 84/84 [==============================] - 121s 1s/step - d_loss: -161.6878 - g_loss: -5810.2755
# Epoch 484/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 163.0695 - g_loss: -3624.29
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 82.85
# 84/84 [==============================] - 121s 1s/step - d_loss: 152.3536 - g_loss: -3599.6280
# Epoch 485/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 184.5137 - g_loss: -2037.77
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 47.67
# 84/84 [==============================] - 121s 1s/step - d_loss: 171.8451 - g_loss: -2028.7763
# Epoch 486/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -13.4505 - g_loss: -932.81
# 1/1 [==============================] - 0s 56ms/step
# FID SCORE: 75.64
# 84/84 [==============================] - 122s 1s/step - d_loss: 36.6149 - g_loss: -955.4807
# Epoch 487/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 10.5446 - g_loss: 485.52
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 52.09
# 84/84 [==============================] - 121s 1s/step - d_loss: -4.1831 - g_loss: 512.5322
# Epoch 488/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -149.8547 - g_loss: 1033.12
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 67.33
# 84/84 [==============================] - 120s 1s/step - d_loss: -151.6041 - g_loss: 1048.7741
# Epoch 489/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 96.9207 - g_loss: 2673.677
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 80.82
# 84/84 [==============================] - 120s 1s/step - d_loss: 93.4946 - g_loss: 2709.4859
# Epoch 490/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 382.4721 - g_loss: 3528.04
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 69.43
# 84/84 [==============================] - 121s 1s/step - d_loss: 410.2725 - g_loss: 3475.1926
# Epoch 491/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 180.4397 - g_loss: 1995.76
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 102.84
# 84/84 [==============================] - 121s 1s/step - d_loss: 192.3983 - g_loss: 1998.7428
# Epoch 492/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 0.1069 - g_loss: 2608.278
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 115.74
# 84/84 [==============================] - 120s 1s/step - d_loss: 3.1497 - g_loss: 2569.9300
# Epoch 493/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -314.0399 - g_loss: 3437.64
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 114.16
# 84/84 [==============================] - 121s 1s/step - d_loss: -305.2958 - g_loss: 3413.7887
# Epoch 494/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -80.7270 - g_loss: 5453.02
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 68.6
# 84/84 [==============================] - 120s 1s/step - d_loss: -113.4173 - g_loss: 5411.1489
# Epoch 495/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 61.8155 - g_loss: 1864.41
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 99.85
# 84/84 [==============================] - 120s 1s/step - d_loss: 57.1899 - g_loss: 1851.9078
# Epoch 496/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -220.1308 - g_loss: 882.14
# 1/1 [==============================] - 0s 53ms/step
# FID SCORE: 80.86
# 84/84 [==============================] - 121s 1s/step - d_loss: -269.3750 - g_loss: 825.3588
# Epoch 497/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -12.3254 - g_loss: 1563.11
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 89.65
# 84/84 [==============================] - 120s 1s/step - d_loss: -8.2801 - g_loss: 1582.0133
# Epoch 498/500
# 1/1 [==============================] - 1s 1s/step- d_loss: -357.2312 - g_loss: 1010.50
# 1/1 [==============================] - 0s 52ms/step
# FID SCORE: 96.15
# 84/84 [==============================] - 120s 1s/step - d_loss: -349.5847 - g_loss: 1018.5247
# Epoch 499/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 146.9227 - g_loss: -2386.04
# 1/1 [==============================] - 0s 51ms/step
# FID SCORE: 104.94
# 84/84 [==============================] - 120s 1s/step - d_loss: 148.9842 - g_loss: -2383.0705
# Epoch 500/500
# 1/1 [==============================] - 1s 1s/step- d_loss: 161.2267 - g_loss: 2270.58
# 1/1 [==============================] - 0s 54ms/step
# FID SCORE: 80.01
# 84/84 [==============================] - 120s 1s/step - d_loss: 151.6505 - g_loss: 2287.3244
# CPU times: user 8h 15min 10s, sys: 35min 46s, total: 8h 50min 56s
# Wall time: 16h 42min 46s

# %% [markdown]
# ### **GET FID_SCORES & PLOT IMAGES**

# %%
min_fid_unrounded = min(fid_scores)
min_fid_unrounded
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 min_fid_unrounded = min(fid_scores)
#       2 min_fid_unrounded
#
# NameError: name 'fid_scores' is not defined

# %%
rounded_fid_scores = [np.round(i) for i in fid_scores]
min_fid = min(rounded_fid_scores)
latest_epoch_for_min_fid = 1 + max([epoch for epoch,fid_score in enumerate(rounded_fid_scores) if fid_score == min_fid])
print(latest_epoch_for_min_fid)

# %%
# take best generator and plot 64 images with it
try:
    best_gen_file = f"MoI_gen_762_(6.92).h30"
    best_generator = tf.keras.models.load_model(working_directory + "best_gen/" + best_gen_file)
    random_latent_vectors = tf.random.normal(shape=(64, noise_dim))
    generated_batch = best_generator(random_latent_vectors)
    synthetic_images = generated_batch.numpy()
    WGAN_CALLBACK().plot_multiple_images(synthetic_images, 8)                    
    plt.show()
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Plotting fid scores corresponding to each epoch
plt.figure(figsize = (30,5))
plt.plot(fid_scores, linewidth = 3, linestyle = '-', marker = 'o', markersize = 10, markerfacecolor='red', label = "FID_SCORE", color = 'k')
plt.axhline(y = min(fid_scores), color = 'green', linestyle = '--', label = 'minimum fid score')
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("FID_SCORE", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(fid_scores)),np.arange(1,len(fid_scores)+1),rotation=90)
plt.legend()
plt.title("FID SCORES FOR EACH EPOCH", fontsize = 20, fontweight = 'bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Plotting fid scores corresponding to each epoch
#       2 plt.figure(figsize = (30,5))
# ----> 3 plt.plot(fid_scores, linewidth = 3, linestyle = '-', marker = 'o', markersize = 10, markerfacecolor='red', label = "FID_SCORE", color = 'k')
#       4 plt.axhline(y = min(fid_scores), color = 'green', linestyle = '--', label = 'minimum fid score')
#       5 plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
#
# NameError: name 'fid_scores' is not defined

# %% [markdown]
# ### **PLOTTING GENERATOR VS DISCRIMINATOR LOSSES**

# %%
plt.figure(figsize = (30,5))
plt.plot(wgan_history.history['g_loss'], linewidth = 3, marker = 'o', markersize = 10, markerfacecolor='k',label = "Generator's Loss")
plt.plot(wgan_history.history['d_loss'], linewidth = 3, marker = '*', markersize = 10, markerfacecolor='k',label = "Discriminator's Loss")
plt.xlabel("EPOCHS", fontsize = 14, fontweight = 'bold')
plt.ylabel("LOSS", fontsize = 14, fontweight = 'bold')
plt.xticks(np.arange(len(wgan_history.history['g_loss'])),np.arange(1,len(wgan_history.history['g_loss'])+1),rotation=90)
plt.legend()
plt.title("GENERATOR VS DISCRIMINATOR LOSS", fontsize = 20, fontweight = 'bold')
plt.show()
